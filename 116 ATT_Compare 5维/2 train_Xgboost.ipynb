# %%
#数据预处理
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

sequence_length = 500 # 模型查看的历史窗口大小
prediction_horizon = 1 # 预测的未来窗口大小

directory = "../datas/train" #数据目录
all_items = os.listdir(directory)  #列出目录下所有文件
csv_files = [os.path.join(directory, item) for item in all_items if item.endswith('.csv') and os.path.isfile(os.path.join(directory, item))]  #筛选出CSV文件 
Sample_size = len(csv_files)  #获取样本数量

sequences_data = [] #创建一个空列表，用于存储所有序列的数据
scalers = {} #创建一个空字典，用于存储每个序列对应的标准化器
base_features = ['Voltage', 'Current']
new_features = ['impedance', 'power', 'cumulative_power']
features = base_features + new_features

for file in csv_files:
    df = pd.read_csv(file)
    df['impedance'] = df['Voltage'] * 1000 / df['Current'].replace(0, np.nan)
    df['power'] = df['Voltage'] * (df['Current'] / 1000)
    df['cumulative_power'] = (df['power']/1000).cumsum()
    # df['impedance_diff'] = df['impedance'].diff().fillna(0) #添加一阶差分
    # df['impedance_rolling_mean'] = df['impedance'].rolling(window=20, min_periods=1).mean() #滚动均值
    # df['impedance_rolling_std'] = df['impedance'].rolling(window=20, min_periods=1).std()  #滚动标准差
    # df['impedance_slope_10'] = df['impedance'].diff(10) / 10  #过去 10 个时间点的平均变化率。
    # df['impedance_slope_10'] = df['impedance_slope_10'].fillna(0) # 将该列中的所有缺失值（NaN）填充为数字0
    df = df.ffill().bfill()  #缺失值处理先用前向填充，再用后向填充
    #数据预处理 数值归一化
    scaler = StandardScaler() #为当前序列创建一个新的StandardScaler实例
    df.loc[:, features] = scaler.fit_transform(df.loc[:, features]) #对当前序列的指定特征列进行拟合和转换
    scalers[file] = scaler #将当前序列的标准化器保存到字典中，键为序列ID
    sequences_data.append(df[features + ['Action']].values) #将当前序列的数组数据添加到结果列表中

train_sequences, val_sequences = train_test_split(sequences_data, test_size=0.18, random_state=42)

print(f'检索到{Sample_size}个样本')
print(f"特征数量: {len(features)}")
print(f"序列数量: {len(sequences_data)}")
print(f"训练序列: {len(train_sequences)}")
print(f"验证序列: {len(val_sequences)}") 
# print(f"训练样本数: {len(train_dataset)}")
# print(f"验证样本数: {len(val_dataset)}")
# Out:
# 检索到55个样本
# 特征数量: 5
# 序列数量: 55
# 训练序列: 45
# 验证序列: 10

# %%
import xgboost as xgb
from tqdm import tqdm

def create_xgboost_data(sequences_data, sequence_length, prediction_horizon):
    X_list = []
    y_list = []
    
    for seq_data in tqdm(sequences_data, desc="处理序列", unit="seq", ncols=60):
        n_samples = len(seq_data) - sequence_length - prediction_horizon + 1
        
        for i in range(n_samples):
            # 提取特征
            x = seq_data[i:i + sequence_length, :-1].flatten()  # 展平为1D向量
            X_list.append(x)
            
            # 提取标签
            y_window = seq_data[i + sequence_length:i + sequence_length + prediction_horizon, -1]
            y = 1 if np.any(y_window == 1) else 0
            y_list.append(y)
    
    return np.array(X_list), np.array(y_list)

print("生成训练数据...")
X_train, y_train = create_xgboost_data(train_sequences, sequence_length, prediction_horizon)
X_val, y_val = create_xgboost_data(val_sequences, sequence_length, prediction_horizon)
# 从float64转化为float32
# X_train = X_train.astype(np.float32)
# y_val = X_val.astype(np.float32)

# 计算类别权重（处理不平衡数据）
# if np.sum(y_train) > 0:
#     scale_pos_weight = (len(y_train) - np.sum(y_train)) / np.sum(y_train)
# else:
#     scale_pos_weight = 1.0
#     print("警告: 训练集中没有正样本!")
scale_pos_weight = 1.0
    
print(f"训练样本数: {len(X_train)}")
print(f"验证样本数: {len(X_val)}")
print(f"训练集形状: X_train {X_train.shape}, y_train {y_train.shape}")
print(f"验证集形状: X_val {X_val.shape}, y_val {y_val.shape}")
print(f"特征维度: {X_train.shape[1]} (序列长度{sequence_length} × 特征数{len(features)})")
print(f"正样本比例 - 训练集: {np.mean(y_train):.4f}, 验证集: {np.mean(y_val):.4f}")
print(f"类别权重 scale_pos_weight: {scale_pos_weight:.2f}")
# Out:
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:05<00:00,  8.31seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 15.93seq/s]
# 训练样本数: 530572
# 验证样本数: 113211
# 训练集形状: X_train (530572, 2500), y_train (530572,)
# 验证集形状: X_val (113211, 2500), y_val (113211,)
# 特征维度: 2500 (序列长度500 × 特征数5)
# 正样本比例 - 训练集: 0.1427, 验证集: 0.1436
# 类别权重 scale_pos_weight: 1.00

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
from sklearn.datasets import dump_svmlight_file
import warnings
warnings.filterwarnings('ignore')

model_name = 'XGBoost'
num_boost_round=1000

# 定义XGBoost模型参数
params = {
    'tree_method': 'hist',  # 使用GPU直方图算法
    'device': 'cuda',           # 指定使用CUDA设备
    'max_bin': 256,                 # 直方图分桶数，GPU上256是常用值，可在速度和精度间权衡
    'objective': 'binary:logistic',  # 根据你的问题调整
    'eval_metric': ['logloss', 'auc', 'error'],
    'learning_rate': 0.1,
    'max_depth': 6,
    'random_state': 42,
    'reg_alpha': 0.1,
    'reg_lambda': 1.0,
    'gamma': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'colsample_bylevel': 0.8,   # 每层特征采样
    'colsample_bynode': 0.8,    # 每个节点特征采样
    'scale_pos_weight': scale_pos_weight,
    'verbosity': 1,  # 新版本推荐用法
}
print("XGBoost模型配置完成")
print("创建DMatrix...")
dtrain = xgb.QuantileDMatrix(X_train, label=y_train, max_bin=params['max_bin'])
dval = xgb.QuantileDMatrix(X_val, label=y_val, max_bin=params['max_bin'], ref=dtrain) # ref引用dtrain的分位数
print("创建DMatrix完成")
# Out:
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成

# %%
# 训练模型
from datetime import datetime

print("开始训练...")
eval_history = {}
# 使用原生接口训练
model = xgb.train(
    params, dtrain,
    num_boost_round,
    evals=[(dtrain, 'train'),(dval, 'val')],  # 这里使用 evals
    early_stopping_rounds=50,
    evals_result=eval_history,  # 这里使用 evals_result
    verbose_eval=True
)
print("XGBoost模型训练完成")
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
print(f"完成时间{timestamp}")
# Out:
# 开始训练...
# [0]	train-logloss:0.35039	train-auc:0.99735	train-error:0.14267	val-logloss:0.35270	val-auc:0.99662	val-error:0.14358
# [1]	train-logloss:0.30290	train-auc:0.99877	train-error:0.14267	val-logloss:0.30563	val-auc:0.99750	val-error:0.14358
# [2]	train-logloss:0.26644	train-auc:0.99911	train-error:0.14267	val-logloss:0.26973	val-auc:0.99792	val-error:0.14358
# [3]	train-logloss:0.23707	train-auc:0.99915	train-error:0.14263	val-logloss:0.24039	val-auc:0.99803	val-error:0.14358
# [4]	train-logloss:0.21168	train-auc:0.99926	train-error:0.02933	val-logloss:0.21645	val-auc:0.99763	val-error:0.02894
# [5]	train-logloss:0.18997	train-auc:0.99932	train-error:0.02295	val-logloss:0.19687	val-auc:0.99158	val-error:0.02525
# [6]	train-logloss:0.17138	train-auc:0.99945	train-error:0.01826	val-logloss:0.17794	val-auc:0.99805	val-error:0.02336
# [7]	train-logloss:0.15500	train-auc:0.99952	train-error:0.01412	val-logloss:0.16306	val-auc:0.99802	val-error:0.02146
# [8]	train-logloss:0.14035	train-auc:0.99960	train-error:0.01155	val-logloss:0.15034	val-auc:0.99789	val-error:0.02040
# [9]	train-logloss:0.12773	train-auc:0.99967	train-error:0.01014	val-logloss:0.13762	val-auc:0.99800	val-error:0.02047
# [10]	train-logloss:0.11637	train-auc:0.99972	train-error:0.00837	val-logloss:0.12666	val-auc:0.99822	val-error:0.01456
# [11]	train-logloss:0.10619	train-auc:0.99976	train-error:0.00699	val-logloss:0.11699	val-auc:0.99825	val-error:0.01370
# [12]	train-logloss:0.09724	train-auc:0.99979	train-error:0.00638	val-logloss:0.10924	val-auc:0.99813	val-error:0.01398
# [13]	train-logloss:0.08915	train-auc:0.99982	train-error:0.00582	val-logloss:0.10252	val-auc:0.99813	val-error:0.01393
# [14]	train-logloss:0.08183	train-auc:0.99985	train-error:0.00514	val-logloss:0.09642	val-auc:0.99811	val-error:0.01389
# [15]	train-logloss:0.07531	train-auc:0.99986	train-error:0.00499	val-logloss:0.08968	val-auc:0.99825	val-error:0.01306
# [16]	train-logloss:0.06945	train-auc:0.99988	train-error:0.00420	val-logloss:0.08445	val-auc:0.99825	val-error:0.01260
# [17]	train-logloss:0.06403	train-auc:0.99990	train-error:0.00388	val-logloss:0.07983	val-auc:0.99823	val-error:0.01282
# [18]	train-logloss:0.05920	train-auc:0.99992	train-error:0.00283	val-logloss:0.07604	val-auc:0.99817	val-error:0.01298
# [19]	train-logloss:0.05488	train-auc:0.99993	train-error:0.00281	val-logloss:0.07267	val-auc:0.99809	val-error:0.01316
# [20]	train-logloss:0.05087	train-auc:0.99993	train-error:0.00273	val-logloss:0.06892	val-auc:0.99811	val-error:0.01336
# [21]	train-logloss:0.04736	train-auc:0.99994	train-error:0.00266	val-logloss:0.06549	val-auc:0.99817	val-error:0.01323
# [22]	train-logloss:0.04403	train-auc:0.99995	train-error:0.00241	val-logloss:0.06278	val-auc:0.99816	val-error:0.01292
# [23]	train-logloss:0.04107	train-auc:0.99996	train-error:0.00225	val-logloss:0.06047	val-auc:0.99816	val-error:0.01328
# [24]	train-logloss:0.03839	train-auc:0.99996	train-error:0.00224	val-logloss:0.05885	val-auc:0.99813	val-error:0.01325
# [25]	train-logloss:0.03601	train-auc:0.99996	train-error:0.00227	val-logloss:0.05621	val-auc:0.99820	val-error:0.01322
# [26]	train-logloss:0.03368	train-auc:0.99997	train-error:0.00212	val-logloss:0.05433	val-auc:0.99818	val-error:0.01363
# [27]	train-logloss:0.03160	train-auc:0.99997	train-error:0.00205	val-logloss:0.05288	val-auc:0.99816	val-error:0.01369
# [28]	train-logloss:0.02976	train-auc:0.99997	train-error:0.00204	val-logloss:0.05120	val-auc:0.99819	val-error:0.01376
# [29]	train-logloss:0.02795	train-auc:0.99997	train-error:0.00201	val-logloss:0.04908	val-auc:0.99828	val-error:0.01313
# [30]	train-logloss:0.02632	train-auc:0.99998	train-error:0.00192	val-logloss:0.04752	val-auc:0.99833	val-error:0.01292
# [31]	train-logloss:0.02498	train-auc:0.99998	train-error:0.00191	val-logloss:0.04639	val-auc:0.99833	val-error:0.01285
# [32]	train-logloss:0.02367	train-auc:0.99998	train-error:0.00188	val-logloss:0.04525	val-auc:0.99836	val-error:0.01295
# [33]	train-logloss:0.02255	train-auc:0.99998	train-error:0.00187	val-logloss:0.04409	val-auc:0.99838	val-error:0.01273
# [34]	train-logloss:0.02134	train-auc:0.99998	train-error:0.00165	val-logloss:0.04306	val-auc:0.99842	val-error:0.01292
# [35]	train-logloss:0.02033	train-auc:0.99998	train-error:0.00158	val-logloss:0.04201	val-auc:0.99845	val-error:0.01248
# [36]	train-logloss:0.01942	train-auc:0.99998	train-error:0.00151	val-logloss:0.04168	val-auc:0.99843	val-error:0.01291
# [37]	train-logloss:0.01861	train-auc:0.99999	train-error:0.00144	val-logloss:0.04138	val-auc:0.99840	val-error:0.01294
# [38]	train-logloss:0.01776	train-auc:0.99999	train-error:0.00126	val-logloss:0.04060	val-auc:0.99842	val-error:0.01309
# [39]	train-logloss:0.01710	train-auc:0.99999	train-error:0.00119	val-logloss:0.03972	val-auc:0.99846	val-error:0.01285
# [40]	train-logloss:0.01638	train-auc:0.99999	train-error:0.00113	val-logloss:0.03928	val-auc:0.99845	val-error:0.01281
# [41]	train-logloss:0.01574	train-auc:0.99999	train-error:0.00111	val-logloss:0.03864	val-auc:0.99849	val-error:0.01268
# [42]	train-logloss:0.01522	train-auc:0.99999	train-error:0.00111	val-logloss:0.03837	val-auc:0.99849	val-error:0.01268
# [43]	train-logloss:0.01466	train-auc:0.99999	train-error:0.00109	val-logloss:0.03823	val-auc:0.99847	val-error:0.01268
# [44]	train-logloss:0.01414	train-auc:0.99999	train-error:0.00100	val-logloss:0.03836	val-auc:0.99845	val-error:0.01283
# [45]	train-logloss:0.01369	train-auc:0.99999	train-error:0.00092	val-logloss:0.03811	val-auc:0.99845	val-error:0.01286
# [46]	train-logloss:0.01316	train-auc:0.99999	train-error:0.00088	val-logloss:0.03778	val-auc:0.99845	val-error:0.01289
# [47]	train-logloss:0.01270	train-auc:0.99999	train-error:0.00087	val-logloss:0.03740	val-auc:0.99848	val-error:0.01319
# [48]	train-logloss:0.01231	train-auc:0.99999	train-error:0.00086	val-logloss:0.03699	val-auc:0.99851	val-error:0.01291
# [49]	train-logloss:0.01199	train-auc:1.00000	train-error:0.00078	val-logloss:0.03666	val-auc:0.99852	val-error:0.01289
# [50]	train-logloss:0.01170	train-auc:1.00000	train-error:0.00075	val-logloss:0.03653	val-auc:0.99852	val-error:0.01296
# [51]	train-logloss:0.01143	train-auc:1.00000	train-error:0.00072	val-logloss:0.03647	val-auc:0.99851	val-error:0.01300
# [52]	train-logloss:0.01110	train-auc:1.00000	train-error:0.00065	val-logloss:0.03623	val-auc:0.99852	val-error:0.01308
# [53]	train-logloss:0.01087	train-auc:1.00000	train-error:0.00062	val-logloss:0.03620	val-auc:0.99851	val-error:0.01309
# [54]	train-logloss:0.01047	train-auc:1.00000	train-error:0.00045	val-logloss:0.03600	val-auc:0.99853	val-error:0.01325
# [55]	train-logloss:0.01016	train-auc:1.00000	train-error:0.00042	val-logloss:0.03572	val-auc:0.99854	val-error:0.01335
# [56]	train-logloss:0.00981	train-auc:1.00000	train-error:0.00039	val-logloss:0.03555	val-auc:0.99855	val-error:0.01327
# [57]	train-logloss:0.00956	train-auc:1.00000	train-error:0.00041	val-logloss:0.03575	val-auc:0.99853	val-error:0.01353
# [58]	train-logloss:0.00934	train-auc:1.00000	train-error:0.00042	val-logloss:0.03577	val-auc:0.99852	val-error:0.01351
# [59]	train-logloss:0.00909	train-auc:1.00000	train-error:0.00037	val-logloss:0.03551	val-auc:0.99855	val-error:0.01340
# [60]	train-logloss:0.00885	train-auc:1.00000	train-error:0.00033	val-logloss:0.03540	val-auc:0.99856	val-error:0.01356
# [61]	train-logloss:0.00864	train-auc:1.00000	train-error:0.00032	val-logloss:0.03555	val-auc:0.99854	val-error:0.01357
# [62]	train-logloss:0.00840	train-auc:1.00000	train-error:0.00031	val-logloss:0.03555	val-auc:0.99853	val-error:0.01381
# [63]	train-logloss:0.00818	train-auc:1.00000	train-error:0.00029	val-logloss:0.03564	val-auc:0.99852	val-error:0.01387
# [64]	train-logloss:0.00797	train-auc:1.00000	train-error:0.00030	val-logloss:0.03537	val-auc:0.99854	val-error:0.01368
# [65]	train-logloss:0.00778	train-auc:1.00000	train-error:0.00028	val-logloss:0.03527	val-auc:0.99854	val-error:0.01394
# [66]	train-logloss:0.00753	train-auc:1.00000	train-error:0.00027	val-logloss:0.03546	val-auc:0.99853	val-error:0.01412
# [67]	train-logloss:0.00738	train-auc:1.00000	train-error:0.00026	val-logloss:0.03526	val-auc:0.99855	val-error:0.01405
# [68]	train-logloss:0.00714	train-auc:1.00000	train-error:0.00022	val-logloss:0.03532	val-auc:0.99854	val-error:0.01452
# [69]	train-logloss:0.00693	train-auc:1.00000	train-error:0.00019	val-logloss:0.03540	val-auc:0.99853	val-error:0.01462
# [70]	train-logloss:0.00682	train-auc:1.00000	train-error:0.00018	val-logloss:0.03547	val-auc:0.99852	val-error:0.01467
# [71]	train-logloss:0.00670	train-auc:1.00000	train-error:0.00018	val-logloss:0.03571	val-auc:0.99850	val-error:0.01490
# [72]	train-logloss:0.00652	train-auc:1.00000	train-error:0.00016	val-logloss:0.03581	val-auc:0.99849	val-error:0.01474
# [73]	train-logloss:0.00640	train-auc:1.00000	train-error:0.00016	val-logloss:0.03570	val-auc:0.99851	val-error:0.01471
# [74]	train-logloss:0.00625	train-auc:1.00000	train-error:0.00016	val-logloss:0.03596	val-auc:0.99848	val-error:0.01488
# [75]	train-logloss:0.00615	train-auc:1.00000	train-error:0.00017	val-logloss:0.03588	val-auc:0.99850	val-error:0.01490
# [76]	train-logloss:0.00601	train-auc:1.00000	train-error:0.00016	val-logloss:0.03584	val-auc:0.99850	val-error:0.01487
# [77]	train-logloss:0.00577	train-auc:1.00000	train-error:0.00014	val-logloss:0.03589	val-auc:0.99850	val-error:0.01457
# [78]	train-logloss:0.00559	train-auc:1.00000	train-error:0.00014	val-logloss:0.03550	val-auc:0.99853	val-error:0.01438
# [79]	train-logloss:0.00537	train-auc:1.00000	train-error:0.00013	val-logloss:0.03595	val-auc:0.99849	val-error:0.01469
# [80]	train-logloss:0.00526	train-auc:1.00000	train-error:0.00011	val-logloss:0.03617	val-auc:0.99848	val-error:0.01498
# [81]	train-logloss:0.00504	train-auc:1.00000	train-error:0.00009	val-logloss:0.03640	val-auc:0.99848	val-error:0.01534
# [82]	train-logloss:0.00493	train-auc:1.00000	train-error:0.00009	val-logloss:0.03647	val-auc:0.99848	val-error:0.01507
# [83]	train-logloss:0.00474	train-auc:1.00000	train-error:0.00007	val-logloss:0.03696	val-auc:0.99844	val-error:0.01537
# [84]	train-logloss:0.00459	train-auc:1.00000	train-error:0.00007	val-logloss:0.03733	val-auc:0.99841	val-error:0.01526
# [85]	train-logloss:0.00449	train-auc:1.00000	train-error:0.00007	val-logloss:0.03724	val-auc:0.99842	val-error:0.01513
# XGBoost模型训练完成
# 完成时间20251215_140736

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
# 绘制logloss
plt.subplot(1, 3, 1)
plt.plot(eval_history['train']['logloss'], label='Train Logloss')
plt.plot(eval_history['val']['logloss'], label='Validation Logloss')
plt.xlabel('Iteration')
plt.ylabel('Logloss')
plt.title('XGBoost Training - Logloss')
plt.legend()
plt.grid(True)

# 绘制错误率
plt.subplot(1, 3, 2)
plt.plot(eval_history['train']['error'], label='Train Error')
plt.plot(eval_history['val']['error'], label='Validation Error')
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.title('XGBoost Training - Error')
plt.legend()
plt.grid(True)

# 绘制错误率
plt.subplot(1, 3, 3)
plt.plot(eval_history['train']['auc'], label='Train auc')
plt.plot(eval_history['val']['auc'], label='Validation auc')
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.title('XGBoost Training - auc')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
"""
评估XGBoost模型性能
"""
print("\n" + "="*60)
print("XGBoost模型评估结果")
print("="*60)

# 训练集预测
y_train_prob = model.predict(dtrain)  # 预测概率
y_train_pred = (y_train_prob > 0.5).astype(int)  # 转换为类别

# 验证集预测
y_val_prob = model.predict(dval)  # 预测概率
y_val_pred = (y_val_prob > 0.5).astype(int)  # 转换为类别

# 计算训练集指标
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, zero_division=0)
train_recall = recall_score(y_train, y_train_pred, zero_division=0)
train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
train_auc = roc_auc_score(y_train, y_train_prob)

# 计算验证集指标
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred, zero_division=0)
val_recall = recall_score(y_val, y_val_pred, zero_division=0)
val_f1 = f1_score(y_val, y_val_pred, zero_division=0)
val_auc = roc_auc_score(y_val, y_val_prob)

# 打印结果表格
print(f"{'指标':<12} | {'训练集':<10} | {'验证集':<10}")
print("-" * 40)
print(f"{'准确率':<12} | {train_accuracy:>10.4f} | {val_accuracy:>10.4f}")
print(f"{'精确率':<12} | {train_precision:>10.4f} | {val_precision:>10.4f}")
print(f"{'召回率':<12} | {train_recall:>10.4f} | {val_recall:>10.4f}")
print(f"{'F1分数':<13} | {train_f1:>10.4f} | {val_f1:>10.4f}")
print(f"{'AUC':<14} | {train_auc:>10.4f} | {val_auc:>10.4f}")

# 验证集详细报告
print(f"\n验证集详细分类报告:")
print(classification_report(y_val, y_val_pred, target_names=['Class 0', 'Class 1']))

# 混淆矩阵
cm = confusion_matrix(y_val, y_val_pred)
print(f"\n验证集混淆矩阵:")
print(f"TN: {cm[0,0]}, FP: {cm[0,1]}")
print(f"FN: {cm[1,0]}, TP: {cm[1,1]}")

feature_names = [f'feature_{i}' for i in range(X_train.shape[1])]

model_name="Model_XGBoost.pkl"

"""
保存XGBoost模型
"""
# 准备保存的数据
model_data = {
    'model': model,
    'feature_names': feature_names,
    'model_type': 'booster'
}
# 获取特征数量
if X_train is not None:
    num_features = X_train.shape[1]
else:
    num_features = len(feature_names)

# 获取最佳迭代轮数
best_iteration = getattr(model, 'best_iteration', '未知')
best_score = getattr(model, 'best_score', '未知')

model_data.update({
    'num_features': num_features,
    'best_iteration': best_iteration,
    'best_score': best_score
})

# 保存模型
joblib.dump(model_data, model_name)
print(f"\n模型已保存为: {model_name}")
print(f"模型类型: Booster (原生接口)")
print(f"特征数量: {model_data.get('num_features', len(feature_names))}")
print(f"最佳迭代轮数: {best_iteration}")
print(f"最佳验证分数: {best_score}")
print(f"类别: [0, 1] (二分类任务)")
print(f"\n{'='*60}")
print("XGBoost模型训练完成!")
print(f"{'='*60}")
# Out:
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9999 |     0.9849
# 精确率          |     0.9998 |     0.9653
# 召回率          |     0.9997 |     0.9280
# F1分数          |     0.9998 |     0.9463
# AUC            |     1.0000 |     0.9984
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99     96956
#      Class 1       0.97      0.93      0.95     16255
#
#     accuracy                           0.98    113211
#    macro avg       0.98      0.96      0.97    113211
# weighted avg       0.98      0.98      0.98    113211
#
#
# 验证集混淆矩阵:
# TN: 96413, FP: 543
# FN: 1170, TP: 15085
#
# 模型已保存为: Model_XGBoost.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 2500
# 最佳迭代轮数: 35
# 最佳验证分数: 0.01248111932586056
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
