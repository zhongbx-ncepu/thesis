# %%
#数据预处理
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

sequence_length = 500 # 模型查看的历史窗口大小
prediction_horizon = 1 # 预测的未来窗口大小

directory = "../datas/train" #数据目录
all_items = os.listdir(directory)  #列出目录下所有文件
csv_files = [os.path.join(directory, item) for item in all_items if item.endswith('.csv') and os.path.isfile(os.path.join(directory, item))]  #筛选出CSV文件 
Sample_size = len(csv_files)  #获取样本数量

sequences_data = [] #创建一个空列表，用于存储所有序列的数据
scalers = {} #创建一个空字典，用于存储每个序列对应的标准化器
base_features = ['Voltage', 'Current']
new_features = ['impedance', 'power', 'cumulative_power', 'impedance_diff', 'impedance_slope_10']
features = base_features + new_features

for file in csv_files:
    df = pd.read_csv(file)
    df['impedance'] = df['Voltage'] * 1000 / df['Current'].replace(0, np.nan)
    df['power'] = df['Voltage'] * (df['Current'] / 1000)
    df['cumulative_power'] = (df['power']/1000).cumsum()
    df['impedance_diff'] = df['impedance'].diff().fillna(0) #添加一阶差分
    # df['impedance_rolling_mean'] = df['impedance'].rolling(window=20, min_periods=1).mean() #滚动均值
    # df['impedance_rolling_std'] = df['impedance'].rolling(window=20, min_periods=1).std()  #滚动标准差
    df['impedance_slope_10'] = df['impedance'].diff(10) / 10  #过去 10 个时间点的平均变化率。
    df['impedance_slope_10'] = df['impedance_slope_10'].fillna(0) # 将该列中的所有缺失值（NaN）填充为数字0
    df = df.ffill().bfill()  #缺失值处理先用前向填充，再用后向填充
    #数据预处理 数值归一化
    scaler = StandardScaler() #为当前序列创建一个新的StandardScaler实例
    df.loc[:, features] = scaler.fit_transform(df.loc[:, features]) #对当前序列的指定特征列进行拟合和转换
    scalers[file] = scaler #将当前序列的标准化器保存到字典中，键为序列ID
    sequences_data.append(df[features + ['Action']].values) #将当前序列的数组数据添加到结果列表中

train_sequences, val_sequences = train_test_split(sequences_data, test_size=0.18, random_state=42)

print(f'检索到{Sample_size}个样本')
print(f"特征数量: {len(features)}")
print(f"序列数量: {len(sequences_data)}")
print(f"训练序列: {len(train_sequences)}")
print(f"验证序列: {len(val_sequences)}") 
# print(f"训练样本数: {len(train_dataset)}")
# print(f"验证样本数: {len(val_dataset)}")
# Out:
# 检索到55个样本
# 特征数量: 7
# 序列数量: 55
# 训练序列: 45
# 验证序列: 10

# %%
import xgboost as xgb
from tqdm import tqdm

def create_xgboost_data(sequences_data, sequence_length, prediction_horizon):
    X_list = []
    y_list = []
    
    for seq_data in tqdm(sequences_data, desc="处理序列", unit="seq", ncols=60):
        n_samples = len(seq_data) - sequence_length - prediction_horizon + 1
        
        for i in range(n_samples):
            # 提取特征
            x = seq_data[i:i + sequence_length, :-1].flatten()  # 展平为1D向量
            X_list.append(x)
            
            # 提取标签
            y_window = seq_data[i + sequence_length:i + sequence_length + prediction_horizon, -1]
            y = 1 if np.any(y_window == 1) else 0
            y_list.append(y)
    
    return np.array(X_list), np.array(y_list)

print("生成训练数据...")
X_train, y_train = create_xgboost_data(train_sequences, sequence_length, prediction_horizon)
X_val, y_val = create_xgboost_data(val_sequences, sequence_length, prediction_horizon)
# 从float64转化为float32
# X_train = X_train.astype(np.float32)
# y_val = X_val.astype(np.float32)

# 计算类别权重（处理不平衡数据）
# if np.sum(y_train) > 0:
#     scale_pos_weight = (len(y_train) - np.sum(y_train)) / np.sum(y_train)
# else:
#     scale_pos_weight = 1.0
#     print("警告: 训练集中没有正样本!")
scale_pos_weight = 1.0
    
print(f"训练样本数: {len(X_train)}")
print(f"验证样本数: {len(X_val)}")
print(f"训练集形状: X_train {X_train.shape}, y_train {y_train.shape}")
print(f"验证集形状: X_val {X_val.shape}, y_val {y_val.shape}")
print(f"特征维度: {X_train.shape[1]} (序列长度{sequence_length} × 特征数{len(features)})")
print(f"正样本比例 - 训练集: {np.mean(y_train):.4f}, 验证集: {np.mean(y_val):.4f}")
print(f"类别权重 scale_pos_weight: {scale_pos_weight:.2f}")
# Out:
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:06<00:00,  6.95seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 12.94seq/s]
# 训练样本数: 530572
# 验证样本数: 113211
# 训练集形状: X_train (530572, 3500), y_train (530572,)
# 验证集形状: X_val (113211, 3500), y_val (113211,)
# 特征维度: 3500 (序列长度500 × 特征数7)
# 正样本比例 - 训练集: 0.1427, 验证集: 0.1436
# 类别权重 scale_pos_weight: 1.00

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
from sklearn.datasets import dump_svmlight_file
import warnings
warnings.filterwarnings('ignore')

model_name = 'XGBoost'
num_boost_round=1000

# 定义XGBoost模型参数
params = {
    'tree_method': 'hist',  # 使用GPU直方图算法
    'device': 'cuda',           # 指定使用CUDA设备
    'max_bin': 256,                 # 直方图分桶数，GPU上256是常用值，可在速度和精度间权衡
    'objective': 'binary:logistic',  # 根据你的问题调整
    'eval_metric': ['logloss', 'auc', 'error'],
    'learning_rate': 0.1,
    'max_depth': 6,
    'random_state': 42,
    'reg_alpha': 0.1,
    'reg_lambda': 1.0,
    'gamma': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'colsample_bylevel': 0.8,   # 每层特征采样
    'colsample_bynode': 0.8,    # 每个节点特征采样
    'scale_pos_weight': scale_pos_weight,
    'verbosity': 1,  # 新版本推荐用法
}
print("XGBoost模型配置完成")
print("创建DMatrix...")
dtrain = xgb.QuantileDMatrix(X_train, label=y_train, max_bin=params['max_bin'])
dval = xgb.QuantileDMatrix(X_val, label=y_val, max_bin=params['max_bin'], ref=dtrain) # ref引用dtrain的分位数
print("创建DMatrix完成")
# Out:
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成

# %%
# 训练模型
from datetime import datetime

print("开始训练...")
eval_history = {}
# 使用原生接口训练
model = xgb.train(
    params, dtrain,
    num_boost_round,
    evals=[(dtrain, 'train'),(dval, 'val')],  # 这里使用 evals
    early_stopping_rounds=50,
    evals_result=eval_history,  # 这里使用 evals_result
    verbose_eval=True
)
print("XGBoost模型训练完成")
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
print(f"完成时间{timestamp}")
# Out:
# 开始训练...
# [0]	train-logloss:0.35023	train-auc:0.99735	train-error:0.14267	val-logloss:0.35262	val-auc:0.99645	val-error:0.14358
# [1]	train-logloss:0.30259	train-auc:0.99870	train-error:0.14267	val-logloss:0.30490	val-auc:0.99754	val-error:0.14358
# [2]	train-logloss:0.26576	train-auc:0.99921	train-error:0.14267	val-logloss:0.26863	val-auc:0.99774	val-error:0.14358
# [3]	train-logloss:0.23570	train-auc:0.99935	train-error:0.14263	val-logloss:0.24031	val-auc:0.99760	val-error:0.14358
# [4]	train-logloss:0.21015	train-auc:0.99945	train-error:0.03075	val-logloss:0.21701	val-auc:0.99755	val-error:0.03091
# [5]	train-logloss:0.18821	train-auc:0.99950	train-error:0.02251	val-logloss:0.19565	val-auc:0.99793	val-error:0.02474
# [6]	train-logloss:0.16933	train-auc:0.99960	train-error:0.01518	val-logloss:0.17731	val-auc:0.99767	val-error:0.02122
# [7]	train-logloss:0.15303	train-auc:0.99963	train-error:0.01293	val-logloss:0.16170	val-auc:0.99749	val-error:0.01790
# [8]	train-logloss:0.13863	train-auc:0.99967	train-error:0.01010	val-logloss:0.14818	val-auc:0.99746	val-error:0.01475
# [9]	train-logloss:0.12592	train-auc:0.99968	train-error:0.00842	val-logloss:0.13716	val-auc:0.99762	val-error:0.01657
# [10]	train-logloss:0.11437	train-auc:0.99974	train-error:0.00688	val-logloss:0.12647	val-auc:0.99798	val-error:0.01331
# [11]	train-logloss:0.10423	train-auc:0.99978	train-error:0.00548	val-logloss:0.11751	val-auc:0.99815	val-error:0.01353
# [12]	train-logloss:0.09526	train-auc:0.99981	train-error:0.00458	val-logloss:0.10956	val-auc:0.99811	val-error:0.01377
# [13]	train-logloss:0.08714	train-auc:0.99983	train-error:0.00388	val-logloss:0.10229	val-auc:0.99815	val-error:0.01269
# [14]	train-logloss:0.07984	train-auc:0.99986	train-error:0.00348	val-logloss:0.09627	val-auc:0.99810	val-error:0.01245
# [15]	train-logloss:0.07340	train-auc:0.99986	train-error:0.00317	val-logloss:0.09068	val-auc:0.99809	val-error:0.01302
# [16]	train-logloss:0.06735	train-auc:0.99993	train-error:0.00294	val-logloss:0.08580	val-auc:0.99808	val-error:0.01337
# [17]	train-logloss:0.06197	train-auc:0.99994	train-error:0.00265	val-logloss:0.08121	val-auc:0.99812	val-error:0.01443
# [18]	train-logloss:0.05722	train-auc:0.99995	train-error:0.00236	val-logloss:0.07743	val-auc:0.99806	val-error:0.01483
# [19]	train-logloss:0.05290	train-auc:0.99996	train-error:0.00216	val-logloss:0.07370	val-auc:0.99805	val-error:0.01450
# [20]	train-logloss:0.04894	train-auc:0.99996	train-error:0.00200	val-logloss:0.07019	val-auc:0.99806	val-error:0.01366
# [21]	train-logloss:0.04542	train-auc:0.99997	train-error:0.00193	val-logloss:0.06789	val-auc:0.99795	val-error:0.01483
# [22]	train-logloss:0.04226	train-auc:0.99997	train-error:0.00176	val-logloss:0.06530	val-auc:0.99792	val-error:0.01544
# [23]	train-logloss:0.03937	train-auc:0.99997	train-error:0.00169	val-logloss:0.06256	val-auc:0.99800	val-error:0.01550
# [24]	train-logloss:0.03665	train-auc:0.99998	train-error:0.00147	val-logloss:0.06107	val-auc:0.99788	val-error:0.01639
# [25]	train-logloss:0.03418	train-auc:0.99998	train-error:0.00152	val-logloss:0.05853	val-auc:0.99797	val-error:0.01641
# [26]	train-logloss:0.03195	train-auc:0.99998	train-error:0.00151	val-logloss:0.05622	val-auc:0.99804	val-error:0.01609
# [27]	train-logloss:0.02997	train-auc:0.99998	train-error:0.00152	val-logloss:0.05416	val-auc:0.99811	val-error:0.01564
# [28]	train-logloss:0.02804	train-auc:0.99998	train-error:0.00143	val-logloss:0.05273	val-auc:0.99809	val-error:0.01547
# [29]	train-logloss:0.02634	train-auc:0.99999	train-error:0.00125	val-logloss:0.05143	val-auc:0.99809	val-error:0.01503
# [30]	train-logloss:0.02472	train-auc:0.99999	train-error:0.00109	val-logloss:0.05020	val-auc:0.99810	val-error:0.01525
# [31]	train-logloss:0.02321	train-auc:0.99999	train-error:0.00106	val-logloss:0.04864	val-auc:0.99814	val-error:0.01518
# [32]	train-logloss:0.02201	train-auc:0.99999	train-error:0.00102	val-logloss:0.04793	val-auc:0.99812	val-error:0.01495
# [33]	train-logloss:0.02092	train-auc:0.99999	train-error:0.00098	val-logloss:0.04749	val-auc:0.99807	val-error:0.01539
# [34]	train-logloss:0.01975	train-auc:0.99999	train-error:0.00096	val-logloss:0.04666	val-auc:0.99809	val-error:0.01464
# [35]	train-logloss:0.01882	train-auc:0.99999	train-error:0.00097	val-logloss:0.04621	val-auc:0.99807	val-error:0.01470
# [36]	train-logloss:0.01795	train-auc:0.99999	train-error:0.00100	val-logloss:0.04596	val-auc:0.99802	val-error:0.01507
# [37]	train-logloss:0.01702	train-auc:0.99999	train-error:0.00096	val-logloss:0.04506	val-auc:0.99807	val-error:0.01441
# [38]	train-logloss:0.01619	train-auc:0.99999	train-error:0.00095	val-logloss:0.04440	val-auc:0.99810	val-error:0.01407
# [39]	train-logloss:0.01554	train-auc:0.99999	train-error:0.00092	val-logloss:0.04365	val-auc:0.99812	val-error:0.01386
# [40]	train-logloss:0.01479	train-auc:1.00000	train-error:0.00075	val-logloss:0.04305	val-auc:0.99813	val-error:0.01416
# [41]	train-logloss:0.01412	train-auc:1.00000	train-error:0.00069	val-logloss:0.04249	val-auc:0.99815	val-error:0.01381
# [42]	train-logloss:0.01361	train-auc:1.00000	train-error:0.00067	val-logloss:0.04240	val-auc:0.99813	val-error:0.01413
# [43]	train-logloss:0.01292	train-auc:1.00000	train-error:0.00054	val-logloss:0.04174	val-auc:0.99816	val-error:0.01391
# [44]	train-logloss:0.01241	train-auc:1.00000	train-error:0.00051	val-logloss:0.04150	val-auc:0.99814	val-error:0.01391
# [45]	train-logloss:0.01196	train-auc:1.00000	train-error:0.00047	val-logloss:0.04186	val-auc:0.99808	val-error:0.01426
# [46]	train-logloss:0.01143	train-auc:1.00000	train-error:0.00041	val-logloss:0.04108	val-auc:0.99814	val-error:0.01405
# [47]	train-logloss:0.01098	train-auc:1.00000	train-error:0.00037	val-logloss:0.04082	val-auc:0.99814	val-error:0.01427
# [48]	train-logloss:0.01059	train-auc:1.00000	train-error:0.00033	val-logloss:0.04032	val-auc:0.99817	val-error:0.01425
# [49]	train-logloss:0.01024	train-auc:1.00000	train-error:0.00034	val-logloss:0.04023	val-auc:0.99816	val-error:0.01414
# [50]	train-logloss:0.00983	train-auc:1.00000	train-error:0.00030	val-logloss:0.03969	val-auc:0.99819	val-error:0.01398
# [51]	train-logloss:0.00944	train-auc:1.00000	train-error:0.00026	val-logloss:0.03958	val-auc:0.99819	val-error:0.01406
# [52]	train-logloss:0.00912	train-auc:1.00000	train-error:0.00022	val-logloss:0.03913	val-auc:0.99821	val-error:0.01405
# [53]	train-logloss:0.00877	train-auc:1.00000	train-error:0.00022	val-logloss:0.03894	val-auc:0.99821	val-error:0.01388
# [54]	train-logloss:0.00845	train-auc:1.00000	train-error:0.00019	val-logloss:0.03896	val-auc:0.99819	val-error:0.01394
# [55]	train-logloss:0.00822	train-auc:1.00000	train-error:0.00019	val-logloss:0.03883	val-auc:0.99819	val-error:0.01398
# [56]	train-logloss:0.00790	train-auc:1.00000	train-error:0.00018	val-logloss:0.03862	val-auc:0.99819	val-error:0.01404
# [57]	train-logloss:0.00766	train-auc:1.00000	train-error:0.00017	val-logloss:0.03845	val-auc:0.99819	val-error:0.01405
# [58]	train-logloss:0.00747	train-auc:1.00000	train-error:0.00017	val-logloss:0.03871	val-auc:0.99817	val-error:0.01415
# [59]	train-logloss:0.00722	train-auc:1.00000	train-error:0.00015	val-logloss:0.03887	val-auc:0.99815	val-error:0.01421
# [60]	train-logloss:0.00703	train-auc:1.00000	train-error:0.00016	val-logloss:0.03938	val-auc:0.99810	val-error:0.01439
# [61]	train-logloss:0.00681	train-auc:1.00000	train-error:0.00014	val-logloss:0.03920	val-auc:0.99811	val-error:0.01449
# [62]	train-logloss:0.00661	train-auc:1.00000	train-error:0.00014	val-logloss:0.03916	val-auc:0.99811	val-error:0.01450
# [63]	train-logloss:0.00645	train-auc:1.00000	train-error:0.00014	val-logloss:0.03911	val-auc:0.99811	val-error:0.01444
# [64]	train-logloss:0.00628	train-auc:1.00000	train-error:0.00013	val-logloss:0.03881	val-auc:0.99813	val-error:0.01442
# XGBoost模型训练完成
# 完成时间20251215_140552

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
# 绘制logloss
plt.subplot(1, 3, 1)
plt.plot(eval_history['train']['logloss'], label='Train Logloss')
plt.plot(eval_history['val']['logloss'], label='Validation Logloss')
plt.xlabel('Iteration')
plt.ylabel('Logloss')
plt.title('XGBoost Training - Logloss')
plt.legend()
plt.grid(True)

# 绘制错误率
plt.subplot(1, 3, 2)
plt.plot(eval_history['train']['error'], label='Train Error')
plt.plot(eval_history['val']['error'], label='Validation Error')
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.title('XGBoost Training - Error')
plt.legend()
plt.grid(True)

# 绘制错误率
plt.subplot(1, 3, 3)
plt.plot(eval_history['train']['auc'], label='Train auc')
plt.plot(eval_history['val']['auc'], label='Validation auc')
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.title('XGBoost Training - auc')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
"""
评估XGBoost模型性能
"""
print("\n" + "="*60)
print("XGBoost模型评估结果")
print("="*60)

# 训练集预测
y_train_prob = model.predict(dtrain)  # 预测概率
y_train_pred = (y_train_prob > 0.5).astype(int)  # 转换为类别

# 验证集预测
y_val_prob = model.predict(dval)  # 预测概率
y_val_pred = (y_val_prob > 0.5).astype(int)  # 转换为类别

# 计算训练集指标
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, zero_division=0)
train_recall = recall_score(y_train, y_train_pred, zero_division=0)
train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
train_auc = roc_auc_score(y_train, y_train_prob)

# 计算验证集指标
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred, zero_division=0)
val_recall = recall_score(y_val, y_val_pred, zero_division=0)
val_f1 = f1_score(y_val, y_val_pred, zero_division=0)
val_auc = roc_auc_score(y_val, y_val_prob)

# 打印结果表格
print(f"{'指标':<12} | {'训练集':<10} | {'验证集':<10}")
print("-" * 40)
print(f"{'准确率':<12} | {train_accuracy:>10.4f} | {val_accuracy:>10.4f}")
print(f"{'精确率':<12} | {train_precision:>10.4f} | {val_precision:>10.4f}")
print(f"{'召回率':<12} | {train_recall:>10.4f} | {val_recall:>10.4f}")
print(f"{'F1分数':<13} | {train_f1:>10.4f} | {val_f1:>10.4f}")
print(f"{'AUC':<14} | {train_auc:>10.4f} | {val_auc:>10.4f}")

# 验证集详细报告
print(f"\n验证集详细分类报告:")
print(classification_report(y_val, y_val_pred, target_names=['Class 0', 'Class 1']))

# 混淆矩阵
cm = confusion_matrix(y_val, y_val_pred)
print(f"\n验证集混淆矩阵:")
print(f"TN: {cm[0,0]}, FP: {cm[0,1]}")
print(f"FN: {cm[1,0]}, TP: {cm[1,1]}")

feature_names = [f'feature_{i}' for i in range(X_train.shape[1])]

model_name="Model_XGBoost.pkl"

"""
保存XGBoost模型
"""
# 准备保存的数据
model_data = {
    'model': model,
    'feature_names': feature_names,
    'model_type': 'booster'
}
# 获取特征数量
if X_train is not None:
    num_features = X_train.shape[1]
else:
    num_features = len(feature_names)

# 获取最佳迭代轮数
best_iteration = getattr(model, 'best_iteration', '未知')
best_score = getattr(model, 'best_score', '未知')

model_data.update({
    'num_features': num_features,
    'best_iteration': best_iteration,
    'best_score': best_score
})

# 保存模型
joblib.dump(model_data, model_name)
print(f"\n模型已保存为: {model_name}")
print(f"模型类型: Booster (原生接口)")
print(f"特征数量: {model_data.get('num_features', len(feature_names))}")
print(f"最佳迭代轮数: {best_iteration}")
print(f"最佳验证分数: {best_score}")
print(f"类别: [0, 1] (二分类任务)")
print(f"\n{'='*60}")
print("XGBoost模型训练完成!")
print(f"{'='*60}")
# Out:
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9999 |     0.9856
# 精确率          |     0.9997 |     0.9577
# 召回率          |     0.9994 |     0.9411
# F1分数          |     0.9996 |     0.9494
# AUC            |     1.0000 |     0.9981
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99     96956
#      Class 1       0.96      0.94      0.95     16255
#
#     accuracy                           0.99    113211
#    macro avg       0.97      0.97      0.97    113211
# weighted avg       0.99      0.99      0.99    113211
#
#
# 验证集混淆矩阵:
# TN: 96281, FP: 675
# FN: 957, TP: 15298
#
# 模型已保存为: Model_XGBoost.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 3500
# 最佳迭代轮数: 14
# 最佳验证分数: 0.01244578707016103
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
