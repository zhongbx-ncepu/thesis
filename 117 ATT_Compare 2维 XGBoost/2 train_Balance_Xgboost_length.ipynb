# %%
#数据预处理
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

batch_size = 256
try_length = [200,500,1000,1500] # 模型查看的历史窗口大小
prediction_horizon = 1 # 预测的未来窗口大小

directory = "../datas/train" #数据目录
all_items = os.listdir(directory)  #列出目录下所有文件
csv_files = [os.path.join(directory, item) for item in all_items if item.endswith('.csv') and os.path.isfile(os.path.join(directory, item))]  #筛选出CSV文件 
Sample_size = len(csv_files)  #获取样本数量

sequences_data = [] #创建一个空列表，用于存储所有序列的数据
scalers = {} #创建一个空字典，用于存储每个序列对应的标准化器
base_features = ['Voltage', 'Current']
features = [ 'impedance','cumulative_power']

for file in csv_files:
    df = pd.read_csv(file)
    df['impedance'] = df['Voltage'] * 1000 / df['Current'].replace(0, np.nan)
    df['power'] = df['Voltage'] * (df['Current'] / 1000)
    df['cumulative_power'] = (df['power']/1000).cumsum()
    df['impedance_diff'] = df['impedance'].diff().fillna(0) #添加一阶差分
    df['impedance_rolling_mean'] = df['impedance'].rolling(window=20, min_periods=1).mean() #滚动均值
    df['impedance_rolling_std'] = df['impedance'].rolling(window=20, min_periods=1).std()  #滚动标准差
    df['impedance_slope_10'] = df['impedance'].diff(10) / 10  #过去 10 个时间点的平均变化率。
    df['impedance_slope_10'] = df['impedance_slope_10'].fillna(0) # 将该列中的所有缺失值（NaN）填充为数字0
    df = df.ffill().bfill()  #缺失值处理先用前向填充，再用后向填充
    #数据预处理 数值归一化
    scaler = StandardScaler() #为当前序列创建一个新的StandardScaler实例
    df.loc[:, features] = scaler.fit_transform(df.loc[:, features]) #对当前序列的指定特征列进行拟合和转换
    scalers[file] = scaler #将当前序列的标准化器保存到字典中，键为序列ID
    sequences_data.append(df[features + ['Action']].values) #将当前序列的数组数据添加到结果列表中

train_sequences, val_sequences = train_test_split(sequences_data, test_size=0.18, random_state=42)

print(f'检索到{Sample_size}个样本')
print(f"特征数量: {len(features)}")
print(f"序列数量: {len(sequences_data)}")
print(f"训练序列: {len(train_sequences)}")
print(f"验证序列: {len(val_sequences)}")
# Out:
# 检索到55个样本
# 特征数量: 2
# 序列数量: 55
# 训练序列: 45
# 验证序列: 10

# %%
import xgboost as xgb
from tqdm import tqdm

def create_xgboost_data(sequences_data, sequence_length, prediction_horizon):
    X_list = []
    y_list = []
    
    for seq_data in tqdm(sequences_data, desc="处理序列", unit="seq", ncols=60):
        n_samples = len(seq_data) - sequence_length - prediction_horizon + 1
        
        for i in range(n_samples):
            # 提取特征
            x = seq_data[i:i + sequence_length, :-1].flatten()  # 展平为1D向量
            X_list.append(x)
            
            # 提取标签
            y_window = seq_data[i + sequence_length:i + sequence_length + prediction_horizon, -1]
            y = 1 if np.any(y_window == 1) else 0
            y_list.append(y)
    
    return np.array(X_list), np.array(y_list)

# %%
# 训练模型
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
from sklearn.datasets import dump_svmlight_file
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from datetime import datetime

model_name = 'XGBoost'
num_boost_round=1000

for sequence_length in try_length:

    print(f"序列窗口长度: {sequence_length}")
    print("生成训练数据...")
    X_train, y_train = create_xgboost_data(train_sequences, sequence_length, prediction_horizon)
    X_val, y_val = create_xgboost_data(val_sequences, sequence_length, prediction_horizon)
    # 从float64转化为float32
    # X_train = X_train.astype(np.float32)
    # y_val = X_val.astype(np.float32)
    
    # 计算类别权重（处理不平衡数据）
    if np.sum(y_train) > 0:
        scale_pos_weight = (len(y_train) - np.sum(y_train)) / np.sum(y_train)
    else:
        scale_pos_weight = 1.0
        print("警告: 训练集中没有正样本!")
    
    # 定义XGBoost模型参数
    params = {
        'tree_method': 'hist',  # 使用GPU直方图算法
        'device': 'cuda',           # 指定使用CUDA设备
        'max_bin': 256,                 # 直方图分桶数，GPU上256是常用值，可在速度和精度间权衡
        'objective': 'binary:logistic',  # 根据你的问题调整
        'eval_metric': ['logloss', 'auc', 'error'],
        'learning_rate': 0.1,
        'max_depth': 6,
        'random_state': 42,
        'reg_alpha': 0.1,
        'reg_lambda': 1.0,
        'gamma': 0.1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'colsample_bylevel': 0.8,   # 每层特征采样
        'colsample_bynode': 0.8,    # 每个节点特征采样
        'scale_pos_weight': scale_pos_weight,
        'verbosity': 1,  # 新版本推荐用法
    }
    print("XGBoost模型配置完成")
    print("创建DMatrix...")
    dtrain = xgb.QuantileDMatrix(X_train, label=y_train, max_bin=params['max_bin'])
    dval = xgb.QuantileDMatrix(X_val, label=y_val, max_bin=params['max_bin'], ref=dtrain) # ref引用dtrain的分位数
    print("创建DMatrix完成")
        
    print(f"训练样本数: {len(X_train)}")
    print(f"验证样本数: {len(X_val)}")
    print(f"训练集形状: X_train {X_train.shape}, y_train {y_train.shape}")
    print(f"验证集形状: X_val {X_val.shape}, y_val {y_val.shape}")
    print(f"特征维度: {X_train.shape[1]} (序列长度{sequence_length} × 特征数{len(features)})")
    print(f"正样本比例 - 训练集: {np.mean(y_train):.4f}, 验证集: {np.mean(y_val):.4f}")
    print(f"类别权重 scale_pos_weight: {scale_pos_weight:.2f}")
    
    print("开始训练...")
    eval_history = {}
    # 使用原生接口训练
    model = xgb.train(
        params, dtrain,
        num_boost_round,
        evals=[(dtrain, 'train'),(dval, 'val')],  # 这里使用 evals
        early_stopping_rounds=50,
        evals_result=eval_history,  # 这里使用 evals_result
        verbose_eval=True
    )
    print("XGBoost模型训练完成")
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"完成时间{timestamp}")
    
    plt.figure(figsize=(12, 4))
    # 绘制logloss
    plt.subplot(1, 3, 1)
    plt.plot(eval_history['train']['logloss'], label='Train Logloss')
    plt.plot(eval_history['val']['logloss'], label='Validation Logloss')
    plt.xlabel('Iteration')
    plt.ylabel('Logloss')
    plt.title('XGBoost Training - Logloss')
    plt.legend()
    plt.grid(True)
    
    # 绘制错误率
    plt.subplot(1, 3, 2)
    plt.plot(eval_history['train']['error'], label='Train Error')
    plt.plot(eval_history['val']['error'], label='Validation Error')
    plt.xlabel('Iteration')
    plt.ylabel('Error')
    plt.title('XGBoost Training - Error')
    plt.legend()
    plt.grid(True)
    
    # 绘制错误率
    plt.subplot(1, 3, 3)
    plt.plot(eval_history['train']['auc'], label='Train auc')
    plt.plot(eval_history['val']['auc'], label='Validation auc')
    plt.xlabel('Iteration')
    plt.ylabel('Error')
    plt.title('XGBoost Training - auc')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    """
    评估XGBoost模型性能
    """
    print("\n" + "="*60)
    print("XGBoost模型评估结果")
    print("="*60)
    
    # 训练集预测
    y_train_prob = model.predict(dtrain)  # 预测概率
    y_train_pred = (y_train_prob > 0.5).astype(int)  # 转换为类别
    
    # 验证集预测
    y_val_prob = model.predict(dval)  # 预测概率
    y_val_pred = (y_val_prob > 0.5).astype(int)  # 转换为类别
    
    # 计算训练集指标
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred, zero_division=0)
    train_recall = recall_score(y_train, y_train_pred, zero_division=0)
    train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
    train_auc = roc_auc_score(y_train, y_train_prob)
    
    # 计算验证集指标
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_precision = precision_score(y_val, y_val_pred, zero_division=0)
    val_recall = recall_score(y_val, y_val_pred, zero_division=0)
    val_f1 = f1_score(y_val, y_val_pred, zero_division=0)
    val_auc = roc_auc_score(y_val, y_val_prob)
    
    # 打印结果表格
    print(f"{'指标':<12} | {'训练集':<10} | {'验证集':<10}")
    print("-" * 40)
    print(f"{'准确率':<12} | {train_accuracy:>10.4f} | {val_accuracy:>10.4f}")
    print(f"{'精确率':<12} | {train_precision:>10.4f} | {val_precision:>10.4f}")
    print(f"{'召回率':<12} | {train_recall:>10.4f} | {val_recall:>10.4f}")
    print(f"{'F1分数':<13} | {train_f1:>10.4f} | {val_f1:>10.4f}")
    print(f"{'AUC':<14} | {train_auc:>10.4f} | {val_auc:>10.4f}")
    
    # 验证集详细报告
    print(f"\n验证集详细分类报告:")
    print(classification_report(y_val, y_val_pred, target_names=['Class 0', 'Class 1']))
    
    # 混淆矩阵
    cm = confusion_matrix(y_val, y_val_pred)
    print(f"\n验证集混淆矩阵:")
    print(f"TN: {cm[0,0]}, FP: {cm[0,1]}")
    print(f"FN: {cm[1,0]}, TP: {cm[1,1]}")
    
    feature_names = [f'feature_{i}' for i in range(X_train.shape[1])]
    
    model_name=f"Model_XGBoost_L{sequence_length}.pkl"
    
    """
    保存XGBoost模型
    """
    # 准备保存的数据
    model_data = {
        'model': model,
        'feature_names': feature_names,
        'model_type': 'booster'
    }
    # 获取特征数量
    if X_train is not None:
        num_features = X_train.shape[1]
    else:
        num_features = len(feature_names)
    
    # 获取最佳迭代轮数
    best_iteration = getattr(model, 'best_iteration', '未知')
    best_score = getattr(model, 'best_score', '未知')
    
    model_data.update({
        'num_features': num_features,
        'best_iteration': best_iteration,
        'best_score': best_score
    })
    
    # 保存模型
    joblib.dump(model_data, model_name)
    print(f"\n模型已保存为: {model_name}")
    print(f"模型类型: Booster (原生接口)")
    print(f"特征数量: {model_data.get('num_features', len(feature_names))}")
    print(f"最佳迭代轮数: {best_iteration}")
    print(f"最佳验证分数: {best_score}")
    print(f"类别: [0, 1] (二分类任务)")
    print(f"\n{'='*60}")
    print("XGBoost模型训练完成!")
    print(f"{'='*60}")
# Out:
# 序列窗口长度: 200
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:02<00:00, 17.28seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 22.98seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 544072
# 验证样本数: 116211
# 训练集形状: X_train (544072, 400), y_train (544072,)
# 验证集形状: X_val (116211, 400), y_val (116211,)
# 特征维度: 400 (序列长度200 × 特征数2)
# 正样本比例 - 训练集: 0.1391, 验证集: 0.1399
# 类别权重 scale_pos_weight: 6.19
# 开始训练...
# [0]	train-logloss:0.60724	train-auc:0.99438	train-error:0.05818	val-logloss:0.60587	val-auc:0.99748	val-error:0.05583
# [1]	train-logloss:0.53641	train-auc:0.99632	train-error:0.05091	val-logloss:0.53450	val-auc:0.99845	val-error:0.05117
# [2]	train-logloss:0.47712	train-auc:0.99685	train-error:0.04127	val-logloss:0.47558	val-auc:0.99809	val-error:0.04933
# [3]	train-logloss:0.42737	train-auc:0.99712	train-error:0.03804	val-logloss:0.42568	val-auc:0.99828	val-error:0.04680
# [4]	train-logloss:0.38438	train-auc:0.99723	train-error:0.03797	val-logloss:0.38373	val-auc:0.99806	val-error:0.04798
# [5]	train-logloss:0.34748	train-auc:0.99727	train-error:0.03747	val-logloss:0.34785	val-auc:0.99799	val-error:0.04935
# [6]	train-logloss:0.31530	train-auc:0.99752	train-error:0.03787	val-logloss:0.31646	val-auc:0.99806	val-error:0.04916
# [7]	train-logloss:0.28739	train-auc:0.99768	train-error:0.03652	val-logloss:0.28898	val-auc:0.99811	val-error:0.04733
# [8]	train-logloss:0.26294	train-auc:0.99778	train-error:0.03670	val-logloss:0.26525	val-auc:0.99813	val-error:0.04763
# [9]	train-logloss:0.24111	train-auc:0.99795	train-error:0.03597	val-logloss:0.24363	val-auc:0.99822	val-error:0.04762
# [10]	train-logloss:0.22185	train-auc:0.99803	train-error:0.03544	val-logloss:0.22491	val-auc:0.99826	val-error:0.04723
# [11]	train-logloss:0.20478	train-auc:0.99810	train-error:0.03405	val-logloss:0.20790	val-auc:0.99833	val-error:0.04621
# [12]	train-logloss:0.18948	train-auc:0.99816	train-error:0.03328	val-logloss:0.19339	val-auc:0.99829	val-error:0.04503
# [13]	train-logloss:0.17552	train-auc:0.99834	train-error:0.03280	val-logloss:0.17935	val-auc:0.99836	val-error:0.04443
# [14]	train-logloss:0.16292	train-auc:0.99849	train-error:0.03128	val-logloss:0.16662	val-auc:0.99844	val-error:0.04146
# [15]	train-logloss:0.15210	train-auc:0.99854	train-error:0.03094	val-logloss:0.15642	val-auc:0.99843	val-error:0.04184
# [16]	train-logloss:0.14221	train-auc:0.99857	train-error:0.02827	val-logloss:0.14642	val-auc:0.99849	val-error:0.04028
# [17]	train-logloss:0.13325	train-auc:0.99862	train-error:0.02660	val-logloss:0.13738	val-auc:0.99856	val-error:0.03632
# [18]	train-logloss:0.12527	train-auc:0.99865	train-error:0.02618	val-logloss:0.12975	val-auc:0.99853	val-error:0.03622
# [19]	train-logloss:0.11817	train-auc:0.99867	train-error:0.02658	val-logloss:0.12278	val-auc:0.99858	val-error:0.03575
# [20]	train-logloss:0.11118	train-auc:0.99876	train-error:0.02628	val-logloss:0.11661	val-auc:0.99853	val-error:0.03595
# [21]	train-logloss:0.10522	train-auc:0.99878	train-error:0.02526	val-logloss:0.11039	val-auc:0.99857	val-error:0.03542
# [22]	train-logloss:0.09988	train-auc:0.99880	train-error:0.02544	val-logloss:0.10478	val-auc:0.99862	val-error:0.03353
# [23]	train-logloss:0.09454	train-auc:0.99888	train-error:0.02403	val-logloss:0.10026	val-auc:0.99857	val-error:0.03362
# [24]	train-logloss:0.08990	train-auc:0.99891	train-error:0.02310	val-logloss:0.09528	val-auc:0.99864	val-error:0.03367
# [25]	train-logloss:0.08567	train-auc:0.99896	train-error:0.02223	val-logloss:0.09109	val-auc:0.99868	val-error:0.03229
# [26]	train-logloss:0.08179	train-auc:0.99897	train-error:0.02163	val-logloss:0.08704	val-auc:0.99872	val-error:0.03078
# [27]	train-logloss:0.07835	train-auc:0.99900	train-error:0.02063	val-logloss:0.08349	val-auc:0.99875	val-error:0.02869
# [28]	train-logloss:0.07531	train-auc:0.99902	train-error:0.02033	val-logloss:0.08073	val-auc:0.99875	val-error:0.02865
# [29]	train-logloss:0.07250	train-auc:0.99904	train-error:0.02031	val-logloss:0.07803	val-auc:0.99877	val-error:0.02840
# [30]	train-logloss:0.06962	train-auc:0.99910	train-error:0.01977	val-logloss:0.07553	val-auc:0.99879	val-error:0.02868
# [31]	train-logloss:0.06699	train-auc:0.99914	train-error:0.01966	val-logloss:0.07330	val-auc:0.99881	val-error:0.02815
# [32]	train-logloss:0.06486	train-auc:0.99915	train-error:0.01932	val-logloss:0.07138	val-auc:0.99883	val-error:0.02780
# [33]	train-logloss:0.06290	train-auc:0.99916	train-error:0.01868	val-logloss:0.06961	val-auc:0.99881	val-error:0.02795
# [34]	train-logloss:0.06098	train-auc:0.99919	train-error:0.01828	val-logloss:0.06817	val-auc:0.99881	val-error:0.02797
# [35]	train-logloss:0.05943	train-auc:0.99920	train-error:0.01820	val-logloss:0.06690	val-auc:0.99880	val-error:0.02789
# [36]	train-logloss:0.05774	train-auc:0.99923	train-error:0.01795	val-logloss:0.06552	val-auc:0.99880	val-error:0.02760
# [37]	train-logloss:0.05646	train-auc:0.99923	train-error:0.01775	val-logloss:0.06453	val-auc:0.99880	val-error:0.02760
# [38]	train-logloss:0.05522	train-auc:0.99924	train-error:0.01769	val-logloss:0.06367	val-auc:0.99878	val-error:0.02784
# [39]	train-logloss:0.05398	train-auc:0.99926	train-error:0.01752	val-logloss:0.06260	val-auc:0.99878	val-error:0.02757
# [40]	train-logloss:0.05269	train-auc:0.99929	train-error:0.01743	val-logloss:0.06155	val-auc:0.99879	val-error:0.02755
# [41]	train-logloss:0.05181	train-auc:0.99930	train-error:0.01738	val-logloss:0.06076	val-auc:0.99880	val-error:0.02758
# [42]	train-logloss:0.05095	train-auc:0.99931	train-error:0.01734	val-logloss:0.06016	val-auc:0.99880	val-error:0.02766
# [43]	train-logloss:0.04982	train-auc:0.99935	train-error:0.01716	val-logloss:0.05949	val-auc:0.99880	val-error:0.02760
# [44]	train-logloss:0.04889	train-auc:0.99938	train-error:0.01708	val-logloss:0.05901	val-auc:0.99880	val-error:0.02771
# [45]	train-logloss:0.04815	train-auc:0.99939	train-error:0.01694	val-logloss:0.05847	val-auc:0.99878	val-error:0.02708
# [46]	train-logloss:0.04745	train-auc:0.99940	train-error:0.01689	val-logloss:0.05816	val-auc:0.99878	val-error:0.02791
# [47]	train-logloss:0.04663	train-auc:0.99943	train-error:0.01679	val-logloss:0.05778	val-auc:0.99878	val-error:0.02785
# [48]	train-logloss:0.04578	train-auc:0.99948	train-error:0.01679	val-logloss:0.05750	val-auc:0.99877	val-error:0.02791
# [49]	train-logloss:0.04505	train-auc:0.99952	train-error:0.01672	val-logloss:0.05735	val-auc:0.99877	val-error:0.02790
# [50]	train-logloss:0.04450	train-auc:0.99953	train-error:0.01666	val-logloss:0.05709	val-auc:0.99877	val-error:0.02764
# [51]	train-logloss:0.04373	train-auc:0.99955	train-error:0.01650	val-logloss:0.05639	val-auc:0.99879	val-error:0.02783
# [52]	train-logloss:0.04324	train-auc:0.99956	train-error:0.01639	val-logloss:0.05604	val-auc:0.99880	val-error:0.02792
# [53]	train-logloss:0.04278	train-auc:0.99956	train-error:0.01600	val-logloss:0.05580	val-auc:0.99880	val-error:0.02799
# [54]	train-logloss:0.04220	train-auc:0.99958	train-error:0.01571	val-logloss:0.05538	val-auc:0.99881	val-error:0.02785
# [55]	train-logloss:0.04185	train-auc:0.99958	train-error:0.01566	val-logloss:0.05519	val-auc:0.99879	val-error:0.02788
# [56]	train-logloss:0.04146	train-auc:0.99960	train-error:0.01564	val-logloss:0.05495	val-auc:0.99880	val-error:0.02760
# [57]	train-logloss:0.04118	train-auc:0.99960	train-error:0.01555	val-logloss:0.05475	val-auc:0.99879	val-error:0.02723
# [58]	train-logloss:0.04086	train-auc:0.99961	train-error:0.01545	val-logloss:0.05455	val-auc:0.99879	val-error:0.02717
# [59]	train-logloss:0.04052	train-auc:0.99962	train-error:0.01540	val-logloss:0.05433	val-auc:0.99879	val-error:0.02683
# [60]	train-logloss:0.03992	train-auc:0.99964	train-error:0.01464	val-logloss:0.05334	val-auc:0.99882	val-error:0.02516
# [61]	train-logloss:0.03936	train-auc:0.99966	train-error:0.01443	val-logloss:0.05292	val-auc:0.99883	val-error:0.02446
# [62]	train-logloss:0.03835	train-auc:0.99970	train-error:0.01395	val-logloss:0.05288	val-auc:0.99878	val-error:0.02460
# [63]	train-logloss:0.03783	train-auc:0.99973	train-error:0.01381	val-logloss:0.05252	val-auc:0.99879	val-error:0.02450
# [64]	train-logloss:0.03733	train-auc:0.99974	train-error:0.01348	val-logloss:0.05253	val-auc:0.99876	val-error:0.02456
# [65]	train-logloss:0.03706	train-auc:0.99974	train-error:0.01334	val-logloss:0.05236	val-auc:0.99876	val-error:0.02457
# [66]	train-logloss:0.03660	train-auc:0.99975	train-error:0.01326	val-logloss:0.05162	val-auc:0.99879	val-error:0.02392
# [67]	train-logloss:0.03593	train-auc:0.99976	train-error:0.01317	val-logloss:0.05115	val-auc:0.99880	val-error:0.02346
# [68]	train-logloss:0.03554	train-auc:0.99977	train-error:0.01302	val-logloss:0.05047	val-auc:0.99882	val-error:0.02273
# [69]	train-logloss:0.03510	train-auc:0.99979	train-error:0.01274	val-logloss:0.05025	val-auc:0.99883	val-error:0.02269
# [70]	train-logloss:0.03453	train-auc:0.99980	train-error:0.01242	val-logloss:0.04973	val-auc:0.99886	val-error:0.02256
# [71]	train-logloss:0.03417	train-auc:0.99981	train-error:0.01234	val-logloss:0.04910	val-auc:0.99888	val-error:0.02227
# [72]	train-logloss:0.03368	train-auc:0.99981	train-error:0.01199	val-logloss:0.04886	val-auc:0.99885	val-error:0.02209
# [73]	train-logloss:0.03335	train-auc:0.99982	train-error:0.01191	val-logloss:0.04829	val-auc:0.99888	val-error:0.02205
# [74]	train-logloss:0.03267	train-auc:0.99983	train-error:0.01185	val-logloss:0.04733	val-auc:0.99892	val-error:0.02125
# [75]	train-logloss:0.03206	train-auc:0.99984	train-error:0.01178	val-logloss:0.04691	val-auc:0.99891	val-error:0.02102
# [76]	train-logloss:0.03181	train-auc:0.99984	train-error:0.01174	val-logloss:0.04648	val-auc:0.99893	val-error:0.02100
# [77]	train-logloss:0.03158	train-auc:0.99984	train-error:0.01175	val-logloss:0.04607	val-auc:0.99895	val-error:0.02091
# [78]	train-logloss:0.03107	train-auc:0.99985	train-error:0.01174	val-logloss:0.04528	val-auc:0.99898	val-error:0.02056
# [79]	train-logloss:0.03061	train-auc:0.99985	train-error:0.01173	val-logloss:0.04479	val-auc:0.99900	val-error:0.02018
# [80]	train-logloss:0.03011	train-auc:0.99986	train-error:0.01153	val-logloss:0.04458	val-auc:0.99898	val-error:0.02018
# [81]	train-logloss:0.02956	train-auc:0.99988	train-error:0.01128	val-logloss:0.04434	val-auc:0.99897	val-error:0.02013
# [82]	train-logloss:0.02904	train-auc:0.99989	train-error:0.01097	val-logloss:0.04427	val-auc:0.99897	val-error:0.02012
# [83]	train-logloss:0.02868	train-auc:0.99989	train-error:0.01083	val-logloss:0.04418	val-auc:0.99896	val-error:0.02007
# [84]	train-logloss:0.02838	train-auc:0.99989	train-error:0.01069	val-logloss:0.04418	val-auc:0.99896	val-error:0.02008
# [85]	train-logloss:0.02801	train-auc:0.99990	train-error:0.01067	val-logloss:0.04363	val-auc:0.99898	val-error:0.01997
# [86]	train-logloss:0.02761	train-auc:0.99990	train-error:0.01043	val-logloss:0.04352	val-auc:0.99898	val-error:0.01988
# [87]	train-logloss:0.02703	train-auc:0.99992	train-error:0.01002	val-logloss:0.04320	val-auc:0.99899	val-error:0.01971
# [88]	train-logloss:0.02674	train-auc:0.99992	train-error:0.00991	val-logloss:0.04308	val-auc:0.99899	val-error:0.01969
# [89]	train-logloss:0.02637	train-auc:0.99993	train-error:0.00967	val-logloss:0.04304	val-auc:0.99899	val-error:0.01973
# [90]	train-logloss:0.02583	train-auc:0.99994	train-error:0.00927	val-logloss:0.04292	val-auc:0.99898	val-error:0.01978
# [91]	train-logloss:0.02560	train-auc:0.99994	train-error:0.00921	val-logloss:0.04295	val-auc:0.99898	val-error:0.01971
# [92]	train-logloss:0.02496	train-auc:0.99994	train-error:0.00871	val-logloss:0.04283	val-auc:0.99893	val-error:0.01931
# [93]	train-logloss:0.02474	train-auc:0.99994	train-error:0.00856	val-logloss:0.04283	val-auc:0.99893	val-error:0.01931
# [94]	train-logloss:0.02445	train-auc:0.99995	train-error:0.00834	val-logloss:0.04280	val-auc:0.99893	val-error:0.01925
# [95]	train-logloss:0.02419	train-auc:0.99995	train-error:0.00815	val-logloss:0.04279	val-auc:0.99893	val-error:0.01923
# [96]	train-logloss:0.02406	train-auc:0.99995	train-error:0.00812	val-logloss:0.04279	val-auc:0.99893	val-error:0.01925
# [97]	train-logloss:0.02387	train-auc:0.99995	train-error:0.00802	val-logloss:0.04279	val-auc:0.99893	val-error:0.01922
# [98]	train-logloss:0.02344	train-auc:0.99996	train-error:0.00764	val-logloss:0.04266	val-auc:0.99891	val-error:0.01912
# [99]	train-logloss:0.02275	train-auc:0.99996	train-error:0.00716	val-logloss:0.04244	val-auc:0.99888	val-error:0.01861
# [100]	train-logloss:0.02234	train-auc:0.99996	train-error:0.00702	val-logloss:0.04262	val-auc:0.99887	val-error:0.01879
# [101]	train-logloss:0.02203	train-auc:0.99996	train-error:0.00703	val-logloss:0.04210	val-auc:0.99890	val-error:0.01865
# [102]	train-logloss:0.02170	train-auc:0.99997	train-error:0.00681	val-logloss:0.04211	val-auc:0.99889	val-error:0.01853
# [103]	train-logloss:0.02142	train-auc:0.99997	train-error:0.00683	val-logloss:0.04170	val-auc:0.99890	val-error:0.01839
# [104]	train-logloss:0.02119	train-auc:0.99997	train-error:0.00668	val-logloss:0.04179	val-auc:0.99889	val-error:0.01859
# [105]	train-logloss:0.02105	train-auc:0.99997	train-error:0.00667	val-logloss:0.04156	val-auc:0.99890	val-error:0.01853
# [106]	train-logloss:0.02059	train-auc:0.99997	train-error:0.00641	val-logloss:0.04148	val-auc:0.99886	val-error:0.01798
# [107]	train-logloss:0.02036	train-auc:0.99997	train-error:0.00622	val-logloss:0.04144	val-auc:0.99887	val-error:0.01799
# [108]	train-logloss:0.01986	train-auc:0.99997	train-error:0.00605	val-logloss:0.04139	val-auc:0.99883	val-error:0.01756
# [109]	train-logloss:0.01967	train-auc:0.99997	train-error:0.00587	val-logloss:0.04143	val-auc:0.99883	val-error:0.01756
# [110]	train-logloss:0.01954	train-auc:0.99997	train-error:0.00587	val-logloss:0.04121	val-auc:0.99884	val-error:0.01756
# [111]	train-logloss:0.01931	train-auc:0.99998	train-error:0.00579	val-logloss:0.04118	val-auc:0.99882	val-error:0.01735
# [112]	train-logloss:0.01909	train-auc:0.99998	train-error:0.00567	val-logloss:0.04122	val-auc:0.99882	val-error:0.01736
# [113]	train-logloss:0.01884	train-auc:0.99998	train-error:0.00567	val-logloss:0.04085	val-auc:0.99883	val-error:0.01736
# [114]	train-logloss:0.01873	train-auc:0.99998	train-error:0.00567	val-logloss:0.04067	val-auc:0.99884	val-error:0.01736
# [115]	train-logloss:0.01853	train-auc:0.99998	train-error:0.00568	val-logloss:0.04031	val-auc:0.99886	val-error:0.01736
# [116]	train-logloss:0.01837	train-auc:0.99998	train-error:0.00556	val-logloss:0.04025	val-auc:0.99887	val-error:0.01736
# [117]	train-logloss:0.01827	train-auc:0.99998	train-error:0.00552	val-logloss:0.04026	val-auc:0.99887	val-error:0.01742
# [118]	train-logloss:0.01798	train-auc:0.99998	train-error:0.00538	val-logloss:0.04014	val-auc:0.99886	val-error:0.01732
# [119]	train-logloss:0.01772	train-auc:0.99998	train-error:0.00528	val-logloss:0.03997	val-auc:0.99888	val-error:0.01736
# [120]	train-logloss:0.01750	train-auc:0.99998	train-error:0.00518	val-logloss:0.04014	val-auc:0.99887	val-error:0.01735
# [121]	train-logloss:0.01733	train-auc:0.99998	train-error:0.00507	val-logloss:0.04022	val-auc:0.99887	val-error:0.01737
# [122]	train-logloss:0.01724	train-auc:0.99998	train-error:0.00507	val-logloss:0.04015	val-auc:0.99887	val-error:0.01736
# [123]	train-logloss:0.01707	train-auc:0.99998	train-error:0.00506	val-logloss:0.03984	val-auc:0.99889	val-error:0.01738
# [124]	train-logloss:0.01686	train-auc:0.99998	train-error:0.00496	val-logloss:0.03983	val-auc:0.99889	val-error:0.01743
# [125]	train-logloss:0.01671	train-auc:0.99998	train-error:0.00495	val-logloss:0.03960	val-auc:0.99891	val-error:0.01744
# [126]	train-logloss:0.01641	train-auc:0.99999	train-error:0.00494	val-logloss:0.03957	val-auc:0.99889	val-error:0.01760
# [127]	train-logloss:0.01635	train-auc:0.99999	train-error:0.00491	val-logloss:0.03967	val-auc:0.99889	val-error:0.01760
# [128]	train-logloss:0.01622	train-auc:0.99999	train-error:0.00478	val-logloss:0.03961	val-auc:0.99889	val-error:0.01756
# [129]	train-logloss:0.01614	train-auc:0.99999	train-error:0.00478	val-logloss:0.03948	val-auc:0.99889	val-error:0.01756
# [130]	train-logloss:0.01597	train-auc:0.99999	train-error:0.00469	val-logloss:0.03941	val-auc:0.99889	val-error:0.01757
# [131]	train-logloss:0.01584	train-auc:0.99999	train-error:0.00469	val-logloss:0.03922	val-auc:0.99890	val-error:0.01764
# [132]	train-logloss:0.01573	train-auc:0.99999	train-error:0.00463	val-logloss:0.03928	val-auc:0.99890	val-error:0.01775
# [133]	train-logloss:0.01549	train-auc:0.99999	train-error:0.00453	val-logloss:0.03929	val-auc:0.99890	val-error:0.01773
# [134]	train-logloss:0.01522	train-auc:0.99999	train-error:0.00448	val-logloss:0.03923	val-auc:0.99889	val-error:0.01781
# [135]	train-logloss:0.01513	train-auc:0.99999	train-error:0.00445	val-logloss:0.03929	val-auc:0.99889	val-error:0.01782
# [136]	train-logloss:0.01491	train-auc:0.99999	train-error:0.00424	val-logloss:0.03923	val-auc:0.99888	val-error:0.01808
# [137]	train-logloss:0.01477	train-auc:0.99999	train-error:0.00416	val-logloss:0.03915	val-auc:0.99888	val-error:0.01807
# [138]	train-logloss:0.01460	train-auc:0.99999	train-error:0.00410	val-logloss:0.03920	val-auc:0.99888	val-error:0.01805
# [139]	train-logloss:0.01444	train-auc:0.99999	train-error:0.00401	val-logloss:0.03918	val-auc:0.99888	val-error:0.01802
# [140]	train-logloss:0.01432	train-auc:0.99999	train-error:0.00398	val-logloss:0.03941	val-auc:0.99888	val-error:0.01817
# [141]	train-logloss:0.01404	train-auc:0.99999	train-error:0.00376	val-logloss:0.03905	val-auc:0.99888	val-error:0.01786
# [142]	train-logloss:0.01378	train-auc:0.99999	train-error:0.00361	val-logloss:0.03915	val-auc:0.99888	val-error:0.01787
# [143]	train-logloss:0.01362	train-auc:0.99999	train-error:0.00346	val-logloss:0.03910	val-auc:0.99887	val-error:0.01778
# [144]	train-logloss:0.01352	train-auc:0.99999	train-error:0.00347	val-logloss:0.03893	val-auc:0.99888	val-error:0.01786
# [145]	train-logloss:0.01346	train-auc:0.99999	train-error:0.00347	val-logloss:0.03882	val-auc:0.99889	val-error:0.01786
# [146]	train-logloss:0.01340	train-auc:0.99999	train-error:0.00346	val-logloss:0.03864	val-auc:0.99890	val-error:0.01770
# [147]	train-logloss:0.01321	train-auc:0.99999	train-error:0.00341	val-logloss:0.03856	val-auc:0.99890	val-error:0.01763
# [148]	train-logloss:0.01315	train-auc:0.99999	train-error:0.00340	val-logloss:0.03846	val-auc:0.99890	val-error:0.01763
# [149]	train-logloss:0.01309	train-auc:0.99999	train-error:0.00338	val-logloss:0.03847	val-auc:0.99890	val-error:0.01754
# [150]	train-logloss:0.01279	train-auc:0.99999	train-error:0.00325	val-logloss:0.03850	val-auc:0.99890	val-error:0.01759
# [151]	train-logloss:0.01267	train-auc:0.99999	train-error:0.00321	val-logloss:0.03852	val-auc:0.99889	val-error:0.01762
# [152]	train-logloss:0.01257	train-auc:0.99999	train-error:0.00319	val-logloss:0.03835	val-auc:0.99890	val-error:0.01753
# [153]	train-logloss:0.01250	train-auc:0.99999	train-error:0.00317	val-logloss:0.03852	val-auc:0.99889	val-error:0.01753
# [154]	train-logloss:0.01232	train-auc:0.99999	train-error:0.00304	val-logloss:0.03851	val-auc:0.99889	val-error:0.01757
# [155]	train-logloss:0.01205	train-auc:0.99999	train-error:0.00294	val-logloss:0.03863	val-auc:0.99887	val-error:0.01749
# [156]	train-logloss:0.01182	train-auc:1.00000	train-error:0.00280	val-logloss:0.03846	val-auc:0.99886	val-error:0.01756
# [157]	train-logloss:0.01177	train-auc:1.00000	train-error:0.00281	val-logloss:0.03837	val-auc:0.99887	val-error:0.01756
# [158]	train-logloss:0.01151	train-auc:1.00000	train-error:0.00273	val-logloss:0.03821	val-auc:0.99888	val-error:0.01746
# [159]	train-logloss:0.01138	train-auc:1.00000	train-error:0.00264	val-logloss:0.03825	val-auc:0.99888	val-error:0.01744
# [160]	train-logloss:0.01123	train-auc:1.00000	train-error:0.00255	val-logloss:0.03823	val-auc:0.99888	val-error:0.01744
# [161]	train-logloss:0.01108	train-auc:1.00000	train-error:0.00253	val-logloss:0.03823	val-auc:0.99886	val-error:0.01739
# [162]	train-logloss:0.01098	train-auc:1.00000	train-error:0.00253	val-logloss:0.03804	val-auc:0.99887	val-error:0.01741
# [163]	train-logloss:0.01076	train-auc:1.00000	train-error:0.00244	val-logloss:0.03778	val-auc:0.99889	val-error:0.01743
# [164]	train-logloss:0.01052	train-auc:1.00000	train-error:0.00232	val-logloss:0.03792	val-auc:0.99887	val-error:0.01748
# [165]	train-logloss:0.01044	train-auc:1.00000	train-error:0.00232	val-logloss:0.03778	val-auc:0.99888	val-error:0.01752
# [166]	train-logloss:0.01021	train-auc:1.00000	train-error:0.00225	val-logloss:0.03791	val-auc:0.99886	val-error:0.01746
# [167]	train-logloss:0.01014	train-auc:1.00000	train-error:0.00224	val-logloss:0.03777	val-auc:0.99887	val-error:0.01738
# [168]	train-logloss:0.00993	train-auc:1.00000	train-error:0.00207	val-logloss:0.03780	val-auc:0.99887	val-error:0.01749
# XGBoost模型训练完成
# 完成时间20251213_072410
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9979 |     0.9825
# 精确率          |     0.9854 |     0.9097
# 召回率          |     1.0000 |     0.9714
# F1分数          |     0.9926 |     0.9395
# AUC            |     1.0000 |     0.9989
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.98      0.99     99956
#      Class 1       0.91      0.97      0.94     16255
#
#     accuracy                           0.98    116211
#    macro avg       0.95      0.98      0.96    116211
# weighted avg       0.98      0.98      0.98    116211
#
#
# 验证集混淆矩阵:
# TN: 98388, FP: 1568
# FN: 465, TP: 15790
#
# 模型已保存为: Model_XGBoost_L200.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 400
# 最佳迭代轮数: 118
# 最佳验证分数: 0.01732194026383045
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
# 序列窗口长度: 500
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:03<00:00, 12.52seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 17.95seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 530572
# 验证样本数: 113211
# 训练集形状: X_train (530572, 1000), y_train (530572,)
# 验证集形状: X_val (113211, 1000), y_val (113211,)
# 特征维度: 1000 (序列长度500 × 特征数2)
# 正样本比例 - 训练集: 0.1427, 验证集: 0.1436
# 类别权重 scale_pos_weight: 6.01
# 开始训练...
# [0]	train-logloss:0.60491	train-auc:0.99586	train-error:0.03574	val-logloss:0.60536	val-auc:0.99730	val-error:0.04010
# [1]	train-logloss:0.53271	train-auc:0.99731	train-error:0.02640	val-logloss:0.53355	val-auc:0.99729	val-error:0.03504
# [2]	train-logloss:0.47242	train-auc:0.99783	train-error:0.03104	val-logloss:0.47329	val-auc:0.99507	val-error:0.03814
# [3]	train-logloss:0.42137	train-auc:0.99821	train-error:0.02749	val-logloss:0.42180	val-auc:0.99415	val-error:0.03733
# [4]	train-logloss:0.37789	train-auc:0.99837	train-error:0.02784	val-logloss:0.37933	val-auc:0.99807	val-error:0.03668
# [5]	train-logloss:0.33997	train-auc:0.99845	train-error:0.02757	val-logloss:0.34238	val-auc:0.99793	val-error:0.03847
# [6]	train-logloss:0.30638	train-auc:0.99862	train-error:0.02518	val-logloss:0.30830	val-auc:0.99810	val-error:0.03464
# [7]	train-logloss:0.27752	train-auc:0.99876	train-error:0.02435	val-logloss:0.27972	val-auc:0.99811	val-error:0.03452
# [8]	train-logloss:0.25180	train-auc:0.99888	train-error:0.02210	val-logloss:0.25352	val-auc:0.99818	val-error:0.02713
# [9]	train-logloss:0.22912	train-auc:0.99889	train-error:0.02137	val-logloss:0.23095	val-auc:0.99806	val-error:0.02847
# [10]	train-logloss:0.20911	train-auc:0.99893	train-error:0.02056	val-logloss:0.21066	val-auc:0.99671	val-error:0.02573
# [11]	train-logloss:0.19131	train-auc:0.99896	train-error:0.01862	val-logloss:0.19310	val-auc:0.99666	val-error:0.02231
# [12]	train-logloss:0.17549	train-auc:0.99899	train-error:0.01823	val-logloss:0.17717	val-auc:0.99655	val-error:0.02195
# [13]	train-logloss:0.16149	train-auc:0.99909	train-error:0.01855	val-logloss:0.16426	val-auc:0.99652	val-error:0.02269
# [14]	train-logloss:0.14872	train-auc:0.99910	train-error:0.01743	val-logloss:0.15130	val-auc:0.99586	val-error:0.02011
# [15]	train-logloss:0.13750	train-auc:0.99915	train-error:0.01772	val-logloss:0.14043	val-auc:0.99652	val-error:0.02103
# [16]	train-logloss:0.12692	train-auc:0.99924	train-error:0.01686	val-logloss:0.12915	val-auc:0.99681	val-error:0.01917
# [17]	train-logloss:0.11731	train-auc:0.99931	train-error:0.01631	val-logloss:0.11952	val-auc:0.99838	val-error:0.01820
# [18]	train-logloss:0.10918	train-auc:0.99931	train-error:0.01598	val-logloss:0.11093	val-auc:0.99840	val-error:0.01730
# [19]	train-logloss:0.10150	train-auc:0.99936	train-error:0.01597	val-logloss:0.10322	val-auc:0.99847	val-error:0.01737
# [20]	train-logloss:0.09482	train-auc:0.99935	train-error:0.01547	val-logloss:0.09634	val-auc:0.99849	val-error:0.01676
# [21]	train-logloss:0.08811	train-auc:0.99945	train-error:0.01531	val-logloss:0.08973	val-auc:0.99862	val-error:0.01692
# [22]	train-logloss:0.08229	train-auc:0.99951	train-error:0.01500	val-logloss:0.08382	val-auc:0.99871	val-error:0.01656
# [23]	train-logloss:0.07722	train-auc:0.99952	train-error:0.01469	val-logloss:0.07867	val-auc:0.99871	val-error:0.01584
# [24]	train-logloss:0.07263	train-auc:0.99954	train-error:0.01459	val-logloss:0.07387	val-auc:0.99879	val-error:0.01583
# [25]	train-logloss:0.06861	train-auc:0.99956	train-error:0.01445	val-logloss:0.06953	val-auc:0.99884	val-error:0.01513
# [26]	train-logloss:0.06477	train-auc:0.99957	train-error:0.01430	val-logloss:0.06592	val-auc:0.99887	val-error:0.01525
# [27]	train-logloss:0.06115	train-auc:0.99962	train-error:0.01394	val-logloss:0.06233	val-auc:0.99892	val-error:0.01503
# [28]	train-logloss:0.05804	train-auc:0.99965	train-error:0.01399	val-logloss:0.05930	val-auc:0.99895	val-error:0.01484
# [29]	train-logloss:0.05519	train-auc:0.99970	train-error:0.01384	val-logloss:0.05641	val-auc:0.99899	val-error:0.01485
# [30]	train-logloss:0.05245	train-auc:0.99972	train-error:0.01359	val-logloss:0.05402	val-auc:0.99897	val-error:0.01462
# [31]	train-logloss:0.05002	train-auc:0.99973	train-error:0.01323	val-logloss:0.05198	val-auc:0.99897	val-error:0.01447
# [32]	train-logloss:0.04784	train-auc:0.99975	train-error:0.01321	val-logloss:0.04997	val-auc:0.99897	val-error:0.01436
# [33]	train-logloss:0.04571	train-auc:0.99977	train-error:0.01277	val-logloss:0.04834	val-auc:0.99896	val-error:0.01456
# [34]	train-logloss:0.04372	train-auc:0.99981	train-error:0.01272	val-logloss:0.04619	val-auc:0.99903	val-error:0.01456
# [35]	train-logloss:0.04190	train-auc:0.99982	train-error:0.01220	val-logloss:0.04475	val-auc:0.99903	val-error:0.01457
# [36]	train-logloss:0.04021	train-auc:0.99983	train-error:0.01197	val-logloss:0.04345	val-auc:0.99903	val-error:0.01450
# [37]	train-logloss:0.03868	train-auc:0.99985	train-error:0.01181	val-logloss:0.04229	val-auc:0.99903	val-error:0.01459
# [38]	train-logloss:0.03736	train-auc:0.99985	train-error:0.01160	val-logloss:0.04109	val-auc:0.99904	val-error:0.01450
# [39]	train-logloss:0.03617	train-auc:0.99986	train-error:0.01162	val-logloss:0.04025	val-auc:0.99902	val-error:0.01453
# [40]	train-logloss:0.03474	train-auc:0.99988	train-error:0.01133	val-logloss:0.03934	val-auc:0.99904	val-error:0.01458
# [41]	train-logloss:0.03376	train-auc:0.99988	train-error:0.01117	val-logloss:0.03867	val-auc:0.99902	val-error:0.01458
# [42]	train-logloss:0.03275	train-auc:0.99989	train-error:0.01101	val-logloss:0.03805	val-auc:0.99903	val-error:0.01458
# [43]	train-logloss:0.03169	train-auc:0.99989	train-error:0.01083	val-logloss:0.03722	val-auc:0.99904	val-error:0.01449
# [44]	train-logloss:0.03082	train-auc:0.99990	train-error:0.01052	val-logloss:0.03681	val-auc:0.99903	val-error:0.01450
# [45]	train-logloss:0.03008	train-auc:0.99990	train-error:0.01040	val-logloss:0.03636	val-auc:0.99903	val-error:0.01462
# [46]	train-logloss:0.02943	train-auc:0.99990	train-error:0.01035	val-logloss:0.03549	val-auc:0.99904	val-error:0.01445
# [47]	train-logloss:0.02866	train-auc:0.99990	train-error:0.01025	val-logloss:0.03492	val-auc:0.99906	val-error:0.01402
# [48]	train-logloss:0.02806	train-auc:0.99990	train-error:0.01011	val-logloss:0.03464	val-auc:0.99905	val-error:0.01406
# [49]	train-logloss:0.02732	train-auc:0.99991	train-error:0.00974	val-logloss:0.03426	val-auc:0.99905	val-error:0.01406
# [50]	train-logloss:0.02668	train-auc:0.99992	train-error:0.00960	val-logloss:0.03401	val-auc:0.99904	val-error:0.01408
# [51]	train-logloss:0.02616	train-auc:0.99992	train-error:0.00943	val-logloss:0.03393	val-auc:0.99902	val-error:0.01408
# [52]	train-logloss:0.02576	train-auc:0.99992	train-error:0.00941	val-logloss:0.03360	val-auc:0.99902	val-error:0.01408
# [53]	train-logloss:0.02502	train-auc:0.99993	train-error:0.00927	val-logloss:0.03335	val-auc:0.99902	val-error:0.01411
# [54]	train-logloss:0.02430	train-auc:0.99993	train-error:0.00921	val-logloss:0.03302	val-auc:0.99902	val-error:0.01408
# [55]	train-logloss:0.02362	train-auc:0.99994	train-error:0.00898	val-logloss:0.03267	val-auc:0.99904	val-error:0.01425
# [56]	train-logloss:0.02328	train-auc:0.99994	train-error:0.00884	val-logloss:0.03263	val-auc:0.99902	val-error:0.01425
# [57]	train-logloss:0.02268	train-auc:0.99995	train-error:0.00858	val-logloss:0.03238	val-auc:0.99903	val-error:0.01424
# [58]	train-logloss:0.02234	train-auc:0.99995	train-error:0.00844	val-logloss:0.03234	val-auc:0.99901	val-error:0.01427
# [59]	train-logloss:0.02205	train-auc:0.99995	train-error:0.00844	val-logloss:0.03227	val-auc:0.99900	val-error:0.01427
# [60]	train-logloss:0.02170	train-auc:0.99995	train-error:0.00833	val-logloss:0.03228	val-auc:0.99898	val-error:0.01428
# [61]	train-logloss:0.02130	train-auc:0.99996	train-error:0.00823	val-logloss:0.03182	val-auc:0.99901	val-error:0.01416
# [62]	train-logloss:0.02084	train-auc:0.99996	train-error:0.00810	val-logloss:0.03164	val-auc:0.99900	val-error:0.01416
# [63]	train-logloss:0.02053	train-auc:0.99996	train-error:0.00795	val-logloss:0.03158	val-auc:0.99900	val-error:0.01415
# [64]	train-logloss:0.02026	train-auc:0.99996	train-error:0.00787	val-logloss:0.03165	val-auc:0.99898	val-error:0.01422
# [65]	train-logloss:0.01974	train-auc:0.99997	train-error:0.00767	val-logloss:0.03153	val-auc:0.99898	val-error:0.01432
# [66]	train-logloss:0.01951	train-auc:0.99997	train-error:0.00764	val-logloss:0.03138	val-auc:0.99899	val-error:0.01432
# [67]	train-logloss:0.01919	train-auc:0.99997	train-error:0.00741	val-logloss:0.03138	val-auc:0.99898	val-error:0.01435
# [68]	train-logloss:0.01867	train-auc:0.99997	train-error:0.00707	val-logloss:0.03136	val-auc:0.99898	val-error:0.01420
# [69]	train-logloss:0.01843	train-auc:0.99998	train-error:0.00697	val-logloss:0.03132	val-auc:0.99898	val-error:0.01420
# [70]	train-logloss:0.01826	train-auc:0.99998	train-error:0.00695	val-logloss:0.03138	val-auc:0.99896	val-error:0.01419
# [71]	train-logloss:0.01786	train-auc:0.99998	train-error:0.00686	val-logloss:0.03125	val-auc:0.99896	val-error:0.01419
# [72]	train-logloss:0.01753	train-auc:0.99998	train-error:0.00679	val-logloss:0.03098	val-auc:0.99898	val-error:0.01419
# [73]	train-logloss:0.01704	train-auc:0.99998	train-error:0.00641	val-logloss:0.03095	val-auc:0.99898	val-error:0.01419
# [74]	train-logloss:0.01672	train-auc:0.99998	train-error:0.00621	val-logloss:0.03103	val-auc:0.99896	val-error:0.01417
# [75]	train-logloss:0.01626	train-auc:0.99998	train-error:0.00603	val-logloss:0.03099	val-auc:0.99897	val-error:0.01418
# [76]	train-logloss:0.01573	train-auc:0.99999	train-error:0.00553	val-logloss:0.03115	val-auc:0.99896	val-error:0.01412
# [77]	train-logloss:0.01537	train-auc:0.99999	train-error:0.00532	val-logloss:0.03106	val-auc:0.99895	val-error:0.01407
# [78]	train-logloss:0.01510	train-auc:0.99999	train-error:0.00522	val-logloss:0.03126	val-auc:0.99892	val-error:0.01406
# [79]	train-logloss:0.01474	train-auc:0.99999	train-error:0.00501	val-logloss:0.03117	val-auc:0.99891	val-error:0.01404
# [80]	train-logloss:0.01429	train-auc:0.99999	train-error:0.00482	val-logloss:0.03125	val-auc:0.99891	val-error:0.01404
# [81]	train-logloss:0.01415	train-auc:0.99999	train-error:0.00476	val-logloss:0.03138	val-auc:0.99889	val-error:0.01395
# [82]	train-logloss:0.01400	train-auc:0.99999	train-error:0.00469	val-logloss:0.03159	val-auc:0.99888	val-error:0.01397
# [83]	train-logloss:0.01365	train-auc:0.99999	train-error:0.00455	val-logloss:0.03168	val-auc:0.99888	val-error:0.01397
# [84]	train-logloss:0.01340	train-auc:0.99999	train-error:0.00438	val-logloss:0.03167	val-auc:0.99888	val-error:0.01392
# [85]	train-logloss:0.01293	train-auc:0.99999	train-error:0.00415	val-logloss:0.03173	val-auc:0.99888	val-error:0.01422
# [86]	train-logloss:0.01277	train-auc:0.99999	train-error:0.00406	val-logloss:0.03175	val-auc:0.99888	val-error:0.01422
# [87]	train-logloss:0.01222	train-auc:1.00000	train-error:0.00355	val-logloss:0.03161	val-auc:0.99889	val-error:0.01412
# [88]	train-logloss:0.01208	train-auc:1.00000	train-error:0.00350	val-logloss:0.03185	val-auc:0.99886	val-error:0.01414
# [89]	train-logloss:0.01190	train-auc:1.00000	train-error:0.00337	val-logloss:0.03180	val-auc:0.99885	val-error:0.01403
# [90]	train-logloss:0.01176	train-auc:1.00000	train-error:0.00328	val-logloss:0.03178	val-auc:0.99886	val-error:0.01401
# [91]	train-logloss:0.01162	train-auc:1.00000	train-error:0.00316	val-logloss:0.03180	val-auc:0.99886	val-error:0.01404
# [92]	train-logloss:0.01151	train-auc:1.00000	train-error:0.00313	val-logloss:0.03205	val-auc:0.99883	val-error:0.01401
# [93]	train-logloss:0.01138	train-auc:1.00000	train-error:0.00312	val-logloss:0.03189	val-auc:0.99885	val-error:0.01400
# [94]	train-logloss:0.01099	train-auc:1.00000	train-error:0.00283	val-logloss:0.03216	val-auc:0.99882	val-error:0.01434
# [95]	train-logloss:0.01072	train-auc:1.00000	train-error:0.00261	val-logloss:0.03228	val-auc:0.99882	val-error:0.01442
# [96]	train-logloss:0.01062	train-auc:1.00000	train-error:0.00260	val-logloss:0.03245	val-auc:0.99880	val-error:0.01443
# [97]	train-logloss:0.01016	train-auc:1.00000	train-error:0.00234	val-logloss:0.03258	val-auc:0.99880	val-error:0.01456
# [98]	train-logloss:0.00988	train-auc:1.00000	train-error:0.00220	val-logloss:0.03257	val-auc:0.99879	val-error:0.01450
# [99]	train-logloss:0.00970	train-auc:1.00000	train-error:0.00213	val-logloss:0.03240	val-auc:0.99879	val-error:0.01446
# [100]	train-logloss:0.00960	train-auc:1.00000	train-error:0.00211	val-logloss:0.03238	val-auc:0.99878	val-error:0.01444
# [101]	train-logloss:0.00949	train-auc:1.00000	train-error:0.00206	val-logloss:0.03241	val-auc:0.99879	val-error:0.01447
# [102]	train-logloss:0.00939	train-auc:1.00000	train-error:0.00200	val-logloss:0.03239	val-auc:0.99879	val-error:0.01447
# [103]	train-logloss:0.00906	train-auc:1.00000	train-error:0.00191	val-logloss:0.03243	val-auc:0.99880	val-error:0.01449
# [104]	train-logloss:0.00877	train-auc:1.00000	train-error:0.00173	val-logloss:0.03222	val-auc:0.99880	val-error:0.01447
# [105]	train-logloss:0.00869	train-auc:1.00000	train-error:0.00171	val-logloss:0.03234	val-auc:0.99878	val-error:0.01450
# [106]	train-logloss:0.00860	train-auc:1.00000	train-error:0.00170	val-logloss:0.03224	val-auc:0.99880	val-error:0.01448
# [107]	train-logloss:0.00827	train-auc:1.00000	train-error:0.00147	val-logloss:0.03233	val-auc:0.99878	val-error:0.01439
# [108]	train-logloss:0.00820	train-auc:1.00000	train-error:0.00148	val-logloss:0.03257	val-auc:0.99876	val-error:0.01443
# [109]	train-logloss:0.00792	train-auc:1.00000	train-error:0.00128	val-logloss:0.03265	val-auc:0.99876	val-error:0.01457
# [110]	train-logloss:0.00779	train-auc:1.00000	train-error:0.00124	val-logloss:0.03279	val-auc:0.99875	val-error:0.01472
# [111]	train-logloss:0.00772	train-auc:1.00000	train-error:0.00124	val-logloss:0.03269	val-auc:0.99877	val-error:0.01472
# [112]	train-logloss:0.00764	train-auc:1.00000	train-error:0.00122	val-logloss:0.03290	val-auc:0.99875	val-error:0.01479
# [113]	train-logloss:0.00735	train-auc:1.00000	train-error:0.00111	val-logloss:0.03286	val-auc:0.99875	val-error:0.01469
# [114]	train-logloss:0.00725	train-auc:1.00000	train-error:0.00109	val-logloss:0.03285	val-auc:0.99875	val-error:0.01471
# [115]	train-logloss:0.00719	train-auc:1.00000	train-error:0.00107	val-logloss:0.03284	val-auc:0.99876	val-error:0.01463
# [116]	train-logloss:0.00695	train-auc:1.00000	train-error:0.00093	val-logloss:0.03306	val-auc:0.99876	val-error:0.01478
# [117]	train-logloss:0.00688	train-auc:1.00000	train-error:0.00092	val-logloss:0.03298	val-auc:0.99877	val-error:0.01479
# [118]	train-logloss:0.00666	train-auc:1.00000	train-error:0.00085	val-logloss:0.03327	val-auc:0.99875	val-error:0.01457
# [119]	train-logloss:0.00658	train-auc:1.00000	train-error:0.00084	val-logloss:0.03326	val-auc:0.99875	val-error:0.01456
# [120]	train-logloss:0.00651	train-auc:1.00000	train-error:0.00082	val-logloss:0.03346	val-auc:0.99872	val-error:0.01455
# [121]	train-logloss:0.00632	train-auc:1.00000	train-error:0.00077	val-logloss:0.03375	val-auc:0.99870	val-error:0.01462
# [122]	train-logloss:0.00618	train-auc:1.00000	train-error:0.00074	val-logloss:0.03371	val-auc:0.99869	val-error:0.01452
# [123]	train-logloss:0.00611	train-auc:1.00000	train-error:0.00072	val-logloss:0.03374	val-auc:0.99869	val-error:0.01457
# [124]	train-logloss:0.00605	train-auc:1.00000	train-error:0.00071	val-logloss:0.03367	val-auc:0.99871	val-error:0.01455
# [125]	train-logloss:0.00599	train-auc:1.00000	train-error:0.00071	val-logloss:0.03367	val-auc:0.99871	val-error:0.01453
# [126]	train-logloss:0.00583	train-auc:1.00000	train-error:0.00065	val-logloss:0.03372	val-auc:0.99870	val-error:0.01431
# [127]	train-logloss:0.00565	train-auc:1.00000	train-error:0.00064	val-logloss:0.03373	val-auc:0.99870	val-error:0.01442
# [128]	train-logloss:0.00548	train-auc:1.00000	train-error:0.00054	val-logloss:0.03404	val-auc:0.99868	val-error:0.01459
# [129]	train-logloss:0.00529	train-auc:1.00000	train-error:0.00050	val-logloss:0.03421	val-auc:0.99868	val-error:0.01474
# [130]	train-logloss:0.00513	train-auc:1.00000	train-error:0.00047	val-logloss:0.03421	val-auc:0.99869	val-error:0.01486
# [131]	train-logloss:0.00503	train-auc:1.00000	train-error:0.00046	val-logloss:0.03433	val-auc:0.99868	val-error:0.01491
# [132]	train-logloss:0.00497	train-auc:1.00000	train-error:0.00046	val-logloss:0.03437	val-auc:0.99868	val-error:0.01491
# [133]	train-logloss:0.00487	train-auc:1.00000	train-error:0.00046	val-logloss:0.03432	val-auc:0.99868	val-error:0.01496
# [134]	train-logloss:0.00474	train-auc:1.00000	train-error:0.00042	val-logloss:0.03424	val-auc:0.99868	val-error:0.01491
# XGBoost模型训练完成
# 完成时间20251213_072422
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9996 |     0.9851
# 精确率          |     0.9971 |     0.9500
# 召回率          |     1.0000 |     0.9459
# F1分数          |     0.9985 |     0.9480
# AUC            |     1.0000 |     0.9987
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99     96956
#      Class 1       0.95      0.95      0.95     16255
#
#     accuracy                           0.99    113211
#    macro avg       0.97      0.97      0.97    113211
# weighted avg       0.99      0.99      0.99    113211
#
#
# 验证集混淆矩阵:
# TN: 96147, FP: 809
# FN: 879, TP: 15376
#
# 模型已保存为: Model_XGBoost_L500.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 1000
# 最佳迭代轮数: 84
# 最佳验证分数: 0.01392090874561659
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
# 序列窗口长度: 1000
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:04<00:00,  9.37seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 13.52seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 508072
# 验证样本数: 108211
# 训练集形状: X_train (508072, 2000), y_train (508072,)
# 验证集形状: X_val (108211, 2000), y_val (108211,)
# 特征维度: 2000 (序列长度1000 × 特征数2)
# 正样本比例 - 训练集: 0.1490, 验证集: 0.1502
# 类别权重 scale_pos_weight: 5.71
# 开始训练...
# [0]	train-logloss:0.60391	train-auc:0.99568	train-error:0.02909	val-logloss:0.60437	val-auc:0.99473	val-error:0.02790
# [1]	train-logloss:0.53054	train-auc:0.99727	train-error:0.02374	val-logloss:0.53175	val-auc:0.99642	val-error:0.02729
# [2]	train-logloss:0.46929	train-auc:0.99812	train-error:0.02618	val-logloss:0.47106	val-auc:0.99692	val-error:0.02689
# [3]	train-logloss:0.41717	train-auc:0.99838	train-error:0.02277	val-logloss:0.41943	val-auc:0.99792	val-error:0.02381
# [4]	train-logloss:0.37308	train-auc:0.99843	train-error:0.02036	val-logloss:0.37552	val-auc:0.99781	val-error:0.02457
# [5]	train-logloss:0.33386	train-auc:0.99886	train-error:0.01857	val-logloss:0.33606	val-auc:0.99839	val-error:0.02301
# [6]	train-logloss:0.29939	train-auc:0.99905	train-error:0.01728	val-logloss:0.30280	val-auc:0.99829	val-error:0.02116
# [7]	train-logloss:0.26962	train-auc:0.99909	train-error:0.01602	val-logloss:0.27366	val-auc:0.99840	val-error:0.02160
# [8]	train-logloss:0.24339	train-auc:0.99918	train-error:0.01425	val-logloss:0.24683	val-auc:0.99887	val-error:0.01970
# [9]	train-logloss:0.22029	train-auc:0.99929	train-error:0.01333	val-logloss:0.22359	val-auc:0.99895	val-error:0.01881
# [10]	train-logloss:0.20017	train-auc:0.99932	train-error:0.01369	val-logloss:0.20390	val-auc:0.99890	val-error:0.01854
# [11]	train-logloss:0.18224	train-auc:0.99937	train-error:0.01312	val-logloss:0.18619	val-auc:0.99888	val-error:0.01852
# [12]	train-logloss:0.16600	train-auc:0.99945	train-error:0.01334	val-logloss:0.17022	val-auc:0.99889	val-error:0.01870
# [13]	train-logloss:0.15175	train-auc:0.99947	train-error:0.01342	val-logloss:0.15601	val-auc:0.99888	val-error:0.01627
# [14]	train-logloss:0.13896	train-auc:0.99951	train-error:0.01312	val-logloss:0.14337	val-auc:0.99895	val-error:0.01652
# [15]	train-logloss:0.12713	train-auc:0.99959	train-error:0.01258	val-logloss:0.13178	val-auc:0.99902	val-error:0.01621
# [16]	train-logloss:0.11672	train-auc:0.99963	train-error:0.01183	val-logloss:0.12150	val-auc:0.99899	val-error:0.01644
# [17]	train-logloss:0.10734	train-auc:0.99970	train-error:0.01179	val-logloss:0.11199	val-auc:0.99910	val-error:0.01569
# [18]	train-logloss:0.09905	train-auc:0.99970	train-error:0.01144	val-logloss:0.10380	val-auc:0.99910	val-error:0.01527
# [19]	train-logloss:0.09159	train-auc:0.99971	train-error:0.01128	val-logloss:0.09644	val-auc:0.99914	val-error:0.01542
# [20]	train-logloss:0.08427	train-auc:0.99977	train-error:0.01093	val-logloss:0.08919	val-auc:0.99920	val-error:0.01515
# [21]	train-logloss:0.07822	train-auc:0.99977	train-error:0.01060	val-logloss:0.08342	val-auc:0.99917	val-error:0.01474
# [22]	train-logloss:0.07221	train-auc:0.99980	train-error:0.01029	val-logloss:0.07779	val-auc:0.99919	val-error:0.01430
# [23]	train-logloss:0.06699	train-auc:0.99981	train-error:0.00985	val-logloss:0.07262	val-auc:0.99922	val-error:0.01403
# [24]	train-logloss:0.06234	train-auc:0.99983	train-error:0.00949	val-logloss:0.06817	val-auc:0.99923	val-error:0.01387
# [25]	train-logloss:0.05830	train-auc:0.99983	train-error:0.00921	val-logloss:0.06393	val-auc:0.99926	val-error:0.01360
# [26]	train-logloss:0.05438	train-auc:0.99985	train-error:0.00919	val-logloss:0.06017	val-auc:0.99928	val-error:0.01332
# [27]	train-logloss:0.05082	train-auc:0.99986	train-error:0.00880	val-logloss:0.05714	val-auc:0.99926	val-error:0.01304
# [28]	train-logloss:0.04767	train-auc:0.99986	train-error:0.00861	val-logloss:0.05419	val-auc:0.99927	val-error:0.01271
# [29]	train-logloss:0.04482	train-auc:0.99987	train-error:0.00850	val-logloss:0.05122	val-auc:0.99927	val-error:0.01245
# [30]	train-logloss:0.04212	train-auc:0.99990	train-error:0.00833	val-logloss:0.04839	val-auc:0.99931	val-error:0.01201
# [31]	train-logloss:0.03966	train-auc:0.99991	train-error:0.00811	val-logloss:0.04600	val-auc:0.99933	val-error:0.01134
# [32]	train-logloss:0.03754	train-auc:0.99992	train-error:0.00795	val-logloss:0.04386	val-auc:0.99933	val-error:0.01064
# [33]	train-logloss:0.03545	train-auc:0.99992	train-error:0.00766	val-logloss:0.04187	val-auc:0.99935	val-error:0.01083
# [34]	train-logloss:0.03367	train-auc:0.99992	train-error:0.00766	val-logloss:0.04014	val-auc:0.99934	val-error:0.01064
# [35]	train-logloss:0.03168	train-auc:0.99994	train-error:0.00724	val-logloss:0.03859	val-auc:0.99935	val-error:0.01005
# [36]	train-logloss:0.03002	train-auc:0.99995	train-error:0.00710	val-logloss:0.03701	val-auc:0.99938	val-error:0.01020
# [37]	train-logloss:0.02856	train-auc:0.99995	train-error:0.00690	val-logloss:0.03575	val-auc:0.99937	val-error:0.01089
# [38]	train-logloss:0.02733	train-auc:0.99996	train-error:0.00680	val-logloss:0.03461	val-auc:0.99937	val-error:0.01151
# [39]	train-logloss:0.02612	train-auc:0.99996	train-error:0.00659	val-logloss:0.03360	val-auc:0.99937	val-error:0.01112
# [40]	train-logloss:0.02492	train-auc:0.99996	train-error:0.00651	val-logloss:0.03250	val-auc:0.99938	val-error:0.01082
# [41]	train-logloss:0.02378	train-auc:0.99997	train-error:0.00634	val-logloss:0.03167	val-auc:0.99939	val-error:0.01053
# [42]	train-logloss:0.02284	train-auc:0.99997	train-error:0.00612	val-logloss:0.03084	val-auc:0.99939	val-error:0.01024
# [43]	train-logloss:0.02192	train-auc:0.99997	train-error:0.00598	val-logloss:0.02998	val-auc:0.99941	val-error:0.00969
# [44]	train-logloss:0.02086	train-auc:0.99997	train-error:0.00581	val-logloss:0.02926	val-auc:0.99942	val-error:0.00930
# [45]	train-logloss:0.02017	train-auc:0.99998	train-error:0.00573	val-logloss:0.02874	val-auc:0.99941	val-error:0.00984
# [46]	train-logloss:0.01934	train-auc:0.99998	train-error:0.00538	val-logloss:0.02807	val-auc:0.99942	val-error:0.01006
# [47]	train-logloss:0.01848	train-auc:0.99998	train-error:0.00513	val-logloss:0.02755	val-auc:0.99943	val-error:0.00984
# [48]	train-logloss:0.01779	train-auc:0.99998	train-error:0.00486	val-logloss:0.02732	val-auc:0.99942	val-error:0.01009
# [49]	train-logloss:0.01693	train-auc:0.99999	train-error:0.00461	val-logloss:0.02696	val-auc:0.99941	val-error:0.01035
# [50]	train-logloss:0.01637	train-auc:0.99999	train-error:0.00436	val-logloss:0.02663	val-auc:0.99940	val-error:0.01108
# [51]	train-logloss:0.01590	train-auc:0.99999	train-error:0.00432	val-logloss:0.02638	val-auc:0.99939	val-error:0.01149
# [52]	train-logloss:0.01529	train-auc:0.99999	train-error:0.00399	val-logloss:0.02599	val-auc:0.99940	val-error:0.01134
# [53]	train-logloss:0.01484	train-auc:0.99999	train-error:0.00390	val-logloss:0.02580	val-auc:0.99940	val-error:0.01145
# [54]	train-logloss:0.01414	train-auc:0.99999	train-error:0.00363	val-logloss:0.02569	val-auc:0.99938	val-error:0.01127
# [55]	train-logloss:0.01376	train-auc:0.99999	train-error:0.00360	val-logloss:0.02562	val-auc:0.99937	val-error:0.01116
# [56]	train-logloss:0.01344	train-auc:0.99999	train-error:0.00350	val-logloss:0.02554	val-auc:0.99936	val-error:0.01140
# [57]	train-logloss:0.01316	train-auc:0.99999	train-error:0.00350	val-logloss:0.02551	val-auc:0.99935	val-error:0.01150
# [58]	train-logloss:0.01280	train-auc:0.99999	train-error:0.00337	val-logloss:0.02546	val-auc:0.99935	val-error:0.01152
# [59]	train-logloss:0.01242	train-auc:0.99999	train-error:0.00331	val-logloss:0.02552	val-auc:0.99934	val-error:0.01190
# [60]	train-logloss:0.01201	train-auc:0.99999	train-error:0.00318	val-logloss:0.02486	val-auc:0.99937	val-error:0.01136
# [61]	train-logloss:0.01167	train-auc:1.00000	train-error:0.00304	val-logloss:0.02496	val-auc:0.99936	val-error:0.01160
# [62]	train-logloss:0.01146	train-auc:1.00000	train-error:0.00299	val-logloss:0.02498	val-auc:0.99935	val-error:0.01139
# [63]	train-logloss:0.01106	train-auc:1.00000	train-error:0.00298	val-logloss:0.02508	val-auc:0.99934	val-error:0.01143
# [64]	train-logloss:0.01088	train-auc:1.00000	train-error:0.00298	val-logloss:0.02502	val-auc:0.99934	val-error:0.01140
# [65]	train-logloss:0.01049	train-auc:1.00000	train-error:0.00273	val-logloss:0.02505	val-auc:0.99932	val-error:0.01148
# [66]	train-logloss:0.01031	train-auc:1.00000	train-error:0.00270	val-logloss:0.02516	val-auc:0.99932	val-error:0.01151
# [67]	train-logloss:0.01001	train-auc:1.00000	train-error:0.00258	val-logloss:0.02474	val-auc:0.99934	val-error:0.01127
# [68]	train-logloss:0.00965	train-auc:1.00000	train-error:0.00226	val-logloss:0.02475	val-auc:0.99933	val-error:0.01131
# [69]	train-logloss:0.00939	train-auc:1.00000	train-error:0.00210	val-logloss:0.02485	val-auc:0.99932	val-error:0.01120
# ...
# [8]	train-logloss:0.23929	train-auc:0.99965	train-error:0.01372	val-logloss:0.24230	val-auc:0.99884	val-error:0.01434
# [9]	train-logloss:0.21615	train-auc:0.99969	train-error:0.01308	val-logloss:0.22016	val-auc:0.99894	val-error:0.01435
# [10]	train-logloss:0.19553	train-auc:0.99972	train-error:0.01231	val-logloss:0.19998	val-auc:0.99902	val-error:0.01445
# [11]	train-logloss:0.17727	train-auc:0.99977	train-error:0.01170	val-logloss:0.18299	val-auc:0.99888	val-error:0.01463
# [12]	train-logloss:0.16091	train-auc:0.99978	train-error:0.01085	val-logloss:0.16866	val-auc:0.99872	val-error:0.01479
# [13]	train-logloss:0.14646	train-auc:0.99979	train-error:0.01038	val-logloss:0.15464	val-auc:0.99879	val-error:0.01532
# [14]	train-logloss:0.13352	train-auc:0.99982	train-error:0.01007	val-logloss:0.14244	val-auc:0.99880	val-error:0.01554
# [15]	train-logloss:0.12195	train-auc:0.99983	train-error:0.00960	val-logloss:0.13109	val-auc:0.99884	val-error:0.01483
# [16]	train-logloss:0.11155	train-auc:0.99986	train-error:0.00933	val-logloss:0.12081	val-auc:0.99890	val-error:0.01397
# [17]	train-logloss:0.10194	train-auc:0.99991	train-error:0.00902	val-logloss:0.11300	val-auc:0.99879	val-error:0.01586
# [18]	train-logloss:0.09334	train-auc:0.99991	train-error:0.00831	val-logloss:0.10502	val-auc:0.99881	val-error:0.01535
# [19]	train-logloss:0.08573	train-auc:0.99992	train-error:0.00806	val-logloss:0.09779	val-auc:0.99883	val-error:0.01472
# [20]	train-logloss:0.07896	train-auc:0.99993	train-error:0.00797	val-logloss:0.09083	val-auc:0.99891	val-error:0.01543
# [21]	train-logloss:0.07258	train-auc:0.99993	train-error:0.00733	val-logloss:0.08473	val-auc:0.99897	val-error:0.01451
# [22]	train-logloss:0.06692	train-auc:0.99995	train-error:0.00729	val-logloss:0.07898	val-auc:0.99903	val-error:0.01502
# [23]	train-logloss:0.06165	train-auc:0.99996	train-error:0.00663	val-logloss:0.07403	val-auc:0.99905	val-error:0.01356
# [24]	train-logloss:0.05701	train-auc:0.99996	train-error:0.00643	val-logloss:0.06966	val-auc:0.99904	val-error:0.01288
# [25]	train-logloss:0.05283	train-auc:0.99996	train-error:0.00620	val-logloss:0.06586	val-auc:0.99907	val-error:0.01266
# [26]	train-logloss:0.04914	train-auc:0.99997	train-error:0.00610	val-logloss:0.06196	val-auc:0.99911	val-error:0.01350
# [27]	train-logloss:0.04565	train-auc:0.99997	train-error:0.00579	val-logloss:0.05881	val-auc:0.99911	val-error:0.01323
# [28]	train-logloss:0.04233	train-auc:0.99997	train-error:0.00571	val-logloss:0.05588	val-auc:0.99912	val-error:0.01318
# [29]	train-logloss:0.03917	train-auc:0.99998	train-error:0.00536	val-logloss:0.05367	val-auc:0.99908	val-error:0.01325
# [30]	train-logloss:0.03654	train-auc:0.99998	train-error:0.00510	val-logloss:0.05081	val-auc:0.99913	val-error:0.01303
# [31]	train-logloss:0.03380	train-auc:0.99999	train-error:0.00470	val-logloss:0.04896	val-auc:0.99909	val-error:0.01318
# [32]	train-logloss:0.03156	train-auc:0.99999	train-error:0.00437	val-logloss:0.04690	val-auc:0.99910	val-error:0.01332
# [33]	train-logloss:0.02945	train-auc:0.99999	train-error:0.00422	val-logloss:0.04525	val-auc:0.99912	val-error:0.01303
# [34]	train-logloss:0.02764	train-auc:0.99999	train-error:0.00407	val-logloss:0.04377	val-auc:0.99911	val-error:0.01333
# [35]	train-logloss:0.02592	train-auc:0.99999	train-error:0.00385	val-logloss:0.04181	val-auc:0.99914	val-error:0.01355
# [36]	train-logloss:0.02413	train-auc:0.99999	train-error:0.00375	val-logloss:0.04081	val-auc:0.99911	val-error:0.01349
# [37]	train-logloss:0.02282	train-auc:0.99999	train-error:0.00356	val-logloss:0.03936	val-auc:0.99913	val-error:0.01353
# [38]	train-logloss:0.02155	train-auc:0.99999	train-error:0.00353	val-logloss:0.03865	val-auc:0.99911	val-error:0.01338
# [39]	train-logloss:0.02032	train-auc:0.99999	train-error:0.00343	val-logloss:0.03742	val-auc:0.99912	val-error:0.01298
# [40]	train-logloss:0.01924	train-auc:0.99999	train-error:0.00341	val-logloss:0.03686	val-auc:0.99910	val-error:0.01288
# [41]	train-logloss:0.01815	train-auc:0.99999	train-error:0.00325	val-logloss:0.03593	val-auc:0.99910	val-error:0.01302
# [42]	train-logloss:0.01726	train-auc:0.99999	train-error:0.00317	val-logloss:0.03541	val-auc:0.99908	val-error:0.01303
# [43]	train-logloss:0.01631	train-auc:1.00000	train-error:0.00290	val-logloss:0.03476	val-auc:0.99909	val-error:0.01253
# [44]	train-logloss:0.01545	train-auc:1.00000	train-error:0.00273	val-logloss:0.03392	val-auc:0.99911	val-error:0.01220
# [45]	train-logloss:0.01480	train-auc:1.00000	train-error:0.00268	val-logloss:0.03315	val-auc:0.99913	val-error:0.01220
# [46]	train-logloss:0.01404	train-auc:1.00000	train-error:0.00265	val-logloss:0.03216	val-auc:0.99918	val-error:0.01194
# [47]	train-logloss:0.01341	train-auc:1.00000	train-error:0.00254	val-logloss:0.03180	val-auc:0.99917	val-error:0.01222
# [48]	train-logloss:0.01286	train-auc:1.00000	train-error:0.00248	val-logloss:0.03116	val-auc:0.99919	val-error:0.01177
# [49]	train-logloss:0.01238	train-auc:1.00000	train-error:0.00247	val-logloss:0.03065	val-auc:0.99920	val-error:0.01112
# [50]	train-logloss:0.01194	train-auc:1.00000	train-error:0.00246	val-logloss:0.03021	val-auc:0.99921	val-error:0.01137
# [51]	train-logloss:0.01136	train-auc:1.00000	train-error:0.00229	val-logloss:0.03011	val-auc:0.99920	val-error:0.01150
# [52]	train-logloss:0.01085	train-auc:1.00000	train-error:0.00216	val-logloss:0.02988	val-auc:0.99920	val-error:0.01170
# [53]	train-logloss:0.01038	train-auc:1.00000	train-error:0.00202	val-logloss:0.02970	val-auc:0.99919	val-error:0.01181
# [54]	train-logloss:0.01006	train-auc:1.00000	train-error:0.00197	val-logloss:0.02954	val-auc:0.99919	val-error:0.01166
# [55]	train-logloss:0.00965	train-auc:1.00000	train-error:0.00192	val-logloss:0.02923	val-auc:0.99921	val-error:0.01043
# [56]	train-logloss:0.00919	train-auc:1.00000	train-error:0.00174	val-logloss:0.02897	val-auc:0.99920	val-error:0.01140
# [57]	train-logloss:0.00892	train-auc:1.00000	train-error:0.00172	val-logloss:0.02864	val-auc:0.99921	val-error:0.01140
# [58]	train-logloss:0.00865	train-auc:1.00000	train-error:0.00170	val-logloss:0.02829	val-auc:0.99922	val-error:0.01115
# [59]	train-logloss:0.00835	train-auc:1.00000	train-error:0.00164	val-logloss:0.02850	val-auc:0.99921	val-error:0.01115
# [60]	train-logloss:0.00800	train-auc:1.00000	train-error:0.00153	val-logloss:0.02878	val-auc:0.99918	val-error:0.01089
# [61]	train-logloss:0.00782	train-auc:1.00000	train-error:0.00147	val-logloss:0.02880	val-auc:0.99917	val-error:0.01094
# [62]	train-logloss:0.00763	train-auc:1.00000	train-error:0.00144	val-logloss:0.02864	val-auc:0.99918	val-error:0.01074
# [63]	train-logloss:0.00749	train-auc:1.00000	train-error:0.00146	val-logloss:0.02854	val-auc:0.99919	val-error:0.01076
# [64]	train-logloss:0.00734	train-auc:1.00000	train-error:0.00144	val-logloss:0.02861	val-auc:0.99918	val-error:0.01063
# [65]	train-logloss:0.00701	train-auc:1.00000	train-error:0.00137	val-logloss:0.02854	val-auc:0.99918	val-error:0.01098
# [66]	train-logloss:0.00670	train-auc:1.00000	train-error:0.00126	val-logloss:0.02881	val-auc:0.99916	val-error:0.01092
# [67]	train-logloss:0.00647	train-auc:1.00000	train-error:0.00126	val-logloss:0.02890	val-auc:0.99916	val-error:0.01082
# [68]	train-logloss:0.00615	train-auc:1.00000	train-error:0.00115	val-logloss:0.02929	val-auc:0.99914	val-error:0.01104
# [69]	train-logloss:0.00584	train-auc:1.00000	train-error:0.00102	val-logloss:0.02964	val-auc:0.99912	val-error:0.01113
# [70]	train-logloss:0.00573	train-auc:1.00000	train-error:0.00095	val-logloss:0.02974	val-auc:0.99911	val-error:0.01106
# [71]	train-logloss:0.00561	train-auc:1.00000	train-error:0.00091	val-logloss:0.02977	val-auc:0.99911	val-error:0.01107
# [72]	train-logloss:0.00535	train-auc:1.00000	train-error:0.00078	val-logloss:0.02994	val-auc:0.99911	val-error:0.01090
# [73]	train-logloss:0.00514	train-auc:1.00000	train-error:0.00076	val-logloss:0.03019	val-auc:0.99909	val-error:0.01112
# [74]	train-logloss:0.00506	train-auc:1.00000	train-error:0.00075	val-logloss:0.03034	val-auc:0.99909	val-error:0.01115
# [75]	train-logloss:0.00477	train-auc:1.00000	train-error:0.00058	val-logloss:0.03049	val-auc:0.99908	val-error:0.01039
# [76]	train-logloss:0.00461	train-auc:1.00000	train-error:0.00057	val-logloss:0.03061	val-auc:0.99908	val-error:0.01038
# [77]	train-logloss:0.00442	train-auc:1.00000	train-error:0.00049	val-logloss:0.03107	val-auc:0.99906	val-error:0.01052
# [78]	train-logloss:0.00419	train-auc:1.00000	train-error:0.00046	val-logloss:0.03145	val-auc:0.99905	val-error:0.01067
# [79]	train-logloss:0.00396	train-auc:1.00000	train-error:0.00037	val-logloss:0.03175	val-auc:0.99904	val-error:0.01074
# [80]	train-logloss:0.00386	train-auc:1.00000	train-error:0.00036	val-logloss:0.03153	val-auc:0.99905	val-error:0.01069
# [81]	train-logloss:0.00370	train-auc:1.00000	train-error:0.00036	val-logloss:0.03169	val-auc:0.99904	val-error:0.01055
# [82]	train-logloss:0.00355	train-auc:1.00000	train-error:0.00030	val-logloss:0.03214	val-auc:0.99903	val-error:0.01012
# [83]	train-logloss:0.00350	train-auc:1.00000	train-error:0.00030	val-logloss:0.03231	val-auc:0.99902	val-error:0.01019
# [84]	train-logloss:0.00336	train-auc:1.00000	train-error:0.00027	val-logloss:0.03245	val-auc:0.99901	val-error:0.01036
# [85]	train-logloss:0.00329	train-auc:1.00000	train-error:0.00027	val-logloss:0.03246	val-auc:0.99902	val-error:0.01035
# [86]	train-logloss:0.00314	train-auc:1.00000	train-error:0.00024	val-logloss:0.03303	val-auc:0.99900	val-error:0.01030
# [87]	train-logloss:0.00295	train-auc:1.00000	train-error:0.00018	val-logloss:0.03316	val-auc:0.99899	val-error:0.01054
# [88]	train-logloss:0.00288	train-auc:1.00000	train-error:0.00017	val-logloss:0.03290	val-auc:0.99900	val-error:0.01042
# [89]	train-logloss:0.00280	train-auc:1.00000	train-error:0.00017	val-logloss:0.03292	val-auc:0.99900	val-error:0.01035
# [90]	train-logloss:0.00267	train-auc:1.00000	train-error:0.00015	val-logloss:0.03302	val-auc:0.99900	val-error:0.01121
# [91]	train-logloss:0.00254	train-auc:1.00000	train-error:0.00014	val-logloss:0.03354	val-auc:0.99898	val-error:0.01117
# [92]	train-logloss:0.00244	train-auc:1.00000	train-error:0.00013	val-logloss:0.03374	val-auc:0.99897	val-error:0.01138
# [93]	train-logloss:0.00231	train-auc:1.00000	train-error:0.00012	val-logloss:0.03421	val-auc:0.99896	val-error:0.01114
# [94]	train-logloss:0.00224	train-auc:1.00000	train-error:0.00012	val-logloss:0.03462	val-auc:0.99895	val-error:0.01116
# [95]	train-logloss:0.00219	train-auc:1.00000	train-error:0.00012	val-logloss:0.03453	val-auc:0.99895	val-error:0.01100
# [96]	train-logloss:0.00209	train-auc:1.00000	train-error:0.00010	val-logloss:0.03480	val-auc:0.99895	val-error:0.01119
# [97]	train-logloss:0.00202	train-auc:1.00000	train-error:0.00011	val-logloss:0.03525	val-auc:0.99894	val-error:0.01153
# [98]	train-logloss:0.00196	train-auc:1.00000	train-error:0.00010	val-logloss:0.03522	val-auc:0.99895	val-error:0.01167
# [99]	train-logloss:0.00187	train-auc:1.00000	train-error:0.00010	val-logloss:0.03574	val-auc:0.99893	val-error:0.01177
# [100]	train-logloss:0.00182	train-auc:1.00000	train-error:0.00010	val-logloss:0.03624	val-auc:0.99892	val-error:0.01248
# [101]	train-logloss:0.00177	train-auc:1.00000	train-error:0.00010	val-logloss:0.03607	val-auc:0.99893	val-error:0.01224
# [102]	train-logloss:0.00172	train-auc:1.00000	train-error:0.00008	val-logloss:0.03603	val-auc:0.99893	val-error:0.01227
# [103]	train-logloss:0.00164	train-auc:1.00000	train-error:0.00008	val-logloss:0.03630	val-auc:0.99894	val-error:0.01290
# [104]	train-logloss:0.00159	train-auc:1.00000	train-error:0.00008	val-logloss:0.03651	val-auc:0.99893	val-error:0.01267
# [105]	train-logloss:0.00156	train-auc:1.00000	train-error:0.00007	val-logloss:0.03668	val-auc:0.99893	val-error:0.01307
# [106]	train-logloss:0.00152	train-auc:1.00000	train-error:0.00007	val-logloss:0.03727	val-auc:0.99891	val-error:0.01355
# [107]	train-logloss:0.00149	train-auc:1.00000	train-error:0.00007	val-logloss:0.03754	val-auc:0.99890	val-error:0.01356
# [108]	train-logloss:0.00146	train-auc:1.00000	train-error:0.00008	val-logloss:0.03719	val-auc:0.99891	val-error:0.01308
# [109]	train-logloss:0.00143	train-auc:1.00000	train-error:0.00008	val-logloss:0.03760	val-auc:0.99890	val-error:0.01306
# [110]	train-logloss:0.00138	train-auc:1.00000	train-error:0.00005	val-logloss:0.03777	val-auc:0.99889	val-error:0.01373
# [111]	train-logloss:0.00134	train-auc:1.00000	train-error:0.00005	val-logloss:0.03817	val-auc:0.99888	val-error:0.01356
# [112]	train-logloss:0.00130	train-auc:1.00000	train-error:0.00005	val-logloss:0.03895	val-auc:0.99885	val-error:0.01417
# [113]	train-logloss:0.00127	train-auc:1.00000	train-error:0.00005	val-logloss:0.03881	val-auc:0.99886	val-error:0.01418
# [114]	train-logloss:0.00123	train-auc:1.00000	train-error:0.00005	val-logloss:0.03946	val-auc:0.99883	val-error:0.01449
# [115]	train-logloss:0.00120	train-auc:1.00000	train-error:0.00005	val-logloss:0.03964	val-auc:0.99882	val-error:0.01468
# [116]	train-logloss:0.00116	train-auc:1.00000	train-error:0.00005	val-logloss:0.03978	val-auc:0.99882	val-error:0.01455
# [117]	train-logloss:0.00114	train-auc:1.00000	train-error:0.00004	val-logloss:0.03981	val-auc:0.99882	val-error:0.01473
# [118]	train-logloss:0.00111	train-auc:1.00000	train-error:0.00004	val-logloss:0.03955	val-auc:0.99882	val-error:0.01462
# [119]	train-logloss:0.00107	train-auc:1.00000	train-error:0.00004	val-logloss:0.03965	val-auc:0.99883	val-error:0.01495
# [120]	train-logloss:0.00102	train-auc:1.00000	train-error:0.00003	val-logloss:0.04004	val-auc:0.99882	val-error:0.01492
# [121]	train-logloss:0.00097	train-auc:1.00000	train-error:0.00003	val-logloss:0.03998	val-auc:0.99882	val-error:0.01491
# [122]	train-logloss:0.00094	train-auc:1.00000	train-error:0.00003	val-logloss:0.04043	val-auc:0.99881	val-error:0.01497
# [123]	train-logloss:0.00091	train-auc:1.00000	train-error:0.00002	val-logloss:0.04043	val-auc:0.99881	val-error:0.01492
# [124]	train-logloss:0.00088	train-auc:1.00000	train-error:0.00003	val-logloss:0.04050	val-auc:0.99881	val-error:0.01493
# [125]	train-logloss:0.00084	train-auc:1.00000	train-error:0.00002	val-logloss:0.04033	val-auc:0.99883	val-error:0.01488
# [126]	train-logloss:0.00082	train-auc:1.00000	train-error:0.00002	val-logloss:0.04045	val-auc:0.99883	val-error:0.01478
# [127]	train-logloss:0.00081	train-auc:1.00000	train-error:0.00002	val-logloss:0.04028	val-auc:0.99884	val-error:0.01465
# [128]	train-logloss:0.00079	train-auc:1.00000	train-error:0.00002	val-logloss:0.04007	val-auc:0.99886	val-error:0.01459
# [129]	train-logloss:0.00076	train-auc:1.00000	train-error:0.00001	val-logloss:0.04039	val-auc:0.99885	val-error:0.01482
# [130]	train-logloss:0.00073	train-auc:1.00000	train-error:0.00002	val-logloss:0.04093	val-auc:0.99884	val-error:0.01489
# [131]	train-logloss:0.00070	train-auc:1.00000	train-error:0.00001	val-logloss:0.04150	val-auc:0.99882	val-error:0.01493
# XGBoost模型训练完成
# 完成时间20251213_072505
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     1.0000 |     0.9851
# 精确率          |     0.9999 |     0.9753
# 召回率          |     1.0000 |     0.9287
# F1分数          |     1.0000 |     0.9514
# AUC            |     1.0000 |     0.9988
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99     86956
#      Class 1       0.98      0.93      0.95     16255
#
#     accuracy                           0.99    103211
#    macro avg       0.98      0.96      0.97    103211
# weighted avg       0.98      0.99      0.98    103211
#
#
# 验证集混淆矩阵:
# TN: 86573, FP: 383
# FN: 1159, TP: 15096
#
# 模型已保存为: Model_XGBoost_L1500.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 3000
# 最佳迭代轮数: 82
# 最佳验证分数: 0.01012488978887909
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
