# %%
#数据预处理
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

batch_size = 256
try_length = [200,500,1000,1500] # 模型查看的历史窗口大小
prediction_horizon = 1 # 预测的未来窗口大小

directory = "../datas/train" #数据目录
all_items = os.listdir(directory)  #列出目录下所有文件
csv_files = [os.path.join(directory, item) for item in all_items if item.endswith('.csv') and os.path.isfile(os.path.join(directory, item))]  #筛选出CSV文件 
Sample_size = len(csv_files)  #获取样本数量

sequences_data = [] #创建一个空列表，用于存储所有序列的数据
scalers = {} #创建一个空字典，用于存储每个序列对应的标准化器
base_features = ['Voltage', 'Current']
features = [ 'impedance','cumulative_power']

for file in csv_files:
    df = pd.read_csv(file)
    df['impedance'] = df['Voltage'] * 1000 / df['Current'].replace(0, np.nan)
    df['power'] = df['Voltage'] * (df['Current'] / 1000)
    df['cumulative_power'] = (df['power']/1000).cumsum()
    df['impedance_diff'] = df['impedance'].diff().fillna(0) #添加一阶差分
    df['impedance_rolling_mean'] = df['impedance'].rolling(window=20, min_periods=1).mean() #滚动均值
    df['impedance_rolling_std'] = df['impedance'].rolling(window=20, min_periods=1).std()  #滚动标准差
    df['impedance_slope_10'] = df['impedance'].diff(10) / 10  #过去 10 个时间点的平均变化率。
    df['impedance_slope_10'] = df['impedance_slope_10'].fillna(0) # 将该列中的所有缺失值（NaN）填充为数字0
    df = df.ffill().bfill()  #缺失值处理先用前向填充，再用后向填充
    #数据预处理 数值归一化
    scaler = StandardScaler() #为当前序列创建一个新的StandardScaler实例
    df.loc[:, features] = scaler.fit_transform(df.loc[:, features]) #对当前序列的指定特征列进行拟合和转换
    scalers[file] = scaler #将当前序列的标准化器保存到字典中，键为序列ID
    sequences_data.append(df[features + ['Action']].values) #将当前序列的数组数据添加到结果列表中

train_sequences, val_sequences = train_test_split(sequences_data, test_size=0.18, random_state=42)

print(f'检索到{Sample_size}个样本')
print(f"特征数量: {len(features)}")
print(f"序列数量: {len(sequences_data)}")
print(f"训练序列: {len(train_sequences)}")
print(f"验证序列: {len(val_sequences)}")
# Out:
# 检索到55个样本
# 特征数量: 2
# 序列数量: 55
# 训练序列: 45
# 验证序列: 10

# %%
import xgboost as xgb
from tqdm import tqdm

def create_xgboost_data(sequences_data, sequence_length, prediction_horizon):
    X_list = []
    y_list = []
    
    for seq_data in tqdm(sequences_data, desc="处理序列", unit="seq", ncols=60):
        n_samples = len(seq_data) - sequence_length - prediction_horizon + 1
        
        for i in range(n_samples):
            # 提取特征
            x = seq_data[i:i + sequence_length, :-1].flatten()  # 展平为1D向量
            X_list.append(x)
            
            # 提取标签
            y_window = seq_data[i + sequence_length:i + sequence_length + prediction_horizon, -1]
            y = 1 if np.any(y_window == 1) else 0
            y_list.append(y)
    
    return np.array(X_list), np.array(y_list)

# %%
# 训练模型
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
from sklearn.datasets import dump_svmlight_file
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from datetime import datetime

model_name = 'XGBoost'
num_boost_round=1000

for sequence_length in try_length:

    print(f"序列窗口长度: {sequence_length}")
    print("生成训练数据...")
    X_train, y_train = create_xgboost_data(train_sequences, sequence_length, prediction_horizon)
    X_val, y_val = create_xgboost_data(val_sequences, sequence_length, prediction_horizon)
    # 从float64转化为float32
    # X_train = X_train.astype(np.float32)
    # y_val = X_val.astype(np.float32)
    
    # 计算类别权重（处理不平衡数据）
    # if np.sum(y_train) > 0:
    #     scale_pos_weight = (len(y_train) - np.sum(y_train)) / np.sum(y_train)
    # else:
    #     scale_pos_weight = 1.0
    #     print("警告: 训练集中没有正样本!")
    scale_pos_weight = 1.0
    
    # 定义XGBoost模型参数
    params = {
        'tree_method': 'hist',  # 使用GPU直方图算法
        'device': 'cuda',           # 指定使用CUDA设备
        'max_bin': 256,                 # 直方图分桶数，GPU上256是常用值，可在速度和精度间权衡
        'objective': 'binary:logistic',  # 根据你的问题调整
        'eval_metric': ['logloss', 'auc', 'error'],
        'learning_rate': 0.1,
        'max_depth': 6,
        'random_state': 42,
        'reg_alpha': 0.1,
        'reg_lambda': 1.0,
        'gamma': 0.1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'colsample_bylevel': 0.8,   # 每层特征采样
        'colsample_bynode': 0.8,    # 每个节点特征采样
        'scale_pos_weight': scale_pos_weight,
        'verbosity': 1,  # 新版本推荐用法
    }
    print("XGBoost模型配置完成")
    print("创建DMatrix...")
    dtrain = xgb.QuantileDMatrix(X_train, label=y_train, max_bin=params['max_bin'])
    dval = xgb.QuantileDMatrix(X_val, label=y_val, max_bin=params['max_bin'], ref=dtrain) # ref引用dtrain的分位数
    print("创建DMatrix完成")
        
    print(f"训练样本数: {len(X_train)}")
    print(f"验证样本数: {len(X_val)}")
    print(f"训练集形状: X_train {X_train.shape}, y_train {y_train.shape}")
    print(f"验证集形状: X_val {X_val.shape}, y_val {y_val.shape}")
    print(f"特征维度: {X_train.shape[1]} (序列长度{sequence_length} × 特征数{len(features)})")
    print(f"正样本比例 - 训练集: {np.mean(y_train):.4f}, 验证集: {np.mean(y_val):.4f}")
    print(f"类别权重 scale_pos_weight: {scale_pos_weight:.2f}")
    
    print("开始训练...")
    eval_history = {}
    # 使用原生接口训练
    model = xgb.train(
        params, dtrain,
        num_boost_round,
        evals=[(dtrain, 'train'),(dval, 'val')],  # 这里使用 evals
        early_stopping_rounds=50,
        evals_result=eval_history,  # 这里使用 evals_result
        verbose_eval=True
    )
    print("XGBoost模型训练完成")
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"完成时间{timestamp}")
    
    plt.figure(figsize=(12, 4))
    # 绘制logloss
    plt.subplot(1, 3, 1)
    plt.plot(eval_history['train']['logloss'], label='Train Logloss')
    plt.plot(eval_history['val']['logloss'], label='Validation Logloss')
    plt.xlabel('Iteration')
    plt.ylabel('Logloss')
    plt.title('XGBoost Training - Logloss')
    plt.legend()
    plt.grid(True)
    
    # 绘制错误率
    plt.subplot(1, 3, 2)
    plt.plot(eval_history['train']['error'], label='Train Error')
    plt.plot(eval_history['val']['error'], label='Validation Error')
    plt.xlabel('Iteration')
    plt.ylabel('Error')
    plt.title('XGBoost Training - Error')
    plt.legend()
    plt.grid(True)
    
    # 绘制错误率
    plt.subplot(1, 3, 3)
    plt.plot(eval_history['train']['auc'], label='Train auc')
    plt.plot(eval_history['val']['auc'], label='Validation auc')
    plt.xlabel('Iteration')
    plt.ylabel('Error')
    plt.title('XGBoost Training - auc')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    """
    评估XGBoost模型性能
    """
    print("\n" + "="*60)
    print("XGBoost模型评估结果")
    print("="*60)
    
    # 训练集预测
    y_train_prob = model.predict(dtrain)  # 预测概率
    y_train_pred = (y_train_prob > 0.5).astype(int)  # 转换为类别
    
    # 验证集预测
    y_val_prob = model.predict(dval)  # 预测概率
    y_val_pred = (y_val_prob > 0.5).astype(int)  # 转换为类别
    
    # 计算训练集指标
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred, zero_division=0)
    train_recall = recall_score(y_train, y_train_pred, zero_division=0)
    train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
    train_auc = roc_auc_score(y_train, y_train_prob)
    
    # 计算验证集指标
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_precision = precision_score(y_val, y_val_pred, zero_division=0)
    val_recall = recall_score(y_val, y_val_pred, zero_division=0)
    val_f1 = f1_score(y_val, y_val_pred, zero_division=0)
    val_auc = roc_auc_score(y_val, y_val_prob)
    
    # 打印结果表格
    print(f"{'指标':<12} | {'训练集':<10} | {'验证集':<10}")
    print("-" * 40)
    print(f"{'准确率':<12} | {train_accuracy:>10.4f} | {val_accuracy:>10.4f}")
    print(f"{'精确率':<12} | {train_precision:>10.4f} | {val_precision:>10.4f}")
    print(f"{'召回率':<12} | {train_recall:>10.4f} | {val_recall:>10.4f}")
    print(f"{'F1分数':<13} | {train_f1:>10.4f} | {val_f1:>10.4f}")
    print(f"{'AUC':<14} | {train_auc:>10.4f} | {val_auc:>10.4f}")
    
    # 验证集详细报告
    print(f"\n验证集详细分类报告:")
    print(classification_report(y_val, y_val_pred, target_names=['Class 0', 'Class 1']))
    
    # 混淆矩阵
    cm = confusion_matrix(y_val, y_val_pred)
    print(f"\n验证集混淆矩阵:")
    print(f"TN: {cm[0,0]}, FP: {cm[0,1]}")
    print(f"FN: {cm[1,0]}, TP: {cm[1,1]}")
    
    feature_names = [f'feature_{i}' for i in range(X_train.shape[1])]
    
    model_name=f"Model_XGBoost_L{sequence_length}.pkl"
    
    """
    保存XGBoost模型
    """
    # 准备保存的数据
    model_data = {
        'model': model,
        'feature_names': feature_names,
        'model_type': 'booster'
    }
    # 获取特征数量
    if X_train is not None:
        num_features = X_train.shape[1]
    else:
        num_features = len(feature_names)
    
    # 获取最佳迭代轮数
    best_iteration = getattr(model, 'best_iteration', '未知')
    best_score = getattr(model, 'best_score', '未知')
    
    model_data.update({
        'num_features': num_features,
        'best_iteration': best_iteration,
        'best_score': best_score
    })
    
    # 保存模型
    joblib.dump(model_data, model_name)
    print(f"\n模型已保存为: {model_name}")
    print(f"模型类型: Booster (原生接口)")
    print(f"特征数量: {model_data.get('num_features', len(feature_names))}")
    print(f"最佳迭代轮数: {best_iteration}")
    print(f"最佳验证分数: {best_score}")
    print(f"类别: [0, 1] (二分类任务)")
    print(f"\n{'='*60}")
    print("XGBoost模型训练完成!")
    print(f"{'='*60}")
# Out:
# 序列窗口长度: 200
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:02<00:00, 17.70seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 23.39seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 544072
# 验证样本数: 116211
# 训练集形状: X_train (544072, 400), y_train (544072,)
# 验证集形状: X_val (116211, 400), y_val (116211,)
# 特征维度: 400 (序列长度200 × 特征数2)
# 正样本比例 - 训练集: 0.1391, 验证集: 0.1399
# 类别权重 scale_pos_weight: 1.00
# 开始训练...
# [0]	train-logloss:0.34745	train-auc:0.99626	train-error:0.13913	val-logloss:0.34697	val-auc:0.99751	val-error:0.13987
# [1]	train-logloss:0.30294	train-auc:0.99729	train-error:0.13913	val-logloss:0.30088	val-auc:0.99812	val-error:0.13987
# [2]	train-logloss:0.26810	train-auc:0.99779	train-error:0.13913	val-logloss:0.26497	val-auc:0.99839	val-error:0.13987
# [3]	train-logloss:0.23983	train-auc:0.99789	train-error:0.13913	val-logloss:0.23584	val-auc:0.99864	val-error:0.13987
# [4]	train-logloss:0.21606	train-auc:0.99796	train-error:0.03719	val-logloss:0.21130	val-auc:0.99870	val-error:0.03411
# [5]	train-logloss:0.19587	train-auc:0.99801	train-error:0.03039	val-logloss:0.19092	val-auc:0.99877	val-error:0.02186
# [6]	train-logloss:0.17822	train-auc:0.99813	train-error:0.02536	val-logloss:0.17309	val-auc:0.99881	val-error:0.01401
# [7]	train-logloss:0.16286	train-auc:0.99820	train-error:0.02179	val-logloss:0.15768	val-auc:0.99879	val-error:0.01280
# [8]	train-logloss:0.14961	train-auc:0.99822	train-error:0.02000	val-logloss:0.14438	val-auc:0.99881	val-error:0.01227
# [9]	train-logloss:0.13775	train-auc:0.99825	train-error:0.01847	val-logloss:0.13266	val-auc:0.99884	val-error:0.01166
# [10]	train-logloss:0.12727	train-auc:0.99829	train-error:0.01681	val-logloss:0.12211	val-auc:0.99884	val-error:0.01060
# [11]	train-logloss:0.11800	train-auc:0.99833	train-error:0.01594	val-logloss:0.11312	val-auc:0.99885	val-error:0.01008
# [12]	train-logloss:0.10955	train-auc:0.99843	train-error:0.01556	val-logloss:0.10487	val-auc:0.99888	val-error:0.01057
# [13]	train-logloss:0.10219	train-auc:0.99846	train-error:0.01514	val-logloss:0.09758	val-auc:0.99890	val-error:0.01083
# [14]	train-logloss:0.09512	train-auc:0.99865	train-error:0.01459	val-logloss:0.09138	val-auc:0.99874	val-error:0.01129
# [15]	train-logloss:0.08893	train-auc:0.99877	train-error:0.01396	val-logloss:0.08565	val-auc:0.99873	val-error:0.01119
# [16]	train-logloss:0.08321	train-auc:0.99884	train-error:0.01389	val-logloss:0.08078	val-auc:0.99865	val-error:0.01102
# [17]	train-logloss:0.07809	train-auc:0.99891	train-error:0.01363	val-logloss:0.07650	val-auc:0.99856	val-error:0.01076
# [18]	train-logloss:0.07330	train-auc:0.99902	train-error:0.01360	val-logloss:0.07231	val-auc:0.99856	val-error:0.01089
# [19]	train-logloss:0.06900	train-auc:0.99911	train-error:0.01295	val-logloss:0.06830	val-auc:0.99869	val-error:0.01090
# [20]	train-logloss:0.06506	train-auc:0.99919	train-error:0.01258	val-logloss:0.06484	val-auc:0.99876	val-error:0.01096
# [21]	train-logloss:0.06150	train-auc:0.99926	train-error:0.01187	val-logloss:0.06188	val-auc:0.99874	val-error:0.01106
# [22]	train-logloss:0.05837	train-auc:0.99930	train-error:0.01127	val-logloss:0.05884	val-auc:0.99882	val-error:0.01105
# [23]	train-logloss:0.05556	train-auc:0.99933	train-error:0.01092	val-logloss:0.05619	val-auc:0.99886	val-error:0.01083
# [24]	train-logloss:0.05300	train-auc:0.99936	train-error:0.01049	val-logloss:0.05378	val-auc:0.99888	val-error:0.01107
# [25]	train-logloss:0.05067	train-auc:0.99938	train-error:0.01033	val-logloss:0.05180	val-auc:0.99888	val-error:0.01145
# [26]	train-logloss:0.04860	train-auc:0.99940	train-error:0.00995	val-logloss:0.04972	val-auc:0.99890	val-error:0.01126
# [27]	train-logloss:0.04669	train-auc:0.99941	train-error:0.00986	val-logloss:0.04808	val-auc:0.99890	val-error:0.01136
# [28]	train-logloss:0.04494	train-auc:0.99943	train-error:0.00972	val-logloss:0.04658	val-auc:0.99890	val-error:0.01142
# [29]	train-logloss:0.04337	train-auc:0.99944	train-error:0.00940	val-logloss:0.04512	val-auc:0.99891	val-error:0.01150
# [30]	train-logloss:0.04197	train-auc:0.99945	train-error:0.00911	val-logloss:0.04381	val-auc:0.99891	val-error:0.01156
# [31]	train-logloss:0.04068	train-auc:0.99946	train-error:0.00907	val-logloss:0.04272	val-auc:0.99891	val-error:0.01164
# [32]	train-logloss:0.03952	train-auc:0.99947	train-error:0.00917	val-logloss:0.04174	val-auc:0.99891	val-error:0.01184
# [33]	train-logloss:0.03843	train-auc:0.99948	train-error:0.00899	val-logloss:0.04084	val-auc:0.99891	val-error:0.01187
# [34]	train-logloss:0.03742	train-auc:0.99949	train-error:0.00889	val-logloss:0.04010	val-auc:0.99891	val-error:0.01186
# [35]	train-logloss:0.03653	train-auc:0.99949	train-error:0.00887	val-logloss:0.03926	val-auc:0.99891	val-error:0.01181
# [36]	train-logloss:0.03563	train-auc:0.99950	train-error:0.00881	val-logloss:0.03867	val-auc:0.99891	val-error:0.01185
# [37]	train-logloss:0.03484	train-auc:0.99952	train-error:0.00869	val-logloss:0.03791	val-auc:0.99891	val-error:0.01169
# [38]	train-logloss:0.03413	train-auc:0.99953	train-error:0.00849	val-logloss:0.03739	val-auc:0.99891	val-error:0.01169
# [39]	train-logloss:0.03347	train-auc:0.99954	train-error:0.00842	val-logloss:0.03690	val-auc:0.99892	val-error:0.01169
# [40]	train-logloss:0.03278	train-auc:0.99956	train-error:0.00817	val-logloss:0.03658	val-auc:0.99892	val-error:0.01169
# [41]	train-logloss:0.03221	train-auc:0.99956	train-error:0.00816	val-logloss:0.03617	val-auc:0.99892	val-error:0.01169
# [42]	train-logloss:0.03167	train-auc:0.99957	train-error:0.00811	val-logloss:0.03589	val-auc:0.99891	val-error:0.01170
# [43]	train-logloss:0.03117	train-auc:0.99957	train-error:0.00809	val-logloss:0.03561	val-auc:0.99891	val-error:0.01193
# [44]	train-logloss:0.03078	train-auc:0.99958	train-error:0.00799	val-logloss:0.03538	val-auc:0.99890	val-error:0.01175
# [45]	train-logloss:0.03037	train-auc:0.99958	train-error:0.00797	val-logloss:0.03511	val-auc:0.99890	val-error:0.01187
# [46]	train-logloss:0.02995	train-auc:0.99960	train-error:0.00769	val-logloss:0.03494	val-auc:0.99890	val-error:0.01187
# [47]	train-logloss:0.02956	train-auc:0.99961	train-error:0.00761	val-logloss:0.03476	val-auc:0.99887	val-error:0.01174
# [48]	train-logloss:0.02927	train-auc:0.99961	train-error:0.00756	val-logloss:0.03460	val-auc:0.99887	val-error:0.01171
# [49]	train-logloss:0.02881	train-auc:0.99963	train-error:0.00737	val-logloss:0.03455	val-auc:0.99883	val-error:0.01186
# [50]	train-logloss:0.02848	train-auc:0.99964	train-error:0.00723	val-logloss:0.03442	val-auc:0.99883	val-error:0.01216
# [51]	train-logloss:0.02806	train-auc:0.99965	train-error:0.00714	val-logloss:0.03423	val-auc:0.99884	val-error:0.01219
# [52]	train-logloss:0.02775	train-auc:0.99965	train-error:0.00709	val-logloss:0.03414	val-auc:0.99883	val-error:0.01235
# [53]	train-logloss:0.02735	train-auc:0.99967	train-error:0.00698	val-logloss:0.03414	val-auc:0.99881	val-error:0.01250
# [54]	train-logloss:0.02704	train-auc:0.99968	train-error:0.00672	val-logloss:0.03410	val-auc:0.99880	val-error:0.01246
# [55]	train-logloss:0.02682	train-auc:0.99969	train-error:0.00668	val-logloss:0.03400	val-auc:0.99881	val-error:0.01246
# [56]	train-logloss:0.02651	train-auc:0.99970	train-error:0.00658	val-logloss:0.03359	val-auc:0.99885	val-error:0.01246
# [57]	train-logloss:0.02605	train-auc:0.99971	train-error:0.00635	val-logloss:0.03343	val-auc:0.99886	val-error:0.01266
# [58]	train-logloss:0.02587	train-auc:0.99972	train-error:0.00632	val-logloss:0.03336	val-auc:0.99886	val-error:0.01266
# [59]	train-logloss:0.02565	train-auc:0.99972	train-error:0.00629	val-logloss:0.03316	val-auc:0.99886	val-error:0.01256
# [60]	train-logloss:0.02538	train-auc:0.99973	train-error:0.00626	val-logloss:0.03312	val-auc:0.99886	val-error:0.01236
# [61]	train-logloss:0.02521	train-auc:0.99974	train-error:0.00615	val-logloss:0.03305	val-auc:0.99887	val-error:0.01236
# XGBoost模型训练完成
# 完成时间20251216_020048
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9938 |     0.9876
# 精确率          |     0.9854 |     0.9536
# 召回率          |     0.9702 |     0.9583
# F1分数          |     0.9777 |     0.9559
# AUC            |     0.9997 |     0.9989
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99     99956
#      Class 1       0.95      0.96      0.96     16255
#
#     accuracy                           0.99    116211
#    macro avg       0.97      0.98      0.97    116211
# weighted avg       0.99      0.99      0.99    116211
#
#
# 验证集混淆矩阵:
# TN: 99198, FP: 758
# FN: 678, TP: 15577
#
# 模型已保存为: Model_XGBoost_L200.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 400
# 最佳迭代轮数: 11
# 最佳验证分数: 0.01007649878238721
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
# 序列窗口长度: 500
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:03<00:00, 12.57seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 17.80seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 530572
# 验证样本数: 113211
# 训练集形状: X_train (530572, 1000), y_train (530572,)
# 验证集形状: X_val (113211, 1000), y_val (113211,)
# 特征维度: 1000 (序列长度500 × 特征数2)
# 正样本比例 - 训练集: 0.1427, 验证集: 0.1436
# 类别权重 scale_pos_weight: 1.00
# 开始训练...
# [0]	train-logloss:0.35097	train-auc:0.99737	train-error:0.14267	val-logloss:0.35194	val-auc:0.99800	val-error:0.14358
# [1]	train-logloss:0.30381	train-auc:0.99852	train-error:0.14267	val-logloss:0.30517	val-auc:0.99875	val-error:0.14358
# [2]	train-logloss:0.26729	train-auc:0.99893	train-error:0.14267	val-logloss:0.26861	val-auc:0.99882	val-error:0.14358
# [3]	train-logloss:0.23764	train-auc:0.99905	train-error:0.14238	val-logloss:0.23920	val-auc:0.99901	val-error:0.14358
# [4]	train-logloss:0.21306	train-auc:0.99912	train-error:0.03567	val-logloss:0.21417	val-auc:0.99904	val-error:0.03600
# [5]	train-logloss:0.19192	train-auc:0.99918	train-error:0.02617	val-logloss:0.19307	val-auc:0.99905	val-error:0.02300
# [6]	train-logloss:0.17361	train-auc:0.99923	train-error:0.01970	val-logloss:0.17497	val-auc:0.99906	val-error:0.01808
# [7]	train-logloss:0.15738	train-auc:0.99934	train-error:0.01751	val-logloss:0.15906	val-auc:0.99910	val-error:0.01607
# [8]	train-logloss:0.14332	train-auc:0.99938	train-error:0.01494	val-logloss:0.14520	val-auc:0.99907	val-error:0.01541
# [9]	train-logloss:0.13050	train-auc:0.99947	train-error:0.01223	val-logloss:0.13289	val-auc:0.99911	val-error:0.01495
# [10]	train-logloss:0.11950	train-auc:0.99948	train-error:0.01098	val-logloss:0.12180	val-auc:0.99916	val-error:0.01434
# [11]	train-logloss:0.10946	train-auc:0.99952	train-error:0.00947	val-logloss:0.11226	val-auc:0.99918	val-error:0.01440
# [12]	train-logloss:0.10057	train-auc:0.99955	train-error:0.00876	val-logloss:0.10389	val-auc:0.99915	val-error:0.01468
# [13]	train-logloss:0.09256	train-auc:0.99960	train-error:0.00783	val-logloss:0.09614	val-auc:0.99917	val-error:0.01389
# [14]	train-logloss:0.08540	train-auc:0.99963	train-error:0.00721	val-logloss:0.08921	val-auc:0.99920	val-error:0.01363
# [15]	train-logloss:0.07890	train-auc:0.99966	train-error:0.00689	val-logloss:0.08321	val-auc:0.99917	val-error:0.01361
# [16]	train-logloss:0.07315	train-auc:0.99968	train-error:0.00644	val-logloss:0.07769	val-auc:0.99918	val-error:0.01374
# [17]	train-logloss:0.06788	train-auc:0.99970	train-error:0.00558	val-logloss:0.07258	val-auc:0.99920	val-error:0.01295
# [18]	train-logloss:0.06311	train-auc:0.99973	train-error:0.00525	val-logloss:0.06856	val-auc:0.99918	val-error:0.01329
# [19]	train-logloss:0.05884	train-auc:0.99974	train-error:0.00542	val-logloss:0.06508	val-auc:0.99914	val-error:0.01305
# [20]	train-logloss:0.05495	train-auc:0.99976	train-error:0.00480	val-logloss:0.06148	val-auc:0.99914	val-error:0.01276
# [21]	train-logloss:0.05140	train-auc:0.99977	train-error:0.00464	val-logloss:0.05837	val-auc:0.99915	val-error:0.01302
# [22]	train-logloss:0.04814	train-auc:0.99978	train-error:0.00470	val-logloss:0.05554	val-auc:0.99916	val-error:0.01351
# [23]	train-logloss:0.04523	train-auc:0.99979	train-error:0.00458	val-logloss:0.05289	val-auc:0.99916	val-error:0.01275
# [24]	train-logloss:0.04271	train-auc:0.99979	train-error:0.00450	val-logloss:0.05047	val-auc:0.99917	val-error:0.01298
# [25]	train-logloss:0.04039	train-auc:0.99981	train-error:0.00448	val-logloss:0.04807	val-auc:0.99920	val-error:0.01243
# [26]	train-logloss:0.03828	train-auc:0.99981	train-error:0.00449	val-logloss:0.04599	val-auc:0.99921	val-error:0.01260
# [27]	train-logloss:0.03628	train-auc:0.99982	train-error:0.00442	val-logloss:0.04426	val-auc:0.99924	val-error:0.01274
# [28]	train-logloss:0.03459	train-auc:0.99983	train-error:0.00424	val-logloss:0.04269	val-auc:0.99926	val-error:0.01260
# [29]	train-logloss:0.03299	train-auc:0.99983	train-error:0.00421	val-logloss:0.04115	val-auc:0.99926	val-error:0.01252
# [30]	train-logloss:0.03144	train-auc:0.99984	train-error:0.00402	val-logloss:0.04023	val-auc:0.99925	val-error:0.01241
# [31]	train-logloss:0.03011	train-auc:0.99985	train-error:0.00402	val-logloss:0.03879	val-auc:0.99927	val-error:0.01230
# [32]	train-logloss:0.02893	train-auc:0.99985	train-error:0.00399	val-logloss:0.03766	val-auc:0.99928	val-error:0.01227
# [33]	train-logloss:0.02778	train-auc:0.99986	train-error:0.00397	val-logloss:0.03679	val-auc:0.99927	val-error:0.01215
# [34]	train-logloss:0.02678	train-auc:0.99986	train-error:0.00386	val-logloss:0.03594	val-auc:0.99927	val-error:0.01222
# [35]	train-logloss:0.02582	train-auc:0.99987	train-error:0.00380	val-logloss:0.03498	val-auc:0.99929	val-error:0.01205
# [36]	train-logloss:0.02498	train-auc:0.99987	train-error:0.00377	val-logloss:0.03416	val-auc:0.99930	val-error:0.01200
# [37]	train-logloss:0.02416	train-auc:0.99988	train-error:0.00371	val-logloss:0.03359	val-auc:0.99930	val-error:0.01200
# [38]	train-logloss:0.02324	train-auc:0.99989	train-error:0.00358	val-logloss:0.03290	val-auc:0.99931	val-error:0.01201
# [39]	train-logloss:0.02251	train-auc:0.99989	train-error:0.00347	val-logloss:0.03243	val-auc:0.99931	val-error:0.01195
# [40]	train-logloss:0.02181	train-auc:0.99990	train-error:0.00336	val-logloss:0.03175	val-auc:0.99932	val-error:0.01179
# [41]	train-logloss:0.02124	train-auc:0.99990	train-error:0.00326	val-logloss:0.03142	val-auc:0.99932	val-error:0.01181
# [42]	train-logloss:0.02072	train-auc:0.99991	train-error:0.00327	val-logloss:0.03101	val-auc:0.99932	val-error:0.01183
# [43]	train-logloss:0.02015	train-auc:0.99991	train-error:0.00316	val-logloss:0.03070	val-auc:0.99931	val-error:0.01176
# [44]	train-logloss:0.01973	train-auc:0.99991	train-error:0.00312	val-logloss:0.03042	val-auc:0.99930	val-error:0.01173
# [45]	train-logloss:0.01931	train-auc:0.99992	train-error:0.00306	val-logloss:0.03029	val-auc:0.99930	val-error:0.01192
# [46]	train-logloss:0.01893	train-auc:0.99992	train-error:0.00308	val-logloss:0.03012	val-auc:0.99930	val-error:0.01198
# [47]	train-logloss:0.01842	train-auc:0.99992	train-error:0.00299	val-logloss:0.03003	val-auc:0.99928	val-error:0.01200
# [48]	train-logloss:0.01809	train-auc:0.99993	train-error:0.00287	val-logloss:0.02990	val-auc:0.99928	val-error:0.01201
# [49]	train-logloss:0.01774	train-auc:0.99993	train-error:0.00280	val-logloss:0.02978	val-auc:0.99927	val-error:0.01219
# [50]	train-logloss:0.01745	train-auc:0.99993	train-error:0.00278	val-logloss:0.02974	val-auc:0.99927	val-error:0.01231
# [51]	train-logloss:0.01713	train-auc:0.99993	train-error:0.00273	val-logloss:0.02958	val-auc:0.99927	val-error:0.01239
# [52]	train-logloss:0.01688	train-auc:0.99993	train-error:0.00276	val-logloss:0.02945	val-auc:0.99926	val-error:0.01237
# [53]	train-logloss:0.01640	train-auc:0.99994	train-error:0.00253	val-logloss:0.02945	val-auc:0.99925	val-error:0.01265
# [54]	train-logloss:0.01617	train-auc:0.99994	train-error:0.00247	val-logloss:0.02937	val-auc:0.99925	val-error:0.01264
# [55]	train-logloss:0.01580	train-auc:0.99995	train-error:0.00242	val-logloss:0.02951	val-auc:0.99924	val-error:0.01239
# [56]	train-logloss:0.01554	train-auc:0.99995	train-error:0.00235	val-logloss:0.02944	val-auc:0.99924	val-error:0.01237
# [57]	train-logloss:0.01534	train-auc:0.99995	train-error:0.00229	val-logloss:0.02940	val-auc:0.99923	val-error:0.01240
# [58]	train-logloss:0.01498	train-auc:0.99996	train-error:0.00218	val-logloss:0.02933	val-auc:0.99923	val-error:0.01273
# [59]	train-logloss:0.01476	train-auc:0.99996	train-error:0.00215	val-logloss:0.02939	val-auc:0.99922	val-error:0.01286
# [60]	train-logloss:0.01459	train-auc:0.99996	train-error:0.00216	val-logloss:0.02951	val-auc:0.99920	val-error:0.01287
# [61]	train-logloss:0.01440	train-auc:0.99996	train-error:0.00216	val-logloss:0.02952	val-auc:0.99919	val-error:0.01287
# [62]	train-logloss:0.01419	train-auc:0.99996	train-error:0.00208	val-logloss:0.02959	val-auc:0.99918	val-error:0.01287
# [63]	train-logloss:0.01391	train-auc:0.99997	train-error:0.00203	val-logloss:0.02947	val-auc:0.99919	val-error:0.01288
# [64]	train-logloss:0.01377	train-auc:0.99997	train-error:0.00203	val-logloss:0.02950	val-auc:0.99918	val-error:0.01289
# [65]	train-logloss:0.01342	train-auc:0.99997	train-error:0.00185	val-logloss:0.02962	val-auc:0.99918	val-error:0.01287
# [66]	train-logloss:0.01315	train-auc:0.99997	train-error:0.00172	val-logloss:0.02946	val-auc:0.99918	val-error:0.01278
# [67]	train-logloss:0.01299	train-auc:0.99998	train-error:0.00165	val-logloss:0.02945	val-auc:0.99918	val-error:0.01280
# [68]	train-logloss:0.01285	train-auc:0.99998	train-error:0.00165	val-logloss:0.02960	val-auc:0.99916	val-error:0.01281
# [69]	train-logloss:0.01244	train-auc:0.99998	train-error:0.00155	val-logloss:0.02974	val-auc:0.99916	val-error:0.01280
# [70]	train-logloss:0.01228	train-auc:0.99998	train-error:0.00152	val-logloss:0.02992	val-auc:0.99914	val-error:0.01283
# [71]	train-logloss:0.01196	train-auc:0.99998	train-error:0.00135	val-logloss:0.02997	val-auc:0.99914	val-error:0.01301
# [72]	train-logloss:0.01166	train-auc:0.99999	train-error:0.00127	val-logloss:0.02999	val-auc:0.99913	val-error:0.01313
# [73]	train-logloss:0.01131	train-auc:0.99999	train-error:0.00117	val-logloss:0.03023	val-auc:0.99912	val-error:0.01307
# [74]	train-logloss:0.01119	train-auc:0.99999	train-error:0.00118	val-logloss:0.03017	val-auc:0.99913	val-error:0.01307
# [75]	train-logloss:0.01084	train-auc:0.99999	train-error:0.00110	val-logloss:0.03031	val-auc:0.99913	val-error:0.01316
# [76]	train-logloss:0.01068	train-auc:0.99999	train-error:0.00106	val-logloss:0.03033	val-auc:0.99912	val-error:0.01312
# [77]	train-logloss:0.01051	train-auc:0.99999	train-error:0.00107	val-logloss:0.03044	val-auc:0.99911	val-error:0.01318
# [78]	train-logloss:0.01039	train-auc:0.99999	train-error:0.00105	val-logloss:0.03061	val-auc:0.99909	val-error:0.01328
# [79]	train-logloss:0.01011	train-auc:0.99999	train-error:0.00099	val-logloss:0.03089	val-auc:0.99909	val-error:0.01312
# [80]	train-logloss:0.00974	train-auc:0.99999	train-error:0.00081	val-logloss:0.03107	val-auc:0.99908	val-error:0.01364
# [81]	train-logloss:0.00962	train-auc:0.99999	train-error:0.00080	val-logloss:0.03113	val-auc:0.99907	val-error:0.01367
# [82]	train-logloss:0.00944	train-auc:0.99999	train-error:0.00074	val-logloss:0.03112	val-auc:0.99908	val-error:0.01366
# [83]	train-logloss:0.00923	train-auc:0.99999	train-error:0.00072	val-logloss:0.03109	val-auc:0.99907	val-error:0.01366
# [84]	train-logloss:0.00895	train-auc:1.00000	train-error:0.00067	val-logloss:0.03134	val-auc:0.99906	val-error:0.01358
# [85]	train-logloss:0.00885	train-auc:1.00000	train-error:0.00067	val-logloss:0.03145	val-auc:0.99904	val-error:0.01358
# [86]	train-logloss:0.00857	train-auc:1.00000	train-error:0.00062	val-logloss:0.03172	val-auc:0.99903	val-error:0.01365
# [87]	train-logloss:0.00848	train-auc:1.00000	train-error:0.00062	val-logloss:0.03186	val-auc:0.99902	val-error:0.01379
# [88]	train-logloss:0.00836	train-auc:1.00000	train-error:0.00055	val-logloss:0.03186	val-auc:0.99902	val-error:0.01379
# [89]	train-logloss:0.00825	train-auc:1.00000	train-error:0.00053	val-logloss:0.03203	val-auc:0.99900	val-error:0.01392
# [90]	train-logloss:0.00812	train-auc:1.00000	train-error:0.00045	val-logloss:0.03205	val-auc:0.99900	val-error:0.01366
# [91]	train-logloss:0.00792	train-auc:1.00000	train-error:0.00041	val-logloss:0.03223	val-auc:0.99899	val-error:0.01397
# [92]	train-logloss:0.00784	train-auc:1.00000	train-error:0.00042	val-logloss:0.03242	val-auc:0.99897	val-error:0.01404
# [93]	train-logloss:0.00772	train-auc:1.00000	train-error:0.00038	val-logloss:0.03240	val-auc:0.99897	val-error:0.01404
# XGBoost模型训练完成
# 完成时间20251216_020058
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9996 |     0.9861
# 精确率          |     0.9994 |     0.9745
# 召回率          |     0.9981 |     0.9274
# F1分数          |     0.9987 |     0.9504
# AUC            |     1.0000 |     0.9990
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99     96956
#      Class 1       0.97      0.93      0.95     16255
#
#     accuracy                           0.99    113211
#    macro avg       0.98      0.96      0.97    113211
# weighted avg       0.99      0.99      0.99    113211
#
#
# 验证集混淆矩阵:
# TN: 96562, FP: 394
# FN: 1180, TP: 15075
#
# 模型已保存为: Model_XGBoost_L500.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 1000
# 最佳迭代轮数: 44
# 最佳验证分数: 0.01173030889224545
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
# 序列窗口长度: 1000
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:04<00:00,  9.38seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 13.56seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 508072
# 验证样本数: 108211
# 训练集形状: X_train (508072, 2000), y_train (508072,)
# 验证集形状: X_val (108211, 2000), y_val (108211,)
# 特征维度: 2000 (序列长度1000 × 特征数2)
# 正样本比例 - 训练集: 0.1490, 验证集: 0.1502
# 类别权重 scale_pos_weight: 1.00
# 开始训练...
# [0]	train-logloss:0.35837	train-auc:0.99806	train-error:0.14898	val-logloss:0.35938	val-auc:0.99850	val-error:0.15022
# [1]	train-logloss:0.30962	train-auc:0.99881	train-error:0.14898	val-logloss:0.31372	val-auc:0.99852	val-error:0.15022
# [2]	train-logloss:0.27104	train-auc:0.99937	train-error:0.14898	val-logloss:0.27714	val-auc:0.99872	val-error:0.15022
# [3]	train-logloss:0.23946	train-auc:0.99952	train-error:0.14718	val-logloss:0.24716	val-auc:0.99879	val-error:0.15022
# [4]	train-logloss:0.21336	train-auc:0.99957	train-error:0.02829	val-logloss:0.22189	val-auc:0.99878	val-error:0.03470
# [5]	train-logloss:0.19097	train-auc:0.99965	train-error:0.01920	val-logloss:0.20017	val-auc:0.99883	val-error:0.03136
# [6]	train-logloss:0.17173	train-auc:0.99967	train-error:0.01237	val-logloss:0.18169	val-auc:0.99898	val-error:0.02515
# [7]	train-logloss:0.15503	train-auc:0.99970	train-error:0.00936	val-logloss:0.16597	val-auc:0.99900	val-error:0.02357
# [8]	train-logloss:0.14030	train-auc:0.99974	train-error:0.00725	val-logloss:0.15149	val-auc:0.99906	val-error:0.02229
# [9]	train-logloss:0.12726	train-auc:0.99976	train-error:0.00613	val-logloss:0.13889	val-auc:0.99909	val-error:0.02150
# [10]	train-logloss:0.11577	train-auc:0.99977	train-error:0.00546	val-logloss:0.12776	val-auc:0.99913	val-error:0.02000
# [11]	train-logloss:0.10551	train-auc:0.99978	train-error:0.00490	val-logloss:0.11790	val-auc:0.99914	val-error:0.01813
# [12]	train-logloss:0.09635	train-auc:0.99979	train-error:0.00452	val-logloss:0.10874	val-auc:0.99918	val-error:0.01657
# [13]	train-logloss:0.08817	train-auc:0.99980	train-error:0.00412	val-logloss:0.10067	val-auc:0.99921	val-error:0.01545
# [14]	train-logloss:0.08081	train-auc:0.99981	train-error:0.00386	val-logloss:0.09355	val-auc:0.99921	val-error:0.01487
# [15]	train-logloss:0.07409	train-auc:0.99983	train-error:0.00378	val-logloss:0.08721	val-auc:0.99921	val-error:0.01350
# [16]	train-logloss:0.06821	train-auc:0.99984	train-error:0.00359	val-logloss:0.08143	val-auc:0.99921	val-error:0.01309
# [17]	train-logloss:0.06283	train-auc:0.99985	train-error:0.00352	val-logloss:0.07645	val-auc:0.99922	val-error:0.01327
# [18]	train-logloss:0.05800	train-auc:0.99987	train-error:0.00324	val-logloss:0.07184	val-auc:0.99924	val-error:0.01283
# [19]	train-logloss:0.05361	train-auc:0.99987	train-error:0.00313	val-logloss:0.06799	val-auc:0.99922	val-error:0.01253
# [20]	train-logloss:0.04962	train-auc:0.99988	train-error:0.00286	val-logloss:0.06366	val-auc:0.99926	val-error:0.01192
# [21]	train-logloss:0.04604	train-auc:0.99989	train-error:0.00278	val-logloss:0.06021	val-auc:0.99928	val-error:0.01200
# [22]	train-logloss:0.04283	train-auc:0.99989	train-error:0.00278	val-logloss:0.05738	val-auc:0.99929	val-error:0.01212
# [23]	train-logloss:0.03987	train-auc:0.99991	train-error:0.00279	val-logloss:0.05474	val-auc:0.99929	val-error:0.01210
# [24]	train-logloss:0.03722	train-auc:0.99991	train-error:0.00275	val-logloss:0.05239	val-auc:0.99930	val-error:0.01231
# [25]	train-logloss:0.03482	train-auc:0.99991	train-error:0.00269	val-logloss:0.05029	val-auc:0.99930	val-error:0.01261
# [26]	train-logloss:0.03266	train-auc:0.99991	train-error:0.00268	val-logloss:0.04829	val-auc:0.99930	val-error:0.01239
# [27]	train-logloss:0.03072	train-auc:0.99991	train-error:0.00269	val-logloss:0.04655	val-auc:0.99930	val-error:0.01233
# [28]	train-logloss:0.02883	train-auc:0.99992	train-error:0.00267	val-logloss:0.04528	val-auc:0.99930	val-error:0.01248
# [29]	train-logloss:0.02726	train-auc:0.99992	train-error:0.00269	val-logloss:0.04394	val-auc:0.99931	val-error:0.01254
# [30]	train-logloss:0.02557	train-auc:0.99993	train-error:0.00234	val-logloss:0.04309	val-auc:0.99928	val-error:0.01260
# [31]	train-logloss:0.02428	train-auc:0.99994	train-error:0.00235	val-logloss:0.04175	val-auc:0.99929	val-error:0.01243
# [32]	train-logloss:0.02302	train-auc:0.99994	train-error:0.00229	val-logloss:0.04067	val-auc:0.99929	val-error:0.01242
# [33]	train-logloss:0.02175	train-auc:0.99995	train-error:0.00224	val-logloss:0.04000	val-auc:0.99927	val-error:0.01252
# [34]	train-logloss:0.02058	train-auc:0.99995	train-error:0.00221	val-logloss:0.03951	val-auc:0.99926	val-error:0.01228
# [35]	train-logloss:0.01955	train-auc:0.99996	train-error:0.00223	val-logloss:0.03894	val-auc:0.99926	val-error:0.01231
# [36]	train-logloss:0.01851	train-auc:0.99996	train-error:0.00210	val-logloss:0.03831	val-auc:0.99926	val-error:0.01260
# [37]	train-logloss:0.01763	train-auc:0.99996	train-error:0.00206	val-logloss:0.03754	val-auc:0.99927	val-error:0.01216
# [38]	train-logloss:0.01692	train-auc:0.99996	train-error:0.00204	val-logloss:0.03691	val-auc:0.99927	val-error:0.01247
# [39]	train-logloss:0.01624	train-auc:0.99997	train-error:0.00196	val-logloss:0.03650	val-auc:0.99928	val-error:0.01261
# [40]	train-logloss:0.01563	train-auc:0.99997	train-error:0.00183	val-logloss:0.03625	val-auc:0.99927	val-error:0.01250
# [41]	train-logloss:0.01498	train-auc:0.99997	train-error:0.00174	val-logloss:0.03567	val-auc:0.99928	val-error:0.01254
# [42]	train-logloss:0.01442	train-auc:0.99997	train-error:0.00173	val-logloss:0.03536	val-auc:0.99928	val-error:0.01250
# [43]	train-logloss:0.01384	train-auc:0.99997	train-error:0.00167	val-logloss:0.03481	val-auc:0.99929	val-error:0.01263
# [44]	train-logloss:0.01335	train-auc:0.99997	train-error:0.00164	val-logloss:0.03470	val-auc:0.99928	val-error:0.01299
# [45]	train-logloss:0.01292	train-auc:0.99998	train-error:0.00156	val-logloss:0.03454	val-auc:0.99928	val-error:0.01309
# [46]	train-logloss:0.01253	train-auc:0.99998	train-error:0.00155	val-logloss:0.03434	val-auc:0.99928	val-error:0.01295
# [47]	train-logloss:0.01211	train-auc:0.99998	train-error:0.00152	val-logloss:0.03384	val-auc:0.99928	val-error:0.01300
# [48]	train-logloss:0.01158	train-auc:0.99998	train-error:0.00138	val-logloss:0.03345	val-auc:0.99928	val-error:0.01256
# [49]	train-logloss:0.01127	train-auc:0.99998	train-error:0.00137	val-logloss:0.03348	val-auc:0.99928	val-error:0.01227
# [50]	train-logloss:0.01098	train-auc:0.99998	train-error:0.00135	val-logloss:0.03341	val-auc:0.99927	val-error:0.01227
# [51]	train-logloss:0.01073	train-auc:0.99998	train-error:0.00134	val-logloss:0.03343	val-auc:0.99927	val-error:0.01240
# [52]	train-logloss:0.01047	train-auc:0.99998	train-error:0.00133	val-logloss:0.03353	val-auc:0.99926	val-error:0.01325
# [53]	train-logloss:0.01019	train-auc:0.99998	train-error:0.00129	val-logloss:0.03323	val-auc:0.99926	val-error:0.01306
# [54]	train-logloss:0.00975	train-auc:0.99999	train-error:0.00106	val-logloss:0.03283	val-auc:0.99928	val-error:0.01255
# [55]	train-logloss:0.00940	train-auc:0.99999	train-error:0.00097	val-logloss:0.03292	val-auc:0.99927	val-error:0.01246
# [56]	train-logloss:0.00898	train-auc:0.99999	train-error:0.00083	val-logloss:0.03316	val-auc:0.99926	val-error:0.01246
# [57]	train-logloss:0.00861	train-auc:0.99999	train-error:0.00079	val-logloss:0.03319	val-auc:0.99926	val-error:0.01242
# [58]	train-logloss:0.00840	train-auc:0.99999	train-error:0.00076	val-logloss:0.03307	val-auc:0.99926	val-error:0.01240
# [59]	train-logloss:0.00824	train-auc:0.99999	train-error:0.00077	val-logloss:0.03318	val-auc:0.99925	val-error:0.01267
# [60]	train-logloss:0.00804	train-auc:0.99999	train-error:0.00075	val-logloss:0.03354	val-auc:0.99923	val-error:0.01292
# [61]	train-logloss:0.00785	train-auc:0.99999	train-error:0.00071	val-logloss:0.03344	val-auc:0.99923	val-error:0.01301
# [62]	train-logloss:0.00770	train-auc:0.99999	train-error:0.00070	val-logloss:0.03363	val-auc:0.99923	val-error:0.01338
# [63]	train-logloss:0.00752	train-auc:1.00000	train-error:0.00066	val-logloss:0.03361	val-auc:0.99922	val-error:0.01346
# [64]	train-logloss:0.00733	train-auc:1.00000	train-error:0.00063	val-logloss:0.03382	val-auc:0.99921	val-error:0.01342
# [65]	train-logloss:0.00715	train-auc:1.00000	train-error:0.00060	val-logloss:0.03405	val-auc:0.99919	val-error:0.01349
# [66]	train-logloss:0.00689	train-auc:1.00000	train-error:0.00056	val-logloss:0.03393	val-auc:0.99919	val-error:0.01341
# [67]	train-logloss:0.00679	train-auc:1.00000	train-error:0.00055	val-logloss:0.03409	val-auc:0.99919	val-error:0.01358
# [68]	train-logloss:0.00667	train-auc:1.00000	train-error:0.00054	val-logloss:0.03423	val-auc:0.99918	val-error:0.01366
# [69]	train-logloss:0.00644	train-auc:1.00000	train-error:0.00051	val-logloss:0.03455	val-auc:0.99918	val-error:0.01351
# [70]	train-logloss:0.00629	train-auc:1.00000	train-error:0.00048	val-logloss:0.03482	val-auc:0.99918	val-error:0.01396
# XGBoost模型训练完成
# 完成时间20251216_020114
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9995 |     0.9860
# 精确率          |     0.9989 |     0.9838
# 召回率          |     0.9978 |     0.9222
# F1分数          |     0.9984 |     0.9520
# AUC            |     1.0000 |     0.9992
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99     91956
#      Class 1       0.98      0.92      0.95     16255
#
#     accuracy                           0.99    108211
#    macro avg       0.99      0.96      0.97    108211
# weighted avg       0.99      0.99      0.99    108211
#
#
# 验证集混淆矩阵:
# TN: 91709, FP: 247
# FN: 1264, TP: 14991
#
# 模型已保存为: Model_XGBoost_L1000.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 2000
# 最佳迭代轮数: 20
# 最佳验证分数: 0.01192115404164087
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
# 序列窗口长度: 1500
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:05<00:00,  7.92seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 11.11seq/s]
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成
# 训练样本数: 485572
# 验证样本数: 103211
# 训练集形状: X_train (485572, 3000), y_train (485572,)
# 验证集形状: X_val (103211, 3000), y_val (103211,)
# 特征维度: 3000 (序列长度1500 × 特征数2)
# 正样本比例 - 训练集: 0.1559, 验证集: 0.1575
# 类别权重 scale_pos_weight: 1.00
# 开始训练...
# [0]	train-logloss:0.36592	train-auc:0.99787	train-error:0.15589	val-logloss:0.37077	val-auc:0.99500	val-error:0.15749
# [1]	train-logloss:0.31471	train-auc:0.99942	train-error:0.15589	val-logloss:0.32258	val-auc:0.99691	val-error:0.15749
# [2]	train-logloss:0.27529	train-auc:0.99968	train-error:0.15589	val-logloss:0.28527	val-auc:0.99672	val-error:0.15749
# [3]	train-logloss:0.24289	train-auc:0.99970	train-error:0.15581	val-logloss:0.25511	val-auc:0.99818	val-error:0.15749
# [4]	train-logloss:0.21573	train-auc:0.99977	train-error:0.01881	val-logloss:0.22934	val-auc:0.99819	val-error:0.03447
# [5]	train-logloss:0.19252	train-auc:0.99979	train-error:0.01144	val-logloss:0.20740	val-auc:0.99835	val-error:0.02955
# [6]	train-logloss:0.17263	train-auc:0.99983	train-error:0.00813	val-logloss:0.18819	val-auc:0.99846	val-error:0.02178
# [7]	train-logloss:0.15526	train-auc:0.99986	train-error:0.00600	val-logloss:0.17130	val-auc:0.99859	val-error:0.01936
# [8]	train-logloss:0.14016	train-auc:0.99987	train-error:0.00520	val-logloss:0.15693	val-auc:0.99867	val-error:0.01920
# [9]	train-logloss:0.12688	train-auc:0.99988	train-error:0.00470	val-logloss:0.14502	val-auc:0.99865	val-error:0.01791
# [10]	train-logloss:0.11509	train-auc:0.99989	train-error:0.00412	val-logloss:0.13331	val-auc:0.99871	val-error:0.01708
# [11]	train-logloss:0.10446	train-auc:0.99991	train-error:0.00393	val-logloss:0.12304	val-auc:0.99875	val-error:0.01711
# [12]	train-logloss:0.09508	train-auc:0.99992	train-error:0.00374	val-logloss:0.11588	val-auc:0.99866	val-error:0.01699
# [13]	train-logloss:0.08672	train-auc:0.99992	train-error:0.00339	val-logloss:0.10743	val-auc:0.99875	val-error:0.01596
# [14]	train-logloss:0.07917	train-auc:0.99993	train-error:0.00276	val-logloss:0.10111	val-auc:0.99872	val-error:0.01633
# [15]	train-logloss:0.07249	train-auc:0.99994	train-error:0.00240	val-logloss:0.09577	val-auc:0.99868	val-error:0.01584
# [16]	train-logloss:0.06632	train-auc:0.99995	train-error:0.00227	val-logloss:0.08892	val-auc:0.99879	val-error:0.01549
# [17]	train-logloss:0.06082	train-auc:0.99996	train-error:0.00201	val-logloss:0.08454	val-auc:0.99881	val-error:0.01559
# [18]	train-logloss:0.05561	train-auc:0.99997	train-error:0.00168	val-logloss:0.07948	val-auc:0.99888	val-error:0.01458
# [19]	train-logloss:0.05097	train-auc:0.99998	train-error:0.00159	val-logloss:0.07653	val-auc:0.99880	val-error:0.01557
# [20]	train-logloss:0.04682	train-auc:0.99998	train-error:0.00139	val-logloss:0.07225	val-auc:0.99886	val-error:0.01422
# [21]	train-logloss:0.04317	train-auc:0.99998	train-error:0.00139	val-logloss:0.06815	val-auc:0.99889	val-error:0.01397
# [22]	train-logloss:0.03979	train-auc:0.99998	train-error:0.00129	val-logloss:0.06622	val-auc:0.99883	val-error:0.01453
# [23]	train-logloss:0.03683	train-auc:0.99998	train-error:0.00130	val-logloss:0.06284	val-auc:0.99888	val-error:0.01415
# [24]	train-logloss:0.03396	train-auc:0.99999	train-error:0.00103	val-logloss:0.06007	val-auc:0.99887	val-error:0.01386
# [25]	train-logloss:0.03147	train-auc:0.99999	train-error:0.00100	val-logloss:0.05711	val-auc:0.99891	val-error:0.01400
# [26]	train-logloss:0.02929	train-auc:0.99999	train-error:0.00104	val-logloss:0.05545	val-auc:0.99894	val-error:0.01385
# [27]	train-logloss:0.02734	train-auc:0.99999	train-error:0.00107	val-logloss:0.05350	val-auc:0.99897	val-error:0.01334
# [28]	train-logloss:0.02543	train-auc:0.99999	train-error:0.00091	val-logloss:0.05151	val-auc:0.99897	val-error:0.01382
# [29]	train-logloss:0.02377	train-auc:0.99999	train-error:0.00092	val-logloss:0.04937	val-auc:0.99902	val-error:0.01315
# [30]	train-logloss:0.02215	train-auc:0.99999	train-error:0.00086	val-logloss:0.04810	val-auc:0.99900	val-error:0.01314
# [31]	train-logloss:0.02062	train-auc:0.99999	train-error:0.00075	val-logloss:0.04719	val-auc:0.99895	val-error:0.01299
# [32]	train-logloss:0.01939	train-auc:0.99999	train-error:0.00068	val-logloss:0.04572	val-auc:0.99899	val-error:0.01289
# [33]	train-logloss:0.01821	train-auc:0.99999	train-error:0.00067	val-logloss:0.04465	val-auc:0.99898	val-error:0.01285
# [34]	train-logloss:0.01713	train-auc:0.99999	train-error:0.00067	val-logloss:0.04329	val-auc:0.99902	val-error:0.01276
# [35]	train-logloss:0.01602	train-auc:0.99999	train-error:0.00060	val-logloss:0.04280	val-auc:0.99898	val-error:0.01238
# [36]	train-logloss:0.01515	train-auc:0.99999	train-error:0.00060	val-logloss:0.04203	val-auc:0.99899	val-error:0.01231
# [37]	train-logloss:0.01436	train-auc:0.99999	train-error:0.00060	val-logloss:0.04099	val-auc:0.99902	val-error:0.01223
# [38]	train-logloss:0.01346	train-auc:1.00000	train-error:0.00051	val-logloss:0.04064	val-auc:0.99900	val-error:0.01257
# [39]	train-logloss:0.01273	train-auc:1.00000	train-error:0.00050	val-logloss:0.03977	val-auc:0.99900	val-error:0.01236
# [40]	train-logloss:0.01210	train-auc:1.00000	train-error:0.00050	val-logloss:0.03925	val-auc:0.99900	val-error:0.01245
# [41]	train-logloss:0.01155	train-auc:1.00000	train-error:0.00050	val-logloss:0.03851	val-auc:0.99902	val-error:0.01229
# [42]	train-logloss:0.01103	train-auc:1.00000	train-error:0.00050	val-logloss:0.03815	val-auc:0.99902	val-error:0.01255
# [43]	train-logloss:0.01045	train-auc:1.00000	train-error:0.00046	val-logloss:0.03848	val-auc:0.99898	val-error:0.01241
# [44]	train-logloss:0.00991	train-auc:1.00000	train-error:0.00040	val-logloss:0.03816	val-auc:0.99897	val-error:0.01237
# [45]	train-logloss:0.00951	train-auc:1.00000	train-error:0.00045	val-logloss:0.03776	val-auc:0.99899	val-error:0.01250
# [46]	train-logloss:0.00913	train-auc:1.00000	train-error:0.00042	val-logloss:0.03730	val-auc:0.99901	val-error:0.01270
# [47]	train-logloss:0.00870	train-auc:1.00000	train-error:0.00042	val-logloss:0.03644	val-auc:0.99905	val-error:0.01256
# [48]	train-logloss:0.00826	train-auc:1.00000	train-error:0.00038	val-logloss:0.03669	val-auc:0.99904	val-error:0.01239
# [49]	train-logloss:0.00792	train-auc:1.00000	train-error:0.00036	val-logloss:0.03654	val-auc:0.99904	val-error:0.01239
# [50]	train-logloss:0.00766	train-auc:1.00000	train-error:0.00039	val-logloss:0.03634	val-auc:0.99905	val-error:0.01229
# [51]	train-logloss:0.00740	train-auc:1.00000	train-error:0.00034	val-logloss:0.03628	val-auc:0.99904	val-error:0.01235
# [52]	train-logloss:0.00718	train-auc:1.00000	train-error:0.00034	val-logloss:0.03631	val-auc:0.99904	val-error:0.01262
# [53]	train-logloss:0.00680	train-auc:1.00000	train-error:0.00032	val-logloss:0.03621	val-auc:0.99902	val-error:0.01253
# [54]	train-logloss:0.00655	train-auc:1.00000	train-error:0.00030	val-logloss:0.03632	val-auc:0.99902	val-error:0.01269
# [55]	train-logloss:0.00640	train-auc:1.00000	train-error:0.00029	val-logloss:0.03634	val-auc:0.99903	val-error:0.01286
# [56]	train-logloss:0.00616	train-auc:1.00000	train-error:0.00027	val-logloss:0.03635	val-auc:0.99901	val-error:0.01259
# [57]	train-logloss:0.00600	train-auc:1.00000	train-error:0.00027	val-logloss:0.03629	val-auc:0.99902	val-error:0.01272
# [58]	train-logloss:0.00577	train-auc:1.00000	train-error:0.00026	val-logloss:0.03635	val-auc:0.99900	val-error:0.01292
# [59]	train-logloss:0.00566	train-auc:1.00000	train-error:0.00026	val-logloss:0.03636	val-auc:0.99900	val-error:0.01293
# [60]	train-logloss:0.00548	train-auc:1.00000	train-error:0.00026	val-logloss:0.03653	val-auc:0.99898	val-error:0.01281
# [61]	train-logloss:0.00523	train-auc:1.00000	train-error:0.00020	val-logloss:0.03638	val-auc:0.99898	val-error:0.01221
# [62]	train-logloss:0.00498	train-auc:1.00000	train-error:0.00018	val-logloss:0.03650	val-auc:0.99898	val-error:0.01238
# [63]	train-logloss:0.00480	train-auc:1.00000	train-error:0.00016	val-logloss:0.03674	val-auc:0.99896	val-error:0.01214
# [64]	train-logloss:0.00468	train-auc:1.00000	train-error:0.00015	val-logloss:0.03695	val-auc:0.99895	val-error:0.01236
# [65]	train-logloss:0.00460	train-auc:1.00000	train-error:0.00015	val-logloss:0.03693	val-auc:0.99896	val-error:0.01233
# [66]	train-logloss:0.00447	train-auc:1.00000	train-error:0.00015	val-logloss:0.03681	val-auc:0.99897	val-error:0.01246
# [67]	train-logloss:0.00438	train-auc:1.00000	train-error:0.00014	val-logloss:0.03712	val-auc:0.99898	val-error:0.01266
# [68]	train-logloss:0.00419	train-auc:1.00000	train-error:0.00012	val-logloss:0.03700	val-auc:0.99897	val-error:0.01224
# [69]	train-logloss:0.00406	train-auc:1.00000	train-error:0.00011	val-logloss:0.03702	val-auc:0.99897	val-error:0.01184
# [70]	train-logloss:0.00396	train-auc:1.00000	train-error:0.00010	val-logloss:0.03703	val-auc:0.99897	val-error:0.01185
# [71]	train-logloss:0.00389	train-auc:1.00000	train-error:0.00010	val-logloss:0.03737	val-auc:0.99897	val-error:0.01221
# [72]	train-logloss:0.00382	train-auc:1.00000	train-error:0.00010	val-logloss:0.03753	val-auc:0.99895	val-error:0.01220
# [73]	train-logloss:0.00370	train-auc:1.00000	train-error:0.00011	val-logloss:0.03747	val-auc:0.99896	val-error:0.01202
# [74]	train-logloss:0.00362	train-auc:1.00000	train-error:0.00011	val-logloss:0.03750	val-auc:0.99897	val-error:0.01222
# [75]	train-logloss:0.00356	train-auc:1.00000	train-error:0.00009	val-logloss:0.03767	val-auc:0.99896	val-error:0.01213
# [76]	train-logloss:0.00348	train-auc:1.00000	train-error:0.00009	val-logloss:0.03750	val-auc:0.99897	val-error:0.01206
# [77]	train-logloss:0.00329	train-auc:1.00000	train-error:0.00007	val-logloss:0.03812	val-auc:0.99895	val-error:0.01244
# [78]	train-logloss:0.00317	train-auc:1.00000	train-error:0.00005	val-logloss:0.03842	val-auc:0.99894	val-error:0.01222
# [79]	train-logloss:0.00300	train-auc:1.00000	train-error:0.00004	val-logloss:0.03906	val-auc:0.99891	val-error:0.01295
# [80]	train-logloss:0.00295	train-auc:1.00000	train-error:0.00004	val-logloss:0.03930	val-auc:0.99891	val-error:0.01334
# [81]	train-logloss:0.00278	train-auc:1.00000	train-error:0.00004	val-logloss:0.03969	val-auc:0.99891	val-error:0.01359
# [82]	train-logloss:0.00266	train-auc:1.00000	train-error:0.00003	val-logloss:0.04004	val-auc:0.99890	val-error:0.01374
# [83]	train-logloss:0.00261	train-auc:1.00000	train-error:0.00004	val-logloss:0.04046	val-auc:0.99890	val-error:0.01412
# [84]	train-logloss:0.00251	train-auc:1.00000	train-error:0.00003	val-logloss:0.04084	val-auc:0.99888	val-error:0.01416
# [85]	train-logloss:0.00245	train-auc:1.00000	train-error:0.00003	val-logloss:0.04091	val-auc:0.99889	val-error:0.01448
# [86]	train-logloss:0.00239	train-auc:1.00000	train-error:0.00003	val-logloss:0.04103	val-auc:0.99889	val-error:0.01487
# [87]	train-logloss:0.00229	train-auc:1.00000	train-error:0.00003	val-logloss:0.04156	val-auc:0.99888	val-error:0.01565
# [88]	train-logloss:0.00219	train-auc:1.00000	train-error:0.00003	val-logloss:0.04189	val-auc:0.99887	val-error:0.01539
# [89]	train-logloss:0.00208	train-auc:1.00000	train-error:0.00002	val-logloss:0.04213	val-auc:0.99886	val-error:0.01559
# [90]	train-logloss:0.00202	train-auc:1.00000	train-error:0.00002	val-logloss:0.04216	val-auc:0.99887	val-error:0.01549
# [91]	train-logloss:0.00195	train-auc:1.00000	train-error:0.00002	val-logloss:0.04226	val-auc:0.99888	val-error:0.01543
# [92]	train-logloss:0.00187	train-auc:1.00000	train-error:0.00001	val-logloss:0.04293	val-auc:0.99885	val-error:0.01573
# [93]	train-logloss:0.00183	train-auc:1.00000	train-error:0.00001	val-logloss:0.04332	val-auc:0.99884	val-error:0.01596
# [94]	train-logloss:0.00180	train-auc:1.00000	train-error:0.00001	val-logloss:0.04375	val-auc:0.99883	val-error:0.01629
# [95]	train-logloss:0.00176	train-auc:1.00000	train-error:0.00001	val-logloss:0.04413	val-auc:0.99881	val-error:0.01635
# [96]	train-logloss:0.00168	train-auc:1.00000	train-error:0.00001	val-logloss:0.04452	val-auc:0.99882	val-error:0.01680
# [97]	train-logloss:0.00163	train-auc:1.00000	train-error:0.00001	val-logloss:0.04458	val-auc:0.99882	val-error:0.01671
# [98]	train-logloss:0.00157	train-auc:1.00000	train-error:0.00001	val-logloss:0.04476	val-auc:0.99881	val-error:0.01705
# [99]	train-logloss:0.00150	train-auc:1.00000	train-error:0.00000	val-logloss:0.04461	val-auc:0.99881	val-error:0.01666
# [100]	train-logloss:0.00147	train-auc:1.00000	train-error:0.00000	val-logloss:0.04530	val-auc:0.99879	val-error:0.01688
# [101]	train-logloss:0.00145	train-auc:1.00000	train-error:0.00000	val-logloss:0.04583	val-auc:0.99878	val-error:0.01744
# [102]	train-logloss:0.00142	train-auc:1.00000	train-error:0.00000	val-logloss:0.04592	val-auc:0.99878	val-error:0.01746
# [103]	train-logloss:0.00139	train-auc:1.00000	train-error:0.00000	val-logloss:0.04626	val-auc:0.99877	val-error:0.01748
# [104]	train-logloss:0.00135	train-auc:1.00000	train-error:0.00000	val-logloss:0.04629	val-auc:0.99877	val-error:0.01739
# [105]	train-logloss:0.00131	train-auc:1.00000	train-error:0.00000	val-logloss:0.04645	val-auc:0.99876	val-error:0.01738
# [106]	train-logloss:0.00125	train-auc:1.00000	train-error:0.00000	val-logloss:0.04679	val-auc:0.99875	val-error:0.01719
# [107]	train-logloss:0.00120	train-auc:1.00000	train-error:0.00000	val-logloss:0.04710	val-auc:0.99875	val-error:0.01740
# [108]	train-logloss:0.00117	train-auc:1.00000	train-error:0.00000	val-logloss:0.04730	val-auc:0.99874	val-error:0.01747
# [109]	train-logloss:0.00114	train-auc:1.00000	train-error:0.00000	val-logloss:0.04767	val-auc:0.99873	val-error:0.01765
# [110]	train-logloss:0.00111	train-auc:1.00000	train-error:0.00000	val-logloss:0.04804	val-auc:0.99872	val-error:0.01782
# [111]	train-logloss:0.00106	train-auc:1.00000	train-error:0.00000	val-logloss:0.04863	val-auc:0.99870	val-error:0.01807
# [112]	train-logloss:0.00104	train-auc:1.00000	train-error:0.00000	val-logloss:0.04884	val-auc:0.99869	val-error:0.01809
# [113]	train-logloss:0.00102	train-auc:1.00000	train-error:0.00000	val-logloss:0.04909	val-auc:0.99868	val-error:0.01812
# [114]	train-logloss:0.00100	train-auc:1.00000	train-error:0.00000	val-logloss:0.04878	val-auc:0.99869	val-error:0.01801
# [115]	train-logloss:0.00098	train-auc:1.00000	train-error:0.00000	val-logloss:0.04907	val-auc:0.99868	val-error:0.01796
# [116]	train-logloss:0.00094	train-auc:1.00000	train-error:0.00000	val-logloss:0.04904	val-auc:0.99869	val-error:0.01814
# [117]	train-logloss:0.00091	train-auc:1.00000	train-error:0.00000	val-logloss:0.04952	val-auc:0.99868	val-error:0.01823
# [118]	train-logloss:0.00089	train-auc:1.00000	train-error:0.00000	val-logloss:0.04963	val-auc:0.99868	val-error:0.01815
# XGBoost模型训练完成
# 完成时间20251216_020138
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     1.0000 |     0.9817
# 精确率          |     1.0000 |     0.9785
# 召回率          |     1.0000 |     0.9035
# F1分数          |     1.0000 |     0.9395
# AUC            |     1.0000 |     0.9987
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      1.00      0.99     86956
#      Class 1       0.98      0.90      0.94     16255
#
#     accuracy                           0.98    103211
#    macro avg       0.98      0.95      0.96    103211
# weighted avg       0.98      0.98      0.98    103211
#
#
# 验证集混淆矩阵:
# TN: 86634, FP: 322
# FN: 1568, TP: 14687
#
# 模型已保存为: Model_XGBoost_L1500.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 3000
# 最佳迭代轮数: 69
# 最佳验证分数: 0.01183982327465096
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
