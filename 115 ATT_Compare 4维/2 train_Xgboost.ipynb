# %%
#数据预处理
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

sequence_length = 500 # 模型查看的历史窗口大小
prediction_horizon = 1 # 预测的未来窗口大小

directory = "../datas/train" #数据目录
all_items = os.listdir(directory)  #列出目录下所有文件
csv_files = [os.path.join(directory, item) for item in all_items if item.endswith('.csv') and os.path.isfile(os.path.join(directory, item))]  #筛选出CSV文件 
Sample_size = len(csv_files)  #获取样本数量

sequences_data = [] #创建一个空列表，用于存储所有序列的数据
scalers = {} #创建一个空字典，用于存储每个序列对应的标准化器
base_features = ['Voltage', 'Current']
new_features = ['impedance', 'power']
features = base_features + new_features

for file in csv_files:
    df = pd.read_csv(file)
    df['impedance'] = df['Voltage'] * 1000 / df['Current'].replace(0, np.nan)
    df['power'] = df['Voltage'] * (df['Current'] / 1000)
    # df['cumulative_power'] = (df['power']/1000).cumsum()
    # df['impedance_diff'] = df['impedance'].diff().fillna(0) #添加一阶差分
    # df['impedance_rolling_mean'] = df['impedance'].rolling(window=20, min_periods=1).mean() #滚动均值
    # df['impedance_rolling_std'] = df['impedance'].rolling(window=20, min_periods=1).std()  #滚动标准差
    # df['impedance_slope_10'] = df['impedance'].diff(10) / 10  #过去 10 个时间点的平均变化率。
    # df['impedance_slope_10'] = df['impedance_slope_10'].fillna(0) # 将该列中的所有缺失值（NaN）填充为数字0
    df = df.ffill().bfill()  #缺失值处理先用前向填充，再用后向填充
    #数据预处理 数值归一化
    scaler = StandardScaler() #为当前序列创建一个新的StandardScaler实例
    df.loc[:, features] = scaler.fit_transform(df.loc[:, features]) #对当前序列的指定特征列进行拟合和转换
    scalers[file] = scaler #将当前序列的标准化器保存到字典中，键为序列ID
    sequences_data.append(df[features + ['Action']].values) #将当前序列的数组数据添加到结果列表中

train_sequences, val_sequences = train_test_split(sequences_data, test_size=0.18, random_state=42)

print(f'检索到{Sample_size}个样本')
print(f"特征数量: {len(features)}")
print(f"序列数量: {len(sequences_data)}")
print(f"训练序列: {len(train_sequences)}")
print(f"验证序列: {len(val_sequences)}") 
# print(f"训练样本数: {len(train_dataset)}")
# print(f"验证样本数: {len(val_dataset)}")
# Out:
# 检索到55个样本
# 特征数量: 4
# 序列数量: 55
# 训练序列: 45
# 验证序列: 10

# %%
import xgboost as xgb
from tqdm import tqdm

def create_xgboost_data(sequences_data, sequence_length, prediction_horizon):
    X_list = []
    y_list = []
    
    for seq_data in tqdm(sequences_data, desc="处理序列", unit="seq", ncols=60):
        n_samples = len(seq_data) - sequence_length - prediction_horizon + 1
        
        for i in range(n_samples):
            # 提取特征
            x = seq_data[i:i + sequence_length, :-1].flatten()  # 展平为1D向量
            X_list.append(x)
            
            # 提取标签
            y_window = seq_data[i + sequence_length:i + sequence_length + prediction_horizon, -1]
            y = 1 if np.any(y_window == 1) else 0
            y_list.append(y)
    
    return np.array(X_list), np.array(y_list)

print("生成训练数据...")
X_train, y_train = create_xgboost_data(train_sequences, sequence_length, prediction_horizon)
X_val, y_val = create_xgboost_data(val_sequences, sequence_length, prediction_horizon)
# 从float64转化为float32
# X_train = X_train.astype(np.float32)
# y_val = X_val.astype(np.float32)

# 计算类别权重（处理不平衡数据）
# if np.sum(y_train) > 0:
#     scale_pos_weight = (len(y_train) - np.sum(y_train)) / np.sum(y_train)
# else:
#     scale_pos_weight = 1.0
#     print("警告: 训练集中没有正样本!")
scale_pos_weight = 1.0
    
print(f"训练样本数: {len(X_train)}")
print(f"验证样本数: {len(X_val)}")
print(f"训练集形状: X_train {X_train.shape}, y_train {y_train.shape}")
print(f"验证集形状: X_val {X_val.shape}, y_val {y_val.shape}")
print(f"特征维度: {X_train.shape[1]} (序列长度{sequence_length} × 特征数{len(features)})")
print(f"正样本比例 - 训练集: {np.mean(y_train):.4f}, 验证集: {np.mean(y_val):.4f}")
print(f"类别权重 scale_pos_weight: {scale_pos_weight:.2f}")
# Out:
# 生成训练数据...
# 处理序列: 100%|████████████| 45/45 [00:04<00:00,  9.42seq/s]
# 处理序列: 100%|████████████| 10/10 [00:00<00:00, 17.56seq/s]
# 训练样本数: 530572
# 验证样本数: 113211
# 训练集形状: X_train (530572, 2000), y_train (530572,)
# 验证集形状: X_val (113211, 2000), y_val (113211,)
# 特征维度: 2000 (序列长度500 × 特征数4)
# 正样本比例 - 训练集: 0.1427, 验证集: 0.1436
# 类别权重 scale_pos_weight: 1.00

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report, confusion_matrix
import joblib
from sklearn.datasets import dump_svmlight_file
import warnings
warnings.filterwarnings('ignore')

model_name = 'XGBoost'
num_boost_round=1000

# 定义XGBoost模型参数
params = {
    'tree_method': 'hist',  # 使用GPU直方图算法
    'device': 'cuda',           # 指定使用CUDA设备
    'max_bin': 256,                 # 直方图分桶数，GPU上256是常用值，可在速度和精度间权衡
    'objective': 'binary:logistic',  # 根据你的问题调整
    'eval_metric': ['logloss', 'auc', 'error'],
    'learning_rate': 0.1,
    'max_depth': 6,
    'random_state': 42,
    'reg_alpha': 0.1,
    'reg_lambda': 1.0,
    'gamma': 0.1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'colsample_bylevel': 0.8,   # 每层特征采样
    'colsample_bynode': 0.8,    # 每个节点特征采样
    'scale_pos_weight': scale_pos_weight,
    'verbosity': 1,  # 新版本推荐用法
}
print("XGBoost模型配置完成")
print("创建DMatrix...")
dtrain = xgb.QuantileDMatrix(X_train, label=y_train, max_bin=params['max_bin'])
dval = xgb.QuantileDMatrix(X_val, label=y_val, max_bin=params['max_bin'], ref=dtrain) # ref引用dtrain的分位数
print("创建DMatrix完成")
# Out:
# XGBoost模型配置完成
# 创建DMatrix...
# 创建DMatrix完成

# %%
# 训练模型
from datetime import datetime

print("开始训练...")
eval_history = {}
# 使用原生接口训练
model = xgb.train(
    params, dtrain,
    num_boost_round,
    evals=[(dtrain, 'train'),(dval, 'val')],  # 这里使用 evals
    early_stopping_rounds=50,
    evals_result=eval_history,  # 这里使用 evals_result
    verbose_eval=True
)
print("XGBoost模型训练完成")
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
print(f"完成时间{timestamp}")
# Out:
# 开始训练...
# [0]	train-logloss:0.38382	train-auc:0.92084	train-error:0.14267	val-logloss:0.38631	val-auc:0.92816	val-error:0.14358
# [1]	train-logloss:0.35765	train-auc:0.93323	train-error:0.14267	val-logloss:0.36400	val-auc:0.92727	val-error:0.14358
# [2]	train-logloss:0.33613	train-auc:0.93791	train-error:0.14267	val-logloss:0.34680	val-auc:0.92773	val-error:0.14358
# [3]	train-logloss:0.31830	train-auc:0.94196	train-error:0.14189	val-logloss:0.33016	val-auc:0.93159	val-error:0.14394
# [4]	train-logloss:0.30300	train-auc:0.94458	train-error:0.13579	val-logloss:0.31684	val-auc:0.93124	val-error:0.13444
# [5]	train-logloss:0.28927	train-auc:0.95009	train-error:0.11601	val-logloss:0.30428	val-auc:0.93466	val-error:0.11562
# [6]	train-logloss:0.27646	train-auc:0.95353	train-error:0.11148	val-logloss:0.29392	val-auc:0.93484	val-error:0.11298
# [7]	train-logloss:0.26545	train-auc:0.95557	train-error:0.10676	val-logloss:0.28432	val-auc:0.93605	val-error:0.11068
# [8]	train-logloss:0.25474	train-auc:0.95738	train-error:0.10304	val-logloss:0.27671	val-auc:0.93389	val-error:0.11002
# [9]	train-logloss:0.24509	train-auc:0.96009	train-error:0.09833	val-logloss:0.27224	val-auc:0.92992	val-error:0.10946
# [10]	train-logloss:0.23546	train-auc:0.96302	train-error:0.09197	val-logloss:0.26776	val-auc:0.93069	val-error:0.10839
# [11]	train-logloss:0.22718	train-auc:0.96443	train-error:0.08455	val-logloss:0.26157	val-auc:0.93066	val-error:0.10645
# [12]	train-logloss:0.22021	train-auc:0.96566	train-error:0.08021	val-logloss:0.25770	val-auc:0.93032	val-error:0.10597
# [13]	train-logloss:0.21387	train-auc:0.96714	train-error:0.07711	val-logloss:0.25264	val-auc:0.93128	val-error:0.10429
# [14]	train-logloss:0.20756	train-auc:0.96857	train-error:0.07365	val-logloss:0.25019	val-auc:0.93008	val-error:0.10461
# [15]	train-logloss:0.20094	train-auc:0.97060	train-error:0.06923	val-logloss:0.24784	val-auc:0.92869	val-error:0.10283
# [16]	train-logloss:0.19567	train-auc:0.97201	train-error:0.06764	val-logloss:0.24417	val-auc:0.93002	val-error:0.10053
# [17]	train-logloss:0.19079	train-auc:0.97310	train-error:0.06673	val-logloss:0.24208	val-auc:0.92952	val-error:0.09956
# [18]	train-logloss:0.18509	train-auc:0.97482	train-error:0.06398	val-logloss:0.23834	val-auc:0.93113	val-error:0.09850
# [19]	train-logloss:0.18045	train-auc:0.97589	train-error:0.06231	val-logloss:0.23743	val-auc:0.92968	val-error:0.09833
# [20]	train-logloss:0.17626	train-auc:0.97691	train-error:0.06028	val-logloss:0.23477	val-auc:0.93047	val-error:0.09681
# [21]	train-logloss:0.17231	train-auc:0.97777	train-error:0.05909	val-logloss:0.23341	val-auc:0.93011	val-error:0.09712
# [22]	train-logloss:0.16904	train-auc:0.97840	train-error:0.05787	val-logloss:0.23113	val-auc:0.93089	val-error:0.09713
# [23]	train-logloss:0.16595	train-auc:0.97915	train-error:0.05624	val-logloss:0.22913	val-auc:0.93171	val-error:0.09661
# [24]	train-logloss:0.16353	train-auc:0.97949	train-error:0.05540	val-logloss:0.22799	val-auc:0.93159	val-error:0.09651
# [25]	train-logloss:0.16115	train-auc:0.97984	train-error:0.05477	val-logloss:0.22644	val-auc:0.93176	val-error:0.09605
# [26]	train-logloss:0.15911	train-auc:0.98006	train-error:0.05435	val-logloss:0.22568	val-auc:0.93161	val-error:0.09537
# [27]	train-logloss:0.15689	train-auc:0.98052	train-error:0.05364	val-logloss:0.22486	val-auc:0.93153	val-error:0.09614
# [28]	train-logloss:0.15439	train-auc:0.98101	train-error:0.05275	val-logloss:0.22489	val-auc:0.93060	val-error:0.09545
# [29]	train-logloss:0.15220	train-auc:0.98179	train-error:0.05212	val-logloss:0.22375	val-auc:0.93118	val-error:0.09510
# [30]	train-logloss:0.15041	train-auc:0.98204	train-error:0.05169	val-logloss:0.22308	val-auc:0.93089	val-error:0.09405
# [31]	train-logloss:0.14868	train-auc:0.98239	train-error:0.05125	val-logloss:0.22321	val-auc:0.93014	val-error:0.09352
# [32]	train-logloss:0.14746	train-auc:0.98253	train-error:0.05102	val-logloss:0.22244	val-auc:0.93037	val-error:0.09391
# [33]	train-logloss:0.14643	train-auc:0.98274	train-error:0.05060	val-logloss:0.22205	val-auc:0.93048	val-error:0.09389
# [34]	train-logloss:0.14400	train-auc:0.98330	train-error:0.04886	val-logloss:0.22191	val-auc:0.93023	val-error:0.09425
# [35]	train-logloss:0.14181	train-auc:0.98406	train-error:0.04831	val-logloss:0.22063	val-auc:0.93103	val-error:0.09390
# [36]	train-logloss:0.14045	train-auc:0.98437	train-error:0.04801	val-logloss:0.22013	val-auc:0.93109	val-error:0.09407
# [37]	train-logloss:0.13852	train-auc:0.98479	train-error:0.04742	val-logloss:0.21922	val-auc:0.93163	val-error:0.09241
# [38]	train-logloss:0.13721	train-auc:0.98516	train-error:0.04699	val-logloss:0.21891	val-auc:0.93173	val-error:0.09233
# [39]	train-logloss:0.13576	train-auc:0.98545	train-error:0.04646	val-logloss:0.21908	val-auc:0.93130	val-error:0.09169
# [40]	train-logloss:0.13467	train-auc:0.98568	train-error:0.04594	val-logloss:0.21864	val-auc:0.93150	val-error:0.09140
# [41]	train-logloss:0.13386	train-auc:0.98580	train-error:0.04565	val-logloss:0.21824	val-auc:0.93172	val-error:0.09136
# [42]	train-logloss:0.13301	train-auc:0.98592	train-error:0.04525	val-logloss:0.21747	val-auc:0.93226	val-error:0.09129
# [43]	train-logloss:0.13163	train-auc:0.98627	train-error:0.04475	val-logloss:0.21607	val-auc:0.93330	val-error:0.09072
# [44]	train-logloss:0.13086	train-auc:0.98641	train-error:0.04451	val-logloss:0.21575	val-auc:0.93334	val-error:0.09072
# [45]	train-logloss:0.12948	train-auc:0.98672	train-error:0.04401	val-logloss:0.21675	val-auc:0.93231	val-error:0.09116
# [46]	train-logloss:0.12842	train-auc:0.98710	train-error:0.04343	val-logloss:0.21645	val-auc:0.93249	val-error:0.09111
# [47]	train-logloss:0.12640	train-auc:0.98790	train-error:0.04271	val-logloss:0.21424	val-auc:0.93461	val-error:0.09125
# [48]	train-logloss:0.12536	train-auc:0.98825	train-error:0.04234	val-logloss:0.21406	val-auc:0.93470	val-error:0.09123
# [49]	train-logloss:0.12316	train-auc:0.98882	train-error:0.04127	val-logloss:0.21429	val-auc:0.93444	val-error:0.09104
# [50]	train-logloss:0.12262	train-auc:0.98888	train-error:0.04109	val-logloss:0.21387	val-auc:0.93457	val-error:0.09102
# [51]	train-logloss:0.12210	train-auc:0.98893	train-error:0.04100	val-logloss:0.21361	val-auc:0.93458	val-error:0.09109
# [52]	train-logloss:0.12027	train-auc:0.98940	train-error:0.04005	val-logloss:0.21373	val-auc:0.93403	val-error:0.08881
# [53]	train-logloss:0.11937	train-auc:0.98955	train-error:0.03984	val-logloss:0.21292	val-auc:0.93458	val-error:0.08871
# [54]	train-logloss:0.11881	train-auc:0.98967	train-error:0.03974	val-logloss:0.21295	val-auc:0.93441	val-error:0.08883
# [55]	train-logloss:0.11727	train-auc:0.99026	train-error:0.03920	val-logloss:0.21235	val-auc:0.93495	val-error:0.08872
# [56]	train-logloss:0.11653	train-auc:0.99040	train-error:0.03885	val-logloss:0.21307	val-auc:0.93413	val-error:0.08869
# [57]	train-logloss:0.11461	train-auc:0.99096	train-error:0.03753	val-logloss:0.21242	val-auc:0.93492	val-error:0.08957
# [58]	train-logloss:0.11411	train-auc:0.99107	train-error:0.03733	val-logloss:0.21357	val-auc:0.93380	val-error:0.08964
# [59]	train-logloss:0.11214	train-auc:0.99160	train-error:0.03626	val-logloss:0.21391	val-auc:0.93345	val-error:0.08924
# [60]	train-logloss:0.11121	train-auc:0.99187	train-error:0.03567	val-logloss:0.21385	val-auc:0.93344	val-error:0.08942
# [61]	train-logloss:0.10923	train-auc:0.99237	train-error:0.03466	val-logloss:0.21285	val-auc:0.93396	val-error:0.08711
# [62]	train-logloss:0.10844	train-auc:0.99258	train-error:0.03426	val-logloss:0.21326	val-auc:0.93342	val-error:0.08714
# [63]	train-logloss:0.10666	train-auc:0.99302	train-error:0.03359	val-logloss:0.21379	val-auc:0.93265	val-error:0.08625
# [64]	train-logloss:0.10592	train-auc:0.99318	train-error:0.03329	val-logloss:0.21538	val-auc:0.93121	val-error:0.08659
# [65]	train-logloss:0.10488	train-auc:0.99342	train-error:0.03282	val-logloss:0.21541	val-auc:0.93105	val-error:0.08637
# [66]	train-logloss:0.10371	train-auc:0.99374	train-error:0.03227	val-logloss:0.21599	val-auc:0.93048	val-error:0.08646
# [67]	train-logloss:0.10181	train-auc:0.99415	train-error:0.03161	val-logloss:0.21696	val-auc:0.92988	val-error:0.08747
# [68]	train-logloss:0.10096	train-auc:0.99430	train-error:0.03103	val-logloss:0.21739	val-auc:0.92919	val-error:0.08730
# [69]	train-logloss:0.09991	train-auc:0.99456	train-error:0.03045	val-logloss:0.21675	val-auc:0.92994	val-error:0.08729
# [70]	train-logloss:0.09910	train-auc:0.99471	train-error:0.03007	val-logloss:0.21726	val-auc:0.92940	val-error:0.08724
# [71]	train-logloss:0.09845	train-auc:0.99487	train-error:0.02978	val-logloss:0.21738	val-auc:0.92927	val-error:0.08726
# [72]	train-logloss:0.09708	train-auc:0.99512	train-error:0.02891	val-logloss:0.21839	val-auc:0.92837	val-error:0.08790
# [73]	train-logloss:0.09681	train-auc:0.99516	train-error:0.02880	val-logloss:0.21830	val-auc:0.92838	val-error:0.08777
# [74]	train-logloss:0.09641	train-auc:0.99519	train-error:0.02866	val-logloss:0.21814	val-auc:0.92853	val-error:0.08756
# [75]	train-logloss:0.09541	train-auc:0.99538	train-error:0.02802	val-logloss:0.21825	val-auc:0.92846	val-error:0.08796
# [76]	train-logloss:0.09459	train-auc:0.99556	train-error:0.02756	val-logloss:0.21943	val-auc:0.92741	val-error:0.08807
# [77]	train-logloss:0.09388	train-auc:0.99572	train-error:0.02674	val-logloss:0.22080	val-auc:0.92614	val-error:0.08825
# [78]	train-logloss:0.09362	train-auc:0.99574	train-error:0.02670	val-logloss:0.22074	val-auc:0.92613	val-error:0.08820
# [79]	train-logloss:0.09319	train-auc:0.99585	train-error:0.02623	val-logloss:0.22072	val-auc:0.92615	val-error:0.08823
# [80]	train-logloss:0.09200	train-auc:0.99602	train-error:0.02583	val-logloss:0.22110	val-auc:0.92589	val-error:0.08783
# [81]	train-logloss:0.09131	train-auc:0.99612	train-error:0.02567	val-logloss:0.22105	val-auc:0.92594	val-error:0.08796
# [82]	train-logloss:0.09068	train-auc:0.99622	train-error:0.02514	val-logloss:0.22092	val-auc:0.92611	val-error:0.08807
# [83]	train-logloss:0.08958	train-auc:0.99640	train-error:0.02469	val-logloss:0.22171	val-auc:0.92499	val-error:0.08673
# [84]	train-logloss:0.08938	train-auc:0.99644	train-error:0.02460	val-logloss:0.22184	val-auc:0.92478	val-error:0.08681
# [85]	train-logloss:0.08848	train-auc:0.99657	train-error:0.02426	val-logloss:0.22342	val-auc:0.92319	val-error:0.08725
# [86]	train-logloss:0.08768	train-auc:0.99677	train-error:0.02394	val-logloss:0.22308	val-auc:0.92368	val-error:0.08725
# [87]	train-logloss:0.08682	train-auc:0.99688	train-error:0.02348	val-logloss:0.22441	val-auc:0.92263	val-error:0.08751
# [88]	train-logloss:0.08602	train-auc:0.99701	train-error:0.02305	val-logloss:0.22454	val-auc:0.92272	val-error:0.08754
# [89]	train-logloss:0.08510	train-auc:0.99712	train-error:0.02265	val-logloss:0.22505	val-auc:0.92219	val-error:0.08779
# [90]	train-logloss:0.08475	train-auc:0.99715	train-error:0.02252	val-logloss:0.22481	val-auc:0.92250	val-error:0.08773
# [91]	train-logloss:0.08403	train-auc:0.99722	train-error:0.02210	val-logloss:0.22447	val-auc:0.92253	val-error:0.08735
# [92]	train-logloss:0.08337	train-auc:0.99731	train-error:0.02180	val-logloss:0.22571	val-auc:0.92130	val-error:0.08735
# [93]	train-logloss:0.08255	train-auc:0.99741	train-error:0.02147	val-logloss:0.22571	val-auc:0.92128	val-error:0.08751
# [94]	train-logloss:0.08187	train-auc:0.99749	train-error:0.02109	val-logloss:0.22547	val-auc:0.92175	val-error:0.08752
# [95]	train-logloss:0.08171	train-auc:0.99750	train-error:0.02102	val-logloss:0.22563	val-auc:0.92166	val-error:0.08751
# [96]	train-logloss:0.08152	train-auc:0.99751	train-error:0.02102	val-logloss:0.22556	val-auc:0.92165	val-error:0.08748
# [97]	train-logloss:0.08111	train-auc:0.99754	train-error:0.02085	val-logloss:0.22560	val-auc:0.92166	val-error:0.08751
# [98]	train-logloss:0.08045	train-auc:0.99762	train-error:0.02047	val-logloss:0.22558	val-auc:0.92160	val-error:0.08749
# [99]	train-logloss:0.07948	train-auc:0.99777	train-error:0.01991	val-logloss:0.22464	val-auc:0.92265	val-error:0.08746
# [100]	train-logloss:0.07843	train-auc:0.99787	train-error:0.01940	val-logloss:0.22671	val-auc:0.92081	val-error:0.08799
# [101]	train-logloss:0.07754	train-auc:0.99798	train-error:0.01888	val-logloss:0.22649	val-auc:0.92095	val-error:0.08784
# [102]	train-logloss:0.07699	train-auc:0.99804	train-error:0.01866	val-logloss:0.22634	val-auc:0.92130	val-error:0.08781
# [103]	train-logloss:0.07660	train-auc:0.99810	train-error:0.01838	val-logloss:0.22633	val-auc:0.92133	val-error:0.08784
# [104]	train-logloss:0.07611	train-auc:0.99814	train-error:0.01820	val-logloss:0.22597	val-auc:0.92156	val-error:0.08767
# [105]	train-logloss:0.07538	train-auc:0.99821	train-error:0.01797	val-logloss:0.22663	val-auc:0.92085	val-error:0.08762
# [106]	train-logloss:0.07495	train-auc:0.99826	train-error:0.01765	val-logloss:0.22625	val-auc:0.92127	val-error:0.08773
# [107]	train-logloss:0.07385	train-auc:0.99838	train-error:0.01715	val-logloss:0.22699	val-auc:0.92103	val-error:0.08892
# [108]	train-logloss:0.07353	train-auc:0.99842	train-error:0.01697	val-logloss:0.22729	val-auc:0.92093	val-error:0.08901
# [109]	train-logloss:0.07338	train-auc:0.99842	train-error:0.01699	val-logloss:0.22722	val-auc:0.92096	val-error:0.08895
# [110]	train-logloss:0.07286	train-auc:0.99846	train-error:0.01669	val-logloss:0.22889	val-auc:0.91944	val-error:0.08905
# [111]	train-logloss:0.07249	train-auc:0.99848	train-error:0.01649	val-logloss:0.22893	val-auc:0.91961	val-error:0.08901
# [112]	train-logloss:0.07156	train-auc:0.99859	train-error:0.01599	val-logloss:0.22875	val-auc:0.92022	val-error:0.08941
# [113]	train-logloss:0.07134	train-auc:0.99860	train-error:0.01594	val-logloss:0.22855	val-auc:0.92058	val-error:0.08941
# XGBoost模型训练完成
# 完成时间20251215_140632

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
# 绘制logloss
plt.subplot(1, 3, 1)
plt.plot(eval_history['train']['logloss'], label='Train Logloss')
plt.plot(eval_history['val']['logloss'], label='Validation Logloss')
plt.xlabel('Iteration')
plt.ylabel('Logloss')
plt.title('XGBoost Training - Logloss')
plt.legend()
plt.grid(True)

# 绘制错误率
plt.subplot(1, 3, 2)
plt.plot(eval_history['train']['error'], label='Train Error')
plt.plot(eval_history['val']['error'], label='Validation Error')
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.title('XGBoost Training - Error')
plt.legend()
plt.grid(True)

# 绘制错误率
plt.subplot(1, 3, 3)
plt.plot(eval_history['train']['auc'], label='Train auc')
plt.plot(eval_history['val']['auc'], label='Validation auc')
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.title('XGBoost Training - auc')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
"""
评估XGBoost模型性能
"""
print("\n" + "="*60)
print("XGBoost模型评估结果")
print("="*60)

# 训练集预测
y_train_prob = model.predict(dtrain)  # 预测概率
y_train_pred = (y_train_prob > 0.5).astype(int)  # 转换为类别

# 验证集预测
y_val_prob = model.predict(dval)  # 预测概率
y_val_pred = (y_val_prob > 0.5).astype(int)  # 转换为类别

# 计算训练集指标
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, zero_division=0)
train_recall = recall_score(y_train, y_train_pred, zero_division=0)
train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
train_auc = roc_auc_score(y_train, y_train_prob)

# 计算验证集指标
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred, zero_division=0)
val_recall = recall_score(y_val, y_val_pred, zero_division=0)
val_f1 = f1_score(y_val, y_val_pred, zero_division=0)
val_auc = roc_auc_score(y_val, y_val_prob)

# 打印结果表格
print(f"{'指标':<12} | {'训练集':<10} | {'验证集':<10}")
print("-" * 40)
print(f"{'准确率':<12} | {train_accuracy:>10.4f} | {val_accuracy:>10.4f}")
print(f"{'精确率':<12} | {train_precision:>10.4f} | {val_precision:>10.4f}")
print(f"{'召回率':<12} | {train_recall:>10.4f} | {val_recall:>10.4f}")
print(f"{'F1分数':<13} | {train_f1:>10.4f} | {val_f1:>10.4f}")
print(f"{'AUC':<14} | {train_auc:>10.4f} | {val_auc:>10.4f}")

# 验证集详细报告
print(f"\n验证集详细分类报告:")
print(classification_report(y_val, y_val_pred, target_names=['Class 0', 'Class 1']))

# 混淆矩阵
cm = confusion_matrix(y_val, y_val_pred)
print(f"\n验证集混淆矩阵:")
print(f"TN: {cm[0,0]}, FP: {cm[0,1]}")
print(f"FN: {cm[1,0]}, TP: {cm[1,1]}")

feature_names = [f'feature_{i}' for i in range(X_train.shape[1])]

model_name="Model_XGBoost.pkl"

"""
保存XGBoost模型
"""
# 准备保存的数据
model_data = {
    'model': model,
    'feature_names': feature_names,
    'model_type': 'booster'
}
# 获取特征数量
if X_train is not None:
    num_features = X_train.shape[1]
else:
    num_features = len(feature_names)

# 获取最佳迭代轮数
best_iteration = getattr(model, 'best_iteration', '未知')
best_score = getattr(model, 'best_score', '未知')

model_data.update({
    'num_features': num_features,
    'best_iteration': best_iteration,
    'best_score': best_score
})

# 保存模型
joblib.dump(model_data, model_name)
print(f"\n模型已保存为: {model_name}")
print(f"模型类型: Booster (原生接口)")
print(f"特征数量: {model_data.get('num_features', len(feature_names))}")
print(f"最佳迭代轮数: {best_iteration}")
print(f"最佳验证分数: {best_score}")
print(f"类别: [0, 1] (二分类任务)")
print(f"\n{'='*60}")
print("XGBoost模型训练完成!")
print(f"{'='*60}")
# Out:
# ============================================================
# XGBoost模型评估结果
# ============================================================
# 指标           | 训练集        | 验证集
# ----------------------------------------
# 准确率          |     0.9841 |     0.9106
# 精确率          |     0.9816 |     0.8911
# 召回率          |     0.9053 |     0.4298
# F1分数          |     0.9419 |     0.5799
# AUC            |     0.9986 |     0.9206
#
# 验证集详细分类报告:
#               precision    recall  f1-score   support
#
#      Class 0       0.91      0.99      0.95     96956
#      Class 1       0.89      0.43      0.58     16255
#
#     accuracy                           0.91    113211
#    macro avg       0.90      0.71      0.76    113211
# weighted avg       0.91      0.91      0.90    113211
#
#
# 验证集混淆矩阵:
# TN: 96102, FP: 854
# FN: 9268, TP: 6987
#
# 模型已保存为: Model_XGBoost.pkl
# 模型类型: Booster (原生接口)
# 特征数量: 2000
# 最佳迭代轮数: 63
# 最佳验证分数: 0.08624603616256371
# 类别: [0, 1] (二分类任务)
#
# ============================================================
# XGBoost模型训练完成!
# ============================================================
